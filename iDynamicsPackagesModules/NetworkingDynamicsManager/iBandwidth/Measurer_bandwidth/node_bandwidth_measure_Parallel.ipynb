# %%
'''Deploy cross-node bandwidth measurement pods'''

from kubernetes import client, config

def check_pods_existence(namespace):
    core_v1 = client.CoreV1Api()
    try:
        pods = core_v1.list_namespaced_pod(namespace=namespace)
        return len(pods.items) > 0  # return True if pods exist
    except client.rest.ApiException as e:
        print(f"Exception when calling CoreV1Api->list_namespaced_pod: {e}")
        return False

def deploy_bandwidth_measurement_daemonset_if_needed():
    namespace = 'measure-nodes-bd'
    ds_name = 'bandwidth-measurement-ds'
    
    # Load Kubernetes configuration
    config.load_kube_config()
    apps_v1 = client.AppsV1Api()

    # Check if pods exist in the namespace
    pods_exist = check_pods_existence(namespace)

    # If no pods exist, deploy the DaemonSet
    if not pods_exist:
        # Define the body of the DaemonSet for `iperf3` server deployment
        ds_body = client.V1DaemonSet(
            api_version="apps/v1",
            kind="DaemonSet",
            metadata=client.V1ObjectMeta(name=ds_name),
            spec=client.V1DaemonSetSpec(
                selector=client.V1LabelSelector(
                    match_labels={"app": "bandwidth-measurement"}
                ),
                template=client.V1PodTemplateSpec(
                    metadata=client.V1ObjectMeta(labels={"app": "bandwidth-measurement"}),
                    spec=client.V1PodSpec(
                        containers=[client.V1Container(
                            name="iperf3-server",
                            image="networkstatic/iperf3",
                            args=["-s"],  # Run in server mode
                            ports=[client.V1ContainerPort(container_port=5201)]
                        )],
                        restart_policy="Always"
                    )
                )
            )
        )

        # Deploy the DaemonSet
        try:
            apps_v1.create_namespaced_daemon_set(namespace=namespace, body=ds_body)
            print(f"Deployed DaemonSet {ds_name} in namespace {namespace}")
        except client.rest.ApiException as e:
            print(f"Exception when calling AppsV1Api->create_namespaced_daemon_set: {e}")
    else:
        print("Pods already exist in the namespace. Skipping DaemonSet deployment.")

# Call the function to deploy the DaemonSet if needed
deploy_bandwidth_measurement_daemonset_if_needed()
# Out:
# Pods already exist in the namespace. Skipping DaemonSet deployment.

# %%
import re
from kubernetes import client, config, stream
import concurrent.futures
import time

# Load Kubernetes configuration
config.load_kube_config()
v1 = client.CoreV1Api()

# Function to measure bandwidth between source and target pods with retries
def measure_bandwidth_from_source_to_target(v1, namespace, source_pod, target_pod, test_duration=5, max_retries=3):
    source_pod_name = source_pod.metadata.name
    source_pod_node_name = source_pod.spec.node_name
    target_pod_ip = target_pod.status.pod_ip
    target_pod_name = target_pod.metadata.name
    target_pod_node_name = target_pod.spec.node_name
    result = (source_pod_node_name, target_pod_node_name, None)

    if source_pod_name != target_pod_name:
        exec_command = ['iperf3', '-c', target_pod_ip, '-t', str(test_duration)]
        attempts = 0

        while attempts < max_retries:
            try:
                # Run iperf3 command
                resp = stream.stream(v1.connect_get_namespaced_pod_exec,
                                     source_pod_name,
                                     namespace,
                                     command=exec_command,
                                     stderr=True,
                                     stdin=False,
                                     stdout=True,
                                     tty=False)

                # Check for "server is busy" in the output
                if "the server is busy" in resp:
                    print(f"Server is busy for connection from {source_pod_name} to {target_pod_name}. Retrying...")
                    attempts += 1
                    time.sleep(test_duration/2)  # Wait before retrying
                    continue

                # Parse the output for bandwidth
                print(f"Full output from {source_pod_name} to {target_pod_name}:\n{resp}")
                match = re.search(r'(\d+\.?\d*\s[MKG]bits/sec)', resp)
                if match:
                    bandwidth = match.group(1)
                    result = (source_pod_node_name, target_pod_node_name, bandwidth)
                    print(f"Bandwidth from {source_pod_node_name} to {target_pod_node_name}: {bandwidth}")
                else:
                    print(f"Could not extract bandwidth for connection from {source_pod_name} to {target_pod_name}.")
                    result = (source_pod_node_name, target_pod_node_name, "Parsing Error")
                break  # Exit loop on success

            except Exception as e:
                print(f"Error executing command in pod {source_pod_name}: {e}")
                result = (source_pod_node_name, target_pod_node_name, "Error")
                break

        if attempts == max_retries:
            print(f"Max retries reached for connection from {source_pod_name} to {target_pod_name}.")
            result = (source_pod_node_name, target_pod_node_name, "Server Busy Error")

    return result

def measure_bandwidth(namespace='measure-nodes-bd', max_concurrent_tasks=3, test_duration=5):
    v1 = client.CoreV1Api()
    pods = v1.list_namespaced_pod(namespace, label_selector="app=bandwidth-measurement").items
    bandwidth_results = {}

    # Use ThreadPoolExecutor for controlled concurrent execution
    with concurrent.futures.ThreadPoolExecutor(max_workers=max_concurrent_tasks) as executor:
        futures = []
        for source_pod in pods:
            for target_pod in pods:
                if source_pod.metadata.name != target_pod.metadata.name:  # Skip self-tests
                    futures.append(executor.submit(measure_bandwidth_from_source_to_target,
                                                   v1, namespace, source_pod, target_pod, test_duration))

        # Collect the completed results
        for future in concurrent.futures.as_completed(futures):
            source_pod_node_name, target_pod_node_name, bandwidth = future.result()
            if source_pod_node_name not in bandwidth_results:
                bandwidth_results[source_pod_node_name] = {}
            bandwidth_results[source_pod_node_name][target_pod_node_name] = bandwidth

    return bandwidth_results

# Call the function to measure bandwidth after deploying the DaemonSet
namespace = 'measure-nodes-bd'
# Reduced concurrency and added retry logic
bandwidth_results = measure_bandwidth(namespace=namespace, max_concurrent_tasks=3, test_duration=10)
print(bandwidth_results)
# Out:
# Full output from bandwidth-measurement-ds-6dldb to bandwidth-measurement-ds-gnsh9:
# Connecting to host 192.168.230.8, port 5201
# [  5] local 192.168.69.255 port 58036 connected to 192.168.230.8 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec   145 MBytes  1.22 Gbits/sec   17   1.16 MBytes
# [  5]   1.00-2.00   sec   170 MBytes  1.43 Gbits/sec    1   1.69 MBytes
# [  5]   2.00-3.00   sec   169 MBytes  1.42 Gbits/sec    0   2.10 MBytes
# [  5]   3.00-4.00   sec   162 MBytes  1.36 Gbits/sec    1   1.74 MBytes
# [  5]   4.00-5.00   sec   158 MBytes  1.32 Gbits/sec    1   1.48 MBytes
# [  5]   5.00-6.00   sec   151 MBytes  1.27 Gbits/sec    0   1.88 MBytes
# [  5]   6.00-7.00   sec   141 MBytes  1.18 Gbits/sec    1   1.63 MBytes
# [  5]   7.00-8.00   sec   136 MBytes  1.14 Gbits/sec    1   1.49 MBytes
# [  5]   8.00-9.00   sec   131 MBytes  1.10 Gbits/sec    1   1.37 MBytes
# [  5]   9.00-10.00  sec   131 MBytes  1.10 Gbits/sec    0   1.75 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec  1.46 GBytes  1.25 Gbits/sec   23             sender
# [  5]   0.00-10.00  sec  1.46 GBytes  1.25 Gbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-3 to k8s-worker-1: 1.22 Gbits/sec
# Full output from bandwidth-measurement-ds-6dldb to bandwidth-measurement-ds-p2vgl:
# Connecting to host 192.168.18.225, port 5201
# [  5] local 192.168.69.255 port 34422 connected to 192.168.18.225 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec   222 MBytes  1.86 Gbits/sec    0   3.15 MBytes
# [  5]   1.00-2.00   sec   174 MBytes  1.46 Gbits/sec    0   3.15 MBytes
# [  5]   2.00-3.00   sec   166 MBytes  1.39 Gbits/sec    1   2.27 MBytes
# [  5]   3.00-4.00   sec   164 MBytes  1.37 Gbits/sec    0   2.63 MBytes
# [  5]   4.00-5.00   sec   154 MBytes  1.29 Gbits/sec    1   2.10 MBytes
# [  5]   5.00-6.00   sec   152 MBytes  1.28 Gbits/sec    0   2.41 MBytes
# [  5]   6.00-7.00   sec   139 MBytes  1.16 Gbits/sec    1   1.92 MBytes
# [  5]   7.00-8.00   sec   135 MBytes  1.13 Gbits/sec    0   2.21 MBytes
# [  5]   8.00-9.00   sec   131 MBytes  1.10 Gbits/sec    1   1.84 MBytes
# [  5]   9.00-10.00  sec   131 MBytes  1.10 Gbits/sec    0   2.14 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec  1.53 GBytes  1.32 Gbits/sec    4             sender
# [  5]   0.00-10.01  sec  1.53 GBytes  1.31 Gbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-3 to k8s-worker-5: 1.86 Gbits/sec
# Full output from bandwidth-measurement-ds-6dldb to bandwidth-measurement-ds-nrznp:
# Connecting to host 192.168.231.202, port 5201
# [  5] local 192.168.69.255 port 57490 connected to 192.168.231.202 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  42.8 MBytes   359 Mbits/sec    3   1.18 MBytes
# [  5]   1.00-2.00   sec  55.0 MBytes   461 Mbits/sec    0   1.37 MBytes
# [  5]   2.00-3.00   sec  65.0 MBytes   545 Mbits/sec    0   1.57 MBytes
# [  5]   3.00-4.00   sec  72.5 MBytes   608 Mbits/sec    0   1.77 MBytes
# [  5]   4.00-5.00   sec  81.2 MBytes   682 Mbits/sec    0   1.97 MBytes
# [  5]   5.00-6.00   sec  90.0 MBytes   755 Mbits/sec    0   2.16 MBytes
# [  5]   6.00-7.00   sec  95.0 MBytes   797 Mbits/sec    0   2.36 MBytes
# [  5]   7.00-8.00   sec   105 MBytes   881 Mbits/sec    0   2.55 MBytes
# [  5]   8.00-9.00   sec   116 MBytes   975 Mbits/sec    0   3.02 MBytes
# [  5]   9.00-10.00  sec   121 MBytes  1.02 Gbits/sec    0   3.02 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   844 MBytes   708 Mbits/sec    3             sender
# [  5]   0.00-10.02  sec   844 MBytes   706 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-3 to k8s-worker-8: 359 Mbits/sec
# Full output from bandwidth-measurement-ds-6dldb to bandwidth-measurement-ds-r7ftn:
# Connecting to host 192.168.251.72, port 5201
# [  5] local 192.168.69.255 port 49348 connected to 192.168.251.72 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec   243 MBytes  2.04 Gbits/sec    0   3.15 MBytes
# [  5]   1.00-2.00   sec   132 MBytes  1.11 Gbits/sec    2   1.78 MBytes
# [  5]   2.00-3.00   sec   130 MBytes  1.09 Gbits/sec    1   1.47 MBytes
# [  5]   3.00-4.00   sec   125 MBytes  1.05 Gbits/sec    0   1.81 MBytes
# [  5]   4.00-5.00   sec   131 MBytes  1.10 Gbits/sec    0   2.11 MBytes
# [  5]   5.00-6.00   sec   134 MBytes  1.12 Gbits/sec    1   1.82 MBytes
# [  5]   6.00-7.00   sec   131 MBytes  1.10 Gbits/sec    1   1.54 MBytes
# [  5]   7.00-8.00   sec   125 MBytes  1.05 Gbits/sec    0   1.87 MBytes
# [  5]   8.00-9.00   sec   131 MBytes  1.10 Gbits/sec    1   1.58 MBytes
# [  5]   9.00-10.00  sec   135 MBytes  1.13 Gbits/sec    0   1.93 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec  1.38 GBytes  1.19 Gbits/sec    6             sender
# [  5]   0.00-10.01  sec  1.38 GBytes  1.19 Gbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-3 to k8s-worker-9: 2.04 Gbits/sec
# Full output from bandwidth-measurement-ds-6dldb to bandwidth-measurement-ds-vf5qp:
# Connecting to host 192.168.140.14, port 5201
# [  5] local 192.168.69.255 port 60714 connected to 192.168.140.14 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec   148 MBytes  1.24 Gbits/sec    3   4.62 MBytes
# [  5]   1.00-2.00   sec   130 MBytes  1.09 Gbits/sec    0   4.62 MBytes
# [  5]   2.00-3.00   sec   122 MBytes  1.03 Gbits/sec    2   2.44 MBytes
# [  5]   3.00-4.00   sec   125 MBytes  1.05 Gbits/sec    0   2.66 MBytes
# [  5]   4.00-5.00   sec   124 MBytes  1.04 Gbits/sec    1   2.11 MBytes
# [  5]   5.00-6.00   sec   134 MBytes  1.12 Gbits/sec    0   2.39 MBytes
# [  5]   6.00-7.00   sec   129 MBytes  1.08 Gbits/sec    0   2.58 MBytes
# [  5]   7.00-8.00   sec   126 MBytes  1.06 Gbits/sec    0   2.77 MBytes
# [  5]   8.00-9.00   sec   132 MBytes  1.11 Gbits/sec    0   2.98 MBytes
# [  5]   9.00-10.00  sec   136 MBytes  1.14 Gbits/sec    1   2.18 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec  1.28 GBytes  1.10 Gbits/sec    7             sender
# [  5]   0.00-10.01  sec  1.27 GBytes  1.09 Gbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-3 to k8s-worker-2: 1.24 Gbits/sec
# Full output from bandwidth-measurement-ds-6dldb to bandwidth-measurement-ds-rfvj2:
# Connecting to host 192.168.227.156, port 5201
# [  5] local 192.168.69.255 port 47926 connected to 192.168.227.156 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  68.4 MBytes   574 Mbits/sec    1   2.21 MBytes
# [  5]   1.00-2.00   sec   126 MBytes  1.06 Gbits/sec    0   2.59 MBytes
# [  5]   2.00-3.00   sec   122 MBytes  1.03 Gbits/sec    1   2.06 MBytes
# [  5]   3.00-4.00   sec   125 MBytes  1.05 Gbits/sec    0   2.32 MBytes
# [  5]   4.00-5.00   sec   136 MBytes  1.14 Gbits/sec    0   2.57 MBytes
# [  5]   5.00-6.00   sec   129 MBytes  1.08 Gbits/sec    1   2.05 MBytes
# [  5]   6.00-7.00   sec   126 MBytes  1.06 Gbits/sec    0   2.33 MBytes
# [  5]   7.00-8.00   sec   128 MBytes  1.07 Gbits/sec    0   2.52 MBytes
# [  5]   8.00-9.00   sec   132 MBytes  1.11 Gbits/sec    1   1.90 MBytes
# [  5]   9.00-10.00  sec   138 MBytes  1.15 Gbits/sec    0   2.24 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec  1.20 GBytes  1.03 Gbits/sec    4             sender
# [  5]   0.00-10.01  sec  1.20 GBytes  1.03 Gbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-3 to k8s-worker-6: 574 Mbits/sec
# Full output from bandwidth-measurement-ds-6dldb to bandwidth-measurement-ds-z29qn:
# Connecting to host 192.168.5.57, port 5201
# [  5] local 192.168.69.255 port 39428 connected to 192.168.5.57 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec   181 MBytes  1.52 Gbits/sec    1   3.29 MBytes
# [  5]   1.00-2.00   sec   160 MBytes  1.34 Gbits/sec    0   3.29 MBytes
# [  5]   2.00-3.00   sec   158 MBytes  1.32 Gbits/sec    0   3.29 MBytes
# [  5]   3.00-4.00   sec   152 MBytes  1.28 Gbits/sec    0   3.29 MBytes
# [  5]   4.00-5.00   sec   155 MBytes  1.30 Gbits/sec    1   2.42 MBytes
# [  5]   5.00-6.00   sec   159 MBytes  1.33 Gbits/sec    0   2.70 MBytes
# [  5]   6.00-7.00   sec   156 MBytes  1.31 Gbits/sec    1   2.13 MBytes
# [  5]   7.00-8.00   sec   161 MBytes  1.35 Gbits/sec    0   2.44 MBytes
# [  5]   8.00-9.00   sec   159 MBytes  1.33 Gbits/sec    0   2.71 MBytes
# [  5]   9.00-10.00  sec   159 MBytes  1.33 Gbits/sec    0   2.95 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec  1.56 GBytes  1.34 Gbits/sec    3             sender
# [  5]   0.00-10.01  sec  1.56 GBytes  1.34 Gbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-3 to k8s-worker-7: 1.52 Gbits/sec
# Full output from bandwidth-measurement-ds-6dldb to bandwidth-measurement-ds-z4wqx:
# Connecting to host 192.168.79.113, port 5201
# [  5] local 192.168.69.255 port 34926 connected to 192.168.79.113 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec   134 MBytes  1.13 Gbits/sec    1   1.74 MBytes
# [  5]   1.00-2.00   sec   150 MBytes  1.26 Gbits/sec    0   2.10 MBytes
# [  5]   2.00-3.00   sec   156 MBytes  1.31 Gbits/sec    0   2.41 MBytes
# [  5]   3.00-4.00   sec   152 MBytes  1.28 Gbits/sec    0   2.68 MBytes
# [  5]   4.00-5.00   sec   156 MBytes  1.31 Gbits/sec    1   2.19 MBytes
# [  5]   5.00-6.00   sec   158 MBytes  1.32 Gbits/sec    0   2.49 MBytes
# [  5]   6.00-7.00   sec   160 MBytes  1.34 Gbits/sec    1   1.99 MBytes
# [  5]   7.00-8.00   sec   160 MBytes  1.34 Gbits/sec    0   2.31 MBytes
# [  5]   8.00-9.00   sec   160 MBytes  1.34 Gbits/sec    0   2.61 MBytes
# [  5]   9.00-10.00  sec   180 MBytes  1.51 Gbits/sec    0   2.90 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec  1.53 GBytes  1.31 Gbits/sec    3             sender
# [  5]   0.00-10.00  sec  1.53 GBytes  1.31 Gbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-3 to k8s-worker-4: 1.13 Gbits/sec
# Full output from bandwidth-measurement-ds-gnsh9 to bandwidth-measurement-ds-6dldb:
# Connecting to host 192.168.69.255, port 5201
# [  5] local 192.168.230.8 port 54162 connected to 192.168.69.255 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec   287 MBytes  2.41 Gbits/sec    0   3.13 MBytes
# [  5]   1.00-2.00   sec   311 MBytes  2.61 Gbits/sec    0   3.13 MBytes
# [  5]   2.00-3.00   sec   304 MBytes  2.55 Gbits/sec    0   3.13 MBytes
# [  5]   3.00-4.00   sec   302 MBytes  2.54 Gbits/sec    0   3.13 MBytes
# [  5]   4.00-5.00   sec   311 MBytes  2.61 Gbits/sec    0   3.13 MBytes
# [  5]   5.00-6.00   sec   308 MBytes  2.58 Gbits/sec    0   3.13 MBytes
# [  5]   6.00-7.00   sec   318 MBytes  2.66 Gbits/sec    0   3.13 MBytes
# [  5]   7.00-8.00   sec   312 MBytes  2.62 Gbits/sec    0   3.13 MBytes
# [  5]   8.00-9.00   sec   316 MBytes  2.65 Gbits/sec    0   3.13 MBytes
# [  5]   9.00-10.00  sec   378 MBytes  3.17 Gbits/sec    0   3.13 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec  3.07 GBytes  2.64 Gbits/sec    0             sender
# [  5]   0.00-10.01  sec  3.07 GBytes  2.64 Gbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-1 to k8s-worker-3: 2.41 Gbits/sec
# Full output from bandwidth-measurement-ds-gnsh9 to bandwidth-measurement-ds-nrznp:
# Connecting to host 192.168.231.202, port 5201
# [  5] local 192.168.230.8 port 46688 connected to 192.168.231.202 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  71.8 MBytes   601 Mbits/sec    3   6.08 MBytes
# [  5]   1.00-2.00   sec  82.5 MBytes   693 Mbits/sec    0   6.08 MBytes
# [  5]   2.00-3.00   sec  83.8 MBytes   703 Mbits/sec    0   6.08 MBytes
# [  5]   3.00-4.00   sec  83.8 MBytes   703 Mbits/sec    0   6.08 MBytes
# [  5]   4.00-5.00   sec  82.5 MBytes   692 Mbits/sec    0   6.08 MBytes
# [  5]   5.00-6.00   sec  82.5 MBytes   692 Mbits/sec    0   6.08 MBytes
# [  5]   6.00-7.00   sec  83.8 MBytes   703 Mbits/sec    0   6.08 MBytes
# [  5]   7.00-8.00   sec  81.2 MBytes   682 Mbits/sec    0   6.08 MBytes
# [  5]   8.00-9.00   sec  83.8 MBytes   703 Mbits/sec    0   6.08 MBytes
# [  5]   9.00-10.00  sec  83.8 MBytes   703 Mbits/sec    0   6.08 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   819 MBytes   687 Mbits/sec    3             sender
# [  5]   0.00-10.03  sec   818 MBytes   684 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-1 to k8s-worker-8: 601 Mbits/sec
# Full output from bandwidth-measurement-ds-gnsh9 to bandwidth-measurement-ds-p2vgl:
# Connecting to host 192.168.18.225, port 5201
# [  5] local 192.168.230.8 port 53840 connected to 192.168.18.225 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec   295 MBytes  2.47 Gbits/sec    0   3.13 MBytes
# [  5]   1.00-2.00   sec   284 MBytes  2.38 Gbits/sec    0   3.13 MBytes
# [  5]   2.00-3.00   sec   285 MBytes  2.39 Gbits/sec    0   3.13 MBytes
# [  5]   3.00-4.00   sec   280 MBytes  2.35 Gbits/sec    0   3.13 MBytes
# [  5]   4.00-5.00   sec   280 MBytes  2.35 Gbits/sec    0   3.13 MBytes
# [  5]   5.00-6.00   sec   271 MBytes  2.28 Gbits/sec    0   3.13 MBytes
# [  5]   6.00-7.00   sec   271 MBytes  2.28 Gbits/sec    0   3.13 MBytes
# [  5]   7.00-8.00   sec   275 MBytes  2.31 Gbits/sec    0   3.13 MBytes
# [  5]   8.00-9.00   sec   274 MBytes  2.30 Gbits/sec    0   3.13 MBytes
# [  5]   9.00-10.00  sec   276 MBytes  2.32 Gbits/sec    0   3.13 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec  2.73 GBytes  2.34 Gbits/sec    0             sender
# [  5]   0.00-10.01  sec  2.72 GBytes  2.34 Gbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-1 to k8s-worker-5: 2.47 Gbits/sec
# Full output from bandwidth-measurement-ds-gnsh9 to bandwidth-measurement-ds-r7ftn:
# Connecting to host 192.168.251.72, port 5201
# [  5] local 192.168.230.8 port 34630 connected to 192.168.251.72 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec   329 MBytes  2.76 Gbits/sec    0   3.17 MBytes
# [  5]   1.00-2.00   sec   336 MBytes  2.82 Gbits/sec    0   3.17 MBytes
# [  5]   2.00-3.00   sec   340 MBytes  2.85 Gbits/sec    0   3.17 MBytes
# [  5]   3.00-4.00   sec   340 MBytes  2.85 Gbits/sec    0   3.17 MBytes
# [  5]   4.00-5.00   sec   328 MBytes  2.75 Gbits/sec    0   3.17 MBytes
# [  5]   5.00-6.00   sec   320 MBytes  2.68 Gbits/sec    0   3.17 MBytes
# [  5]   6.00-7.00   sec   322 MBytes  2.71 Gbits/sec    0   3.17 MBytes
# [  5]   7.00-8.00   sec   321 MBytes  2.69 Gbits/sec    0   3.17 MBytes
# [  5]   8.00-9.00   sec   322 MBytes  2.71 Gbits/sec    0   3.17 MBytes
# [  5]   9.00-10.00  sec   359 MBytes  3.01 Gbits/sec    0   3.17 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec  3.24 GBytes  2.78 Gbits/sec    0             sender
# [  5]   0.00-10.01  sec  3.24 GBytes  2.78 Gbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-1 to k8s-worker-9: 2.76 Gbits/sec
# Full output from bandwidth-measurement-ds-gnsh9 to bandwidth-measurement-ds-vf5qp:
# Connecting to host 192.168.140.14, port 5201
# [  5] local 192.168.230.8 port 42098 connected to 192.168.140.14 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec   297 MBytes  2.49 Gbits/sec    0   4.21 MBytes
# [  5]   1.00-2.00   sec   274 MBytes  2.30 Gbits/sec    0   4.21 MBytes
# [  5]   2.00-3.00   sec   252 MBytes  2.12 Gbits/sec    0   4.21 MBytes
# [  5]   3.00-4.00   sec   248 MBytes  2.08 Gbits/sec    0   4.21 MBytes
# [  5]   4.00-5.00   sec   236 MBytes  1.98 Gbits/sec    0   4.21 MBytes
# [  5]   5.00-6.00   sec   231 MBytes  1.94 Gbits/sec    0   4.21 MBytes
# [  5]   6.00-7.00   sec   230 MBytes  1.93 Gbits/sec    0   4.21 MBytes
# [  5]   7.00-8.00   sec   235 MBytes  1.97 Gbits/sec    0   4.21 MBytes
# [  5]   8.00-9.00   sec   232 MBytes  1.95 Gbits/sec    0   4.21 MBytes
# [  5]   9.00-10.00  sec   234 MBytes  1.96 Gbits/sec    0   4.21 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec  2.41 GBytes  2.07 Gbits/sec    0             sender
# [  5]   0.00-10.01  sec  2.41 GBytes  2.07 Gbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-1 to k8s-worker-2: 2.49 Gbits/sec
# Full output from bandwidth-measurement-ds-gnsh9 to bandwidth-measurement-ds-rfvj2:
# Connecting to host 192.168.227.156, port 5201
# [  5] local 192.168.230.8 port 59414 connected to 192.168.227.156 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec   135 MBytes  1.13 Gbits/sec    6   1.80 MBytes
# [  5]   1.00-2.00   sec   168 MBytes  1.41 Gbits/sec    0   2.18 MBytes
# [  5]   2.00-3.00   sec   202 MBytes  1.70 Gbits/sec    0   2.56 MBytes
# [  5]   3.00-4.00   sec   209 MBytes  1.75 Gbits/sec    0   2.91 MBytes
# [  5]   4.00-5.00   sec   216 MBytes  1.81 Gbits/sec    0   3.02 MBytes
# [  5]   5.00-6.00   sec   218 MBytes  1.83 Gbits/sec    0   3.03 MBytes
# [  5]   6.00-7.00   sec   214 MBytes  1.79 Gbits/sec    0   3.03 MBytes
# [  5]   7.00-8.00   sec   215 MBytes  1.80 Gbits/sec    0   3.03 MBytes
# [  5]   8.00-9.00   sec   216 MBytes  1.81 Gbits/sec    0   3.03 MBytes
# [  5]   9.00-10.00  sec   218 MBytes  1.82 Gbits/sec    0   3.03 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec  1.96 GBytes  1.69 Gbits/sec    6             sender
# [  5]   0.00-10.01  sec  1.96 GBytes  1.68 Gbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-1 to k8s-worker-6: 1.13 Gbits/sec
# Full output from bandwidth-measurement-ds-gnsh9 to bandwidth-measurement-ds-z29qn:
# Connecting to host 192.168.5.57, port 5201
# [  5] local 192.168.230.8 port 36548 connected to 192.168.5.57 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec   255 MBytes  2.14 Gbits/sec    1   6.16 MBytes
# [  5]   1.00-2.00   sec   251 MBytes  2.11 Gbits/sec    0   6.16 MBytes
# [  5]   2.00-3.00   sec   242 MBytes  2.03 Gbits/sec    0   6.16 MBytes
# [  5]   3.00-4.00   sec   235 MBytes  1.97 Gbits/sec    0   6.16 MBytes
# [  5]   4.00-5.00   sec   231 MBytes  1.94 Gbits/sec    0   6.16 MBytes
# [  5]   5.00-6.00   sec   229 MBytes  1.92 Gbits/sec    0   6.16 MBytes
# [  5]   6.00-7.00   sec   229 MBytes  1.92 Gbits/sec    0   6.16 MBytes
# [  5]   7.00-8.00   sec   228 MBytes  1.91 Gbits/sec    0   6.16 MBytes
# [  5]   8.00-9.00   sec   230 MBytes  1.93 Gbits/sec    0   6.16 MBytes
# [  5]   9.00-10.00  sec   276 MBytes  2.32 Gbits/sec    0   6.16 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec  2.35 GBytes  2.02 Gbits/sec    1             sender
# [  5]   0.00-10.01  sec  2.35 GBytes  2.02 Gbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-1 to k8s-worker-7: 2.14 Gbits/sec
# Full output from bandwidth-measurement-ds-gnsh9 to bandwidth-measurement-ds-z4wqx:
# Connecting to host 192.168.79.113, port 5201
# [  5] local 192.168.230.8 port 54918 connected to 192.168.79.113 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec   226 MBytes  1.89 Gbits/sec    0   5.29 MBytes
# [  5]   1.00-2.00   sec   239 MBytes  2.00 Gbits/sec    0   5.29 MBytes
# [  5]   2.00-3.00   sec   239 MBytes  2.00 Gbits/sec    0   5.29 MBytes
# [  5]   3.00-4.00   sec   235 MBytes  1.97 Gbits/sec    0   5.29 MBytes
# [  5]   4.00-5.00   sec   241 MBytes  2.02 Gbits/sec    0   5.29 MBytes
# [  5]   5.00-6.00   sec   244 MBytes  2.04 Gbits/sec    0   5.29 MBytes
# [  5]   6.00-7.00   sec   241 MBytes  2.02 Gbits/sec    0   5.29 MBytes
# [  5]   7.00-8.00   sec   241 MBytes  2.02 Gbits/sec    0   5.29 MBytes
# [  5]   8.00-9.00   sec   235 MBytes  1.97 Gbits/sec    0   5.29 MBytes
# [  5]   9.00-10.00  sec   241 MBytes  2.02 Gbits/sec    0   5.29 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec  2.33 GBytes  2.00 Gbits/sec    0             sender
# [  5]   0.00-10.01  sec  2.33 GBytes  2.00 Gbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-1 to k8s-worker-4: 1.89 Gbits/sec
# Full output from bandwidth-measurement-ds-nrznp to bandwidth-measurement-ds-6dldb:
# Connecting to host 192.168.69.255, port 5201
# [  5] local 192.168.231.202 port 32946 connected to 192.168.69.255 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  86.4 MBytes   725 Mbits/sec    0   3.16 MBytes
# [  5]   1.00-2.00   sec  93.8 MBytes   786 Mbits/sec    0   3.16 MBytes
# [  5]   2.00-3.00   sec  93.8 MBytes   786 Mbits/sec    0   3.16 MBytes
# [  5]   3.00-4.00   sec  93.8 MBytes   786 Mbits/sec    0   3.16 MBytes
# [  5]   4.00-5.00   sec  93.8 MBytes   786 Mbits/sec    0   3.16 MBytes
# [  5]   5.00-6.00   sec  93.8 MBytes   786 Mbits/sec    0   3.16 MBytes
# [  5]   6.00-7.00   sec  93.8 MBytes   786 Mbits/sec    0   3.16 MBytes
# [  5]   7.00-8.00   sec  93.8 MBytes   786 Mbits/sec    0   3.16 MBytes
# [  5]   8.00-9.00   sec  93.8 MBytes   786 Mbits/sec    0   3.16 MBytes
# [  5]   9.00-10.00  sec  93.8 MBytes   786 Mbits/sec    0   3.16 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   930 MBytes   780 Mbits/sec    0             sender
# [  5]   0.00-10.03  sec   929 MBytes   777 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-8 to k8s-worker-3: 725 Mbits/sec
# Full output from bandwidth-measurement-ds-nrznp to bandwidth-measurement-ds-gnsh9:
# Connecting to host 192.168.230.8, port 5201
# [  5] local 192.168.231.202 port 55360 connected to 192.168.230.8 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  70.1 MBytes   588 Mbits/sec    0   3.95 MBytes
# [  5]   1.00-2.00   sec  87.5 MBytes   734 Mbits/sec    0   3.95 MBytes
# [  5]   2.00-3.00   sec  87.5 MBytes   734 Mbits/sec    0   3.95 MBytes
# [  5]   3.00-4.00   sec  86.2 MBytes   724 Mbits/sec    2   3.95 MBytes
# [  5]   4.00-5.00   sec  88.8 MBytes   744 Mbits/sec    0   3.95 MBytes
# [  5]   5.00-6.00   sec  87.5 MBytes   734 Mbits/sec    0   3.95 MBytes
# [  5]   6.00-7.00   sec  87.5 MBytes   734 Mbits/sec    0   3.95 MBytes
# [  5]   7.00-8.00   sec  87.5 MBytes   734 Mbits/sec    0   3.95 MBytes
# [  5]   8.00-9.00   sec  87.5 MBytes   734 Mbits/sec    0   3.95 MBytes
# [  5]   9.00-10.00  sec  87.5 MBytes   734 Mbits/sec    0   3.95 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   858 MBytes   719 Mbits/sec    2             sender
# [  5]   0.00-10.03  sec   858 MBytes   717 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-8 to k8s-worker-1: 588 Mbits/sec
# Full output from bandwidth-measurement-ds-nrznp to bandwidth-measurement-ds-p2vgl:
# Connecting to host 192.168.18.225, port 5201
# [  5] local 192.168.231.202 port 43868 connected to 192.168.18.225 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  88.8 MBytes   744 Mbits/sec    0   3.15 MBytes
# [  5]   1.00-2.00   sec  92.5 MBytes   776 Mbits/sec    0   3.15 MBytes
# [  5]   2.00-3.00   sec  93.8 MBytes   786 Mbits/sec    0   3.15 MBytes
# [  5]   3.00-4.00   sec  93.8 MBytes   786 Mbits/sec    0   3.15 MBytes
# [  5]   4.00-5.00   sec  93.8 MBytes   786 Mbits/sec    0   3.15 MBytes
# [  5]   5.00-6.00   sec  93.8 MBytes   786 Mbits/sec    0   3.15 MBytes
# [  5]   6.00-7.00   sec  92.5 MBytes   776 Mbits/sec    0   3.15 MBytes
# [  5]   7.00-8.00   sec  90.0 MBytes   755 Mbits/sec    0   3.15 MBytes
# [  5]   8.00-9.00   sec  93.8 MBytes   786 Mbits/sec    0   3.15 MBytes
# [  5]   9.00-10.00  sec  92.5 MBytes   776 Mbits/sec    0   3.15 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   925 MBytes   776 Mbits/sec    0             sender
# [  5]   0.00-10.03  sec   925 MBytes   774 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-8 to k8s-worker-5: 744 Mbits/sec
# Full output from bandwidth-measurement-ds-nrznp to bandwidth-measurement-ds-r7ftn:
# Connecting to host 192.168.251.72, port 5201
# [  5] local 192.168.231.202 port 55018 connected to 192.168.251.72 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  92.8 MBytes   778 Mbits/sec    0   3.16 MBytes
# [  5]   1.00-2.00   sec  92.5 MBytes   776 Mbits/sec    0   3.16 MBytes
# [  5]   2.00-3.00   sec  93.8 MBytes   786 Mbits/sec    0   3.16 MBytes
# [  5]   3.00-4.00   sec  93.8 MBytes   786 Mbits/sec    0   3.16 MBytes
# [  5]   4.00-5.00   sec  93.8 MBytes   786 Mbits/sec    0   3.16 MBytes
# [  5]   5.00-6.00   sec  92.5 MBytes   776 Mbits/sec    0   3.16 MBytes
# [  5]   6.00-7.00   sec  93.8 MBytes   786 Mbits/sec    0   3.16 MBytes
# [  5]   7.00-8.00   sec  88.8 MBytes   745 Mbits/sec    0   3.16 MBytes
# [  5]   8.00-9.00   sec  93.8 MBytes   786 Mbits/sec    0   3.16 MBytes
# [  5]   9.00-10.00  sec  93.8 MBytes   786 Mbits/sec    0   3.16 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   929 MBytes   779 Mbits/sec    0             sender
# [  5]   0.00-10.03  sec   929 MBytes   776 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-8 to k8s-worker-9: 778 Mbits/sec
# Full output from bandwidth-measurement-ds-nrznp to bandwidth-measurement-ds-rfvj2:
# Connecting to host 192.168.227.156, port 5201
# [  5] local 192.168.231.202 port 42580 connected to 192.168.227.156 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  90.2 MBytes   757 Mbits/sec    0   3.16 MBytes
# [  5]   1.00-2.00   sec  93.8 MBytes   786 Mbits/sec    0   3.16 MBytes
# [  5]   2.00-3.00   sec  93.8 MBytes   786 Mbits/sec    0   3.16 MBytes
# [  5]   3.00-4.00   sec  93.8 MBytes   786 Mbits/sec    0   3.16 MBytes
# [  5]   4.00-5.00   sec  92.5 MBytes   776 Mbits/sec    0   3.16 MBytes
# [  5]   5.00-6.00   sec  93.8 MBytes   786 Mbits/sec    0   3.16 MBytes
# [  5]   6.00-7.00   sec  92.5 MBytes   776 Mbits/sec    0   3.16 MBytes
# [  5]   7.00-8.00   sec  90.0 MBytes   755 Mbits/sec    0   3.16 MBytes
# [  5]   8.00-9.00   sec  93.8 MBytes   786 Mbits/sec    0   3.16 MBytes
# [  5]   9.00-10.00  sec  91.2 MBytes   765 Mbits/sec    0   3.16 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   925 MBytes   776 Mbits/sec    0             sender
# [  5]   0.00-10.03  sec   925 MBytes   773 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-8 to k8s-worker-6: 757 Mbits/sec
# Full output from bandwidth-measurement-ds-nrznp to bandwidth-measurement-ds-z29qn:
# Connecting to host 192.168.5.57, port 5201
# [  5] local 192.168.231.202 port 33988 connected to 192.168.5.57 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  85.2 MBytes   715 Mbits/sec    0   3.88 MBytes
# [  5]   1.00-2.00   sec  93.8 MBytes   786 Mbits/sec    0   3.88 MBytes
# [  5]   2.00-3.00   sec  93.8 MBytes   786 Mbits/sec    0   3.88 MBytes
# [  5]   3.00-4.00   sec  93.8 MBytes   786 Mbits/sec    0   3.88 MBytes
# [  5]   4.00-5.00   sec  92.5 MBytes   776 Mbits/sec    0   3.88 MBytes
# [  5]   5.00-6.00   sec  93.8 MBytes   786 Mbits/sec    0   3.88 MBytes
# [  5]   6.00-7.00   sec  92.5 MBytes   776 Mbits/sec    0   3.88 MBytes
# [  5]   7.00-8.00   sec  93.8 MBytes   786 Mbits/sec    0   3.88 MBytes
# [  5]   8.00-9.00   sec  92.5 MBytes   776 Mbits/sec    0   3.88 MBytes
# [  5]   9.00-10.00  sec  93.8 MBytes   786 Mbits/sec    0   3.88 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   925 MBytes   776 Mbits/sec    0             sender
# [  5]   0.00-10.03  sec   925 MBytes   773 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-8 to k8s-worker-7: 715 Mbits/sec
# Full output from bandwidth-measurement-ds-nrznp to bandwidth-measurement-ds-vf5qp:
# Connecting to host 192.168.140.14, port 5201
# [  5] local 192.168.231.202 port 44108 connected to 192.168.140.14 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  54.1 MBytes   454 Mbits/sec    0   3.83 MBytes
# [  5]   1.00-2.00   sec  72.5 MBytes   608 Mbits/sec    0   3.83 MBytes
# [  5]   2.00-3.00   sec  72.5 MBytes   608 Mbits/sec    0   3.83 MBytes
# [  5]   3.00-4.00   sec  72.5 MBytes   608 Mbits/sec    0   3.83 MBytes
# [  5]   4.00-5.00   sec  71.2 MBytes   598 Mbits/sec    0   3.83 MBytes
# [  5]   5.00-6.00   sec  72.5 MBytes   608 Mbits/sec    0   3.83 MBytes
# [  5]   6.00-7.00   sec  71.2 MBytes   598 Mbits/sec    0   3.83 MBytes
# [  5]   7.00-8.00   sec  72.5 MBytes   608 Mbits/sec    0   3.83 MBytes
# [  5]   8.00-9.00   sec  72.5 MBytes   608 Mbits/sec    0   3.83 MBytes
# [  5]   9.00-10.00  sec  72.5 MBytes   608 Mbits/sec    0   3.83 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   704 MBytes   591 Mbits/sec    0             sender
# [  5]   0.00-10.04  sec   703 MBytes   587 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-8 to k8s-worker-2: 454 Mbits/sec
# Full output from bandwidth-measurement-ds-nrznp to bandwidth-measurement-ds-z4wqx:
# Connecting to host 192.168.79.113, port 5201
# [  5] local 192.168.231.202 port 52222 connected to 192.168.79.113 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  83.8 MBytes   702 Mbits/sec    0   3.87 MBytes
# [  5]   1.00-2.00   sec  93.8 MBytes   786 Mbits/sec    0   3.87 MBytes
# [  5]   2.00-3.00   sec  93.8 MBytes   786 Mbits/sec    0   3.87 MBytes
# [  5]   3.00-4.00   sec  92.5 MBytes   776 Mbits/sec    0   3.87 MBytes
# [  5]   4.00-5.00   sec  93.8 MBytes   786 Mbits/sec    0   3.87 MBytes
# [  5]   5.00-6.00   sec  93.8 MBytes   786 Mbits/sec    0   3.87 MBytes
# [  5]   6.00-7.00   sec  92.5 MBytes   776 Mbits/sec    0   3.87 MBytes
# [  5]   7.00-8.00   sec  93.8 MBytes   786 Mbits/sec    0   3.87 MBytes
# [  5]   8.00-9.00   sec  92.5 MBytes   776 Mbits/sec    0   3.87 MBytes
# [  5]   9.00-10.00  sec  93.8 MBytes   786 Mbits/sec    0   3.87 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   924 MBytes   775 Mbits/sec    0             sender
# [  5]   0.00-10.03  sec   923 MBytes   772 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-8 to k8s-worker-4: 702 Mbits/sec
# Full output from bandwidth-measurement-ds-p2vgl to bandwidth-measurement-ds-6dldb:
# Connecting to host 192.168.69.255, port 5201
# [  5] local 192.168.18.225 port 40498 connected to 192.168.69.255 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  94.8 MBytes   795 Mbits/sec    0   3.15 MBytes
# [  5]   1.00-2.00   sec  92.5 MBytes   776 Mbits/sec    0   3.15 MBytes
# [  5]   2.00-3.00   sec  93.8 MBytes   786 Mbits/sec    0   3.15 MBytes
# [  5]   3.00-4.00   sec  92.5 MBytes   776 Mbits/sec    0   3.15 MBytes
# [  5]   4.00-5.00   sec  93.8 MBytes   786 Mbits/sec    0   3.15 MBytes
# [  5]   5.00-6.00   sec  92.5 MBytes   776 Mbits/sec    0   3.15 MBytes
# [  5]   6.00-7.00   sec  93.8 MBytes   786 Mbits/sec    0   3.15 MBytes
# [  5]   7.00-8.00   sec  93.8 MBytes   786 Mbits/sec    0   3.15 MBytes
# [  5]   8.00-9.00   sec  92.5 MBytes   776 Mbits/sec    0   3.15 MBytes
# [  5]   9.00-10.00  sec  93.8 MBytes   786 Mbits/sec    0   3.15 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   934 MBytes   783 Mbits/sec    0             sender
# [  5]   0.00-10.03  sec   933 MBytes   780 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-5 to k8s-worker-3: 795 Mbits/sec
# Full output from bandwidth-measurement-ds-p2vgl to bandwidth-measurement-ds-gnsh9:
# Connecting to host 192.168.230.8, port 5201
# [  5] local 192.168.18.225 port 54162 connected to 192.168.230.8 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  94.2 MBytes   790 Mbits/sec    0   3.14 MBytes
# [  5]   1.00-2.00   sec  92.5 MBytes   776 Mbits/sec    0   3.14 MBytes
# [  5]   2.00-3.00   sec  92.5 MBytes   776 Mbits/sec    0   3.14 MBytes
# [  5]   3.00-4.00   sec  93.8 MBytes   786 Mbits/sec    0   3.14 MBytes
# [  5]   4.00-5.00   sec  92.5 MBytes   776 Mbits/sec    0   3.14 MBytes
# [  5]   5.00-6.00   sec  93.8 MBytes   786 Mbits/sec    0   3.14 MBytes
# [  5]   6.00-7.00   sec  93.8 MBytes   786 Mbits/sec    0   3.14 MBytes
# [  5]   7.00-8.00   sec  93.8 MBytes   786 Mbits/sec    0   3.14 MBytes
# [  5]   8.00-9.00   sec  92.5 MBytes   776 Mbits/sec    0   3.14 MBytes
# [  5]   9.00-10.00  sec  93.8 MBytes   786 Mbits/sec    0   3.14 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   933 MBytes   783 Mbits/sec    0             sender
# [  5]   0.00-10.03  sec   932 MBytes   780 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-5 to k8s-worker-1: 790 Mbits/sec
# Full output from bandwidth-measurement-ds-p2vgl to bandwidth-measurement-ds-nrznp:
# Connecting to host 192.168.231.202, port 5201
# [  5] local 192.168.18.225 port 55170 connected to 192.168.231.202 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  88.9 MBytes   745 Mbits/sec    0   3.17 MBytes
# [  5]   1.00-2.00   sec  92.5 MBytes   776 Mbits/sec    0   3.17 MBytes
# [  5]   2.00-3.00   sec  92.5 MBytes   776 Mbits/sec    0   3.17 MBytes
# [  5]   3.00-4.00   sec  93.8 MBytes   787 Mbits/sec    0   3.17 MBytes
# [  5]   4.00-5.00   sec  93.8 MBytes   786 Mbits/sec    0   3.17 MBytes
# [  5]   5.00-6.00   sec  92.5 MBytes   776 Mbits/sec    0   3.17 MBytes
# [  5]   6.00-7.00   sec  93.8 MBytes   786 Mbits/sec    0   3.17 MBytes
# [  5]   7.00-8.00   sec  93.8 MBytes   786 Mbits/sec    1   3.17 MBytes
# [  5]   8.00-9.00   sec  92.5 MBytes   776 Mbits/sec    0   3.17 MBytes
# [  5]   9.00-10.00  sec  93.8 MBytes   786 Mbits/sec    0   3.17 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   928 MBytes   778 Mbits/sec    1             sender
# [  5]   0.00-10.03  sec   927 MBytes   775 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-5 to k8s-worker-8: 745 Mbits/sec
# Full output from bandwidth-measurement-ds-p2vgl to bandwidth-measurement-ds-r7ftn:
# Connecting to host 192.168.251.72, port 5201
# [  5] local 192.168.18.225 port 58830 connected to 192.168.251.72 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  85.1 MBytes   714 Mbits/sec    0   3.13 MBytes
# [  5]   1.00-2.00   sec  92.5 MBytes   776 Mbits/sec    0   3.13 MBytes
# [  5]   2.00-3.00   sec  93.8 MBytes   786 Mbits/sec    0   3.13 MBytes
# [  5]   3.00-4.00   sec  92.5 MBytes   776 Mbits/sec    0   3.13 MBytes
# [  5]   4.00-5.00   sec  92.5 MBytes   776 Mbits/sec    0   3.13 MBytes
# [  5]   5.00-6.00   sec  93.8 MBytes   786 Mbits/sec    0   3.13 MBytes
# [  5]   6.00-7.00   sec  92.5 MBytes   776 Mbits/sec    0   3.13 MBytes
# [  5]   7.00-8.00   sec  93.8 MBytes   786 Mbits/sec    0   3.13 MBytes
# [  5]   8.00-9.00   sec  92.5 MBytes   776 Mbits/sec    0   3.13 MBytes
# [  5]   9.00-10.00  sec  93.8 MBytes   786 Mbits/sec    0   3.13 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   923 MBytes   774 Mbits/sec    0             sender
# [  5]   0.00-10.03  sec   922 MBytes   771 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-5 to k8s-worker-9: 714 Mbits/sec
# Full output from bandwidth-measurement-ds-p2vgl to bandwidth-measurement-ds-rfvj2:
# Connecting to host 192.168.227.156, port 5201
# [  5] local 192.168.18.225 port 49118 connected to 192.168.227.156 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  91.6 MBytes   769 Mbits/sec    0   3.15 MBytes
# [  5]   1.00-2.00   sec  92.5 MBytes   776 Mbits/sec    0   3.15 MBytes
# [  5]   2.00-3.00   sec  92.5 MBytes   776 Mbits/sec    0   3.15 MBytes
# [  5]   3.00-4.00   sec  92.5 MBytes   776 Mbits/sec    0   3.15 MBytes
# [  5]   4.00-5.00   sec  93.8 MBytes   786 Mbits/sec    0   3.15 MBytes
# [  5]   5.00-6.00   sec  93.8 MBytes   786 Mbits/sec    0   3.15 MBytes
# [  5]   6.00-7.00   sec  92.5 MBytes   776 Mbits/sec    0   3.15 MBytes
# [  5]   7.00-8.00   sec  93.8 MBytes   786 Mbits/sec    0   3.15 MBytes
# [  5]   8.00-9.00   sec  92.5 MBytes   776 Mbits/sec    0   3.15 MBytes
# [  5]   9.00-10.00  sec  92.5 MBytes   776 Mbits/sec    0   3.15 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   928 MBytes   778 Mbits/sec    0             sender
# [  5]   0.00-10.03  sec   928 MBytes   776 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-5 to k8s-worker-6: 769 Mbits/sec
# Full output from bandwidth-measurement-ds-p2vgl to bandwidth-measurement-ds-vf5qp:
# Connecting to host 192.168.140.14, port 5201
# [  5] local 192.168.18.225 port 44008 connected to 192.168.140.14 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  90.9 MBytes   762 Mbits/sec    0   3.14 MBytes
# [  5]   1.00-2.00   sec  93.8 MBytes   786 Mbits/sec    0   3.14 MBytes
# [  5]   2.00-3.00   sec  92.5 MBytes   776 Mbits/sec    0   3.14 MBytes
# [  5]   3.00-4.00   sec  92.5 MBytes   776 Mbits/sec    0   3.14 MBytes
# [  5]   4.00-5.00   sec  93.8 MBytes   786 Mbits/sec    0   3.14 MBytes
# [  5]   5.00-6.00   sec  92.5 MBytes   776 Mbits/sec    0   3.14 MBytes
# [  5]   6.00-7.00   sec  93.8 MBytes   786 Mbits/sec    0   3.14 MBytes
# [  5]   7.00-8.00   sec  93.8 MBytes   786 Mbits/sec    0   3.14 MBytes
# [  5]   8.00-9.00   sec  92.5 MBytes   776 Mbits/sec    0   3.14 MBytes
# [  5]   9.00-10.00  sec  93.8 MBytes   786 Mbits/sec    0   3.14 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   930 MBytes   780 Mbits/sec    0             sender
# [  5]   0.00-10.03  sec   929 MBytes   777 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-5 to k8s-worker-2: 762 Mbits/sec
# Full output from bandwidth-measurement-ds-p2vgl to bandwidth-measurement-ds-z29qn:
# Connecting to host 192.168.5.57, port 5201
# [  5] local 192.168.18.225 port 35458 connected to 192.168.5.57 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  90.0 MBytes   755 Mbits/sec    0   3.15 MBytes
# [  5]   1.00-2.00   sec  93.8 MBytes   786 Mbits/sec    0   3.15 MBytes
# [  5]   2.00-3.00   sec  93.8 MBytes   786 Mbits/sec    0   3.15 MBytes
# [  5]   3.00-4.00   sec  93.8 MBytes   786 Mbits/sec    0   3.15 MBytes
# [  5]   4.00-5.00   sec  93.8 MBytes   785 Mbits/sec    0   3.15 MBytes
# [  5]   5.00-6.00   sec  92.5 MBytes   777 Mbits/sec    0   3.15 MBytes
# [  5]   6.00-7.00   sec  93.8 MBytes   786 Mbits/sec    0   3.15 MBytes
# [  5]   7.00-8.00   sec  92.5 MBytes   776 Mbits/sec    0   3.15 MBytes
# [  5]   8.00-9.00   sec  93.8 MBytes   786 Mbits/sec    0   3.15 MBytes
# [  5]   9.00-10.00  sec  93.8 MBytes   786 Mbits/sec    0   3.15 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   931 MBytes   781 Mbits/sec    0             sender
# [  5]   0.00-10.03  sec   931 MBytes   779 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-5 to k8s-worker-7: 755 Mbits/sec
# Full output from bandwidth-measurement-ds-p2vgl to bandwidth-measurement-ds-z4wqx:
# Connecting to host 192.168.79.113, port 5201
# [  5] local 192.168.18.225 port 42252 connected to 192.168.79.113 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  93.2 MBytes   782 Mbits/sec    0   3.14 MBytes
# [  5]   1.00-2.00   sec  93.8 MBytes   786 Mbits/sec    0   3.14 MBytes
# [  5]   2.00-3.00   sec  93.8 MBytes   786 Mbits/sec    0   3.14 MBytes
# [  5]   3.00-4.00   sec  93.8 MBytes   786 Mbits/sec    0   3.14 MBytes
# [  5]   4.00-5.00   sec  93.8 MBytes   786 Mbits/sec    0   3.14 MBytes
# [  5]   5.00-6.00   sec  93.8 MBytes   786 Mbits/sec    0   3.14 MBytes
# [  5]   6.00-7.00   sec  92.5 MBytes   776 Mbits/sec    0   3.14 MBytes
# [  5]   7.00-8.00   sec  93.8 MBytes   786 Mbits/sec    0   3.14 MBytes
# [  5]   8.00-9.00   sec  93.8 MBytes   786 Mbits/sec    0   3.14 MBytes
# [  5]   9.00-10.00  sec  93.8 MBytes   786 Mbits/sec    0   3.14 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   936 MBytes   785 Mbits/sec    0             sender
# [  5]   0.00-10.03  sec   936 MBytes   782 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-5 to k8s-worker-4: 782 Mbits/sec
# Full output from bandwidth-measurement-ds-r7ftn to bandwidth-measurement-ds-6dldb:
# Connecting to host 192.168.69.255, port 5201
# [  5] local 192.168.251.72 port 45678 connected to 192.168.69.255 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  95.5 MBytes   801 Mbits/sec    0   3.15 MBytes
# [  5]   1.00-2.00   sec  95.0 MBytes   797 Mbits/sec    0   3.15 MBytes
# [  5]   2.00-3.00   sec  93.8 MBytes   787 Mbits/sec    0   3.15 MBytes
# [  5]   3.00-4.00   sec  93.8 MBytes   786 Mbits/sec    0   3.15 MBytes
# [  5]   4.00-5.00   sec  93.8 MBytes   786 Mbits/sec    0   3.15 MBytes
# [  5]   5.00-6.00   sec  93.8 MBytes   786 Mbits/sec    0   3.15 MBytes
# [  5]   6.00-7.00   sec  93.8 MBytes   786 Mbits/sec    0   3.15 MBytes
# [  5]   7.00-8.00   sec  93.8 MBytes   786 Mbits/sec    0   3.15 MBytes
# [  5]   8.00-9.00   sec  93.8 MBytes   786 Mbits/sec    0   3.15 MBytes
# [  5]   9.00-10.00  sec  93.8 MBytes   786 Mbits/sec    0   3.15 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   940 MBytes   789 Mbits/sec    0             sender
# [  5]   0.00-10.03  sec   940 MBytes   786 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-9 to k8s-worker-3: 801 Mbits/sec
# Full output from bandwidth-measurement-ds-r7ftn to bandwidth-measurement-ds-gnsh9:
# Connecting to host 192.168.230.8, port 5201
# [  5] local 192.168.251.72 port 38740 connected to 192.168.230.8 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  95.9 MBytes   804 Mbits/sec    0   3.15 MBytes
# [  5]   1.00-2.00   sec  92.5 MBytes   776 Mbits/sec    0   3.15 MBytes
# [  5]   2.00-3.00   sec  93.8 MBytes   786 Mbits/sec    0   3.15 MBytes
# [  5]   3.00-4.00   sec  93.8 MBytes   786 Mbits/sec    0   3.15 MBytes
# [  5]   4.00-5.00   sec  93.8 MBytes   786 Mbits/sec    0   3.15 MBytes
# [  5]   5.00-6.00   sec  92.5 MBytes   776 Mbits/sec    0   3.15 MBytes
# [  5]   6.00-7.00   sec  93.8 MBytes   786 Mbits/sec    0   3.15 MBytes
# [  5]   7.00-8.00   sec  93.8 MBytes   786 Mbits/sec    0   3.15 MBytes
# [  5]   8.00-9.00   sec  93.8 MBytes   786 Mbits/sec    0   3.15 MBytes
# [  5]   9.00-10.00  sec  93.8 MBytes   786 Mbits/sec    0   3.15 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   937 MBytes   786 Mbits/sec    0             sender
# [  5]   0.00-10.03  sec   937 MBytes   783 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-9 to k8s-worker-1: 804 Mbits/sec
# Full output from bandwidth-measurement-ds-r7ftn to bandwidth-measurement-ds-nrznp:
# Connecting to host 192.168.231.202, port 5201
# [  5] local 192.168.251.72 port 41178 connected to 192.168.231.202 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  92.9 MBytes   779 Mbits/sec    0   3.14 MBytes
# [  5]   1.00-2.00   sec  82.5 MBytes   692 Mbits/sec    0   3.14 MBytes
# ...
# [  5]   4.00-5.00   sec  92.5 MBytes   776 Mbits/sec    0   3.82 MBytes
# [  5]   5.00-6.00   sec  93.8 MBytes   786 Mbits/sec    0   3.82 MBytes
# [  5]   6.00-7.00   sec  93.8 MBytes   786 Mbits/sec    0   3.82 MBytes
# [  5]   7.00-8.00   sec  92.5 MBytes   776 Mbits/sec    0   3.82 MBytes
# [  5]   8.00-9.00   sec  91.2 MBytes   765 Mbits/sec    0   3.82 MBytes
# [  5]   9.00-10.00  sec  93.8 MBytes   786 Mbits/sec    0   3.82 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   921 MBytes   773 Mbits/sec    0             sender
# [  5]   0.00-10.03  sec   921 MBytes   770 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-7 to k8s-worker-2: 722 Mbits/sec
# Full output from bandwidth-measurement-ds-z29qn to bandwidth-measurement-ds-z4wqx:
# Connecting to host 192.168.79.113, port 5201
# [  5] local 192.168.5.57 port 48642 connected to 192.168.79.113 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  87.5 MBytes   734 Mbits/sec    0   3.83 MBytes
# [  5]   1.00-2.00   sec  93.8 MBytes   786 Mbits/sec    0   3.83 MBytes
# [  5]   2.00-3.00   sec  93.8 MBytes   786 Mbits/sec    0   3.83 MBytes
# [  5]   3.00-4.00   sec  93.8 MBytes   786 Mbits/sec    0   3.83 MBytes
# [  5]   4.00-5.00   sec  95.0 MBytes   797 Mbits/sec    0   3.83 MBytes
# [  5]   5.00-6.00   sec  93.8 MBytes   786 Mbits/sec    0   3.83 MBytes
# [  5]   6.00-7.00   sec  93.8 MBytes   787 Mbits/sec    0   3.83 MBytes
# [  5]   7.00-8.00   sec  93.8 MBytes   786 Mbits/sec    0   3.83 MBytes
# [  5]   8.00-9.00   sec  93.8 MBytes   786 Mbits/sec    0   3.83 MBytes
# [  5]   9.00-10.00  sec  93.8 MBytes   786 Mbits/sec    0   3.83 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   932 MBytes   782 Mbits/sec    0             sender
# [  5]   0.00-10.03  sec   932 MBytes   779 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-7 to k8s-worker-4: 734 Mbits/sec
# Full output from bandwidth-measurement-ds-z4wqx to bandwidth-measurement-ds-6dldb:
# Connecting to host 192.168.69.255, port 5201
# [  5] local 192.168.79.113 port 58830 connected to 192.168.69.255 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  95.1 MBytes   798 Mbits/sec    0   3.16 MBytes
# [  5]   1.00-2.00   sec  92.5 MBytes   775 Mbits/sec    0   3.16 MBytes
# [  5]   2.00-3.00   sec  91.2 MBytes   767 Mbits/sec    0   3.16 MBytes
# [  5]   3.00-4.00   sec  91.2 MBytes   765 Mbits/sec    0   3.16 MBytes
# [  5]   4.00-5.00   sec  92.5 MBytes   776 Mbits/sec    0   3.16 MBytes
# [  5]   5.00-6.00   sec  90.0 MBytes   755 Mbits/sec    0   3.16 MBytes
# [  5]   6.00-7.00   sec  91.2 MBytes   765 Mbits/sec    0   3.16 MBytes
# [  5]   7.00-8.00   sec  92.5 MBytes   776 Mbits/sec    0   3.16 MBytes
# [  5]   8.00-9.00   sec  92.5 MBytes   776 Mbits/sec    0   3.16 MBytes
# [  5]   9.00-10.00  sec  92.5 MBytes   776 Mbits/sec    0   3.16 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   921 MBytes   773 Mbits/sec    0             sender
# [  5]   0.00-10.03  sec   921 MBytes   770 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-4 to k8s-worker-3: 798 Mbits/sec
# Full output from bandwidth-measurement-ds-z4wqx to bandwidth-measurement-ds-gnsh9:
# Connecting to host 192.168.230.8, port 5201
# [  5] local 192.168.79.113 port 54112 connected to 192.168.230.8 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  89.9 MBytes   754 Mbits/sec    0   3.15 MBytes
# [  5]   1.00-2.00   sec  91.2 MBytes   765 Mbits/sec    0   3.15 MBytes
# [  5]   2.00-3.00   sec  92.5 MBytes   776 Mbits/sec    0   3.15 MBytes
# [  5]   3.00-4.00   sec  91.2 MBytes   765 Mbits/sec    0   3.15 MBytes
# [  5]   4.00-5.00   sec  91.2 MBytes   765 Mbits/sec    0   3.15 MBytes
# [  5]   5.00-6.00   sec  91.2 MBytes   765 Mbits/sec    0   3.15 MBytes
# [  5]   6.00-7.00   sec  91.2 MBytes   765 Mbits/sec    0   3.15 MBytes
# [  5]   7.00-8.00   sec  92.5 MBytes   776 Mbits/sec    0   3.15 MBytes
# [  5]   8.00-9.00   sec  92.5 MBytes   776 Mbits/sec    0   3.15 MBytes
# [  5]   9.00-10.00  sec  92.5 MBytes   776 Mbits/sec    0   3.15 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   916 MBytes   768 Mbits/sec    0             sender
# [  5]   0.00-10.03  sec   916 MBytes   766 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-4 to k8s-worker-1: 754 Mbits/sec
# Full output from bandwidth-measurement-ds-z4wqx to bandwidth-measurement-ds-p2vgl:
# Connecting to host 192.168.18.225, port 5201
# [  5] local 192.168.79.113 port 50752 connected to 192.168.18.225 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  92.6 MBytes   777 Mbits/sec    0   3.14 MBytes
# [  5]   1.00-2.00   sec  93.8 MBytes   786 Mbits/sec    0   3.14 MBytes
# [  5]   2.00-3.00   sec  93.8 MBytes   786 Mbits/sec    0   3.14 MBytes
# [  5]   3.00-4.00   sec  93.8 MBytes   786 Mbits/sec    0   3.14 MBytes
# [  5]   4.00-5.00   sec  92.5 MBytes   776 Mbits/sec    0   3.14 MBytes
# [  5]   5.00-6.00   sec  93.8 MBytes   786 Mbits/sec    0   3.14 MBytes
# [  5]   6.00-7.00   sec  93.8 MBytes   787 Mbits/sec    0   3.14 MBytes
# [  5]   7.00-8.00   sec  92.5 MBytes   776 Mbits/sec    0   3.14 MBytes
# [  5]   8.00-9.00   sec  93.8 MBytes   786 Mbits/sec    0   3.14 MBytes
# [  5]   9.00-10.00  sec  93.8 MBytes   786 Mbits/sec    0   3.14 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   934 MBytes   783 Mbits/sec    0             sender
# [  5]   0.00-10.03  sec   934 MBytes   781 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-4 to k8s-worker-5: 777 Mbits/sec
# Full output from bandwidth-measurement-ds-z4wqx to bandwidth-measurement-ds-nrznp:
# Connecting to host 192.168.231.202, port 5201
# [  5] local 192.168.79.113 port 37970 connected to 192.168.231.202 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  82.1 MBytes   689 Mbits/sec    0   4.10 MBytes
# [  5]   1.00-2.00   sec  93.8 MBytes   786 Mbits/sec    0   4.10 MBytes
# [  5]   2.00-3.00   sec  93.8 MBytes   786 Mbits/sec    0   4.10 MBytes
# [  5]   3.00-4.00   sec  93.8 MBytes   786 Mbits/sec    0   4.10 MBytes
# [  5]   4.00-5.00   sec  92.5 MBytes   776 Mbits/sec    0   4.10 MBytes
# [  5]   5.00-6.00   sec  93.8 MBytes   786 Mbits/sec    0   4.10 MBytes
# [  5]   6.00-7.00   sec  92.5 MBytes   776 Mbits/sec    0   4.10 MBytes
# [  5]   7.00-8.00   sec  93.8 MBytes   786 Mbits/sec    0   4.10 MBytes
# [  5]   8.00-9.00   sec  93.8 MBytes   786 Mbits/sec    0   4.10 MBytes
# [  5]   9.00-10.00  sec  93.8 MBytes   786 Mbits/sec    0   4.10 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   923 MBytes   775 Mbits/sec    0             sender
# [  5]   0.00-10.03  sec   923 MBytes   772 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-4 to k8s-worker-8: 689 Mbits/sec
# Full output from bandwidth-measurement-ds-z4wqx to bandwidth-measurement-ds-r7ftn:
# Connecting to host 192.168.251.72, port 5201
# [  5] local 192.168.79.113 port 49870 connected to 192.168.251.72 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  87.9 MBytes   737 Mbits/sec    0   3.84 MBytes
# [  5]   1.00-2.00   sec  92.5 MBytes   776 Mbits/sec    0   3.84 MBytes
# [  5]   2.00-3.00   sec  93.8 MBytes   786 Mbits/sec    0   3.84 MBytes
# [  5]   3.00-4.00   sec  93.8 MBytes   786 Mbits/sec    0   3.84 MBytes
# [  5]   4.00-5.00   sec  92.5 MBytes   776 Mbits/sec    0   3.84 MBytes
# [  5]   5.00-6.00   sec  93.8 MBytes   786 Mbits/sec    0   3.84 MBytes
# [  5]   6.00-7.00   sec  92.5 MBytes   776 Mbits/sec    1   3.84 MBytes
# [  5]   7.00-8.00   sec  93.8 MBytes   786 Mbits/sec    0   3.84 MBytes
# [  5]   8.00-9.00   sec  93.8 MBytes   786 Mbits/sec    0   3.84 MBytes
# [  5]   9.00-10.00  sec  93.8 MBytes   786 Mbits/sec    0   3.84 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   928 MBytes   778 Mbits/sec    1             sender
# [  5]   0.00-10.03  sec   928 MBytes   776 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-4 to k8s-worker-9: 737 Mbits/sec
# Full output from bandwidth-measurement-ds-z4wqx to bandwidth-measurement-ds-rfvj2:
# Connecting to host 192.168.227.156, port 5201
# [  5] local 192.168.79.113 port 48714 connected to 192.168.227.156 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  85.2 MBytes   715 Mbits/sec    0   3.82 MBytes
# [  5]   1.00-2.00   sec  93.8 MBytes   786 Mbits/sec    0   3.82 MBytes
# [  5]   2.00-3.00   sec  93.8 MBytes   786 Mbits/sec    0   3.82 MBytes
# [  5]   3.00-4.00   sec  93.8 MBytes   786 Mbits/sec    0   3.82 MBytes
# [  5]   4.00-5.00   sec  92.5 MBytes   776 Mbits/sec    0   3.82 MBytes
# [  5]   5.00-6.00   sec  93.8 MBytes   786 Mbits/sec    0   3.82 MBytes
# [  5]   6.00-7.00   sec  93.8 MBytes   786 Mbits/sec    0   3.82 MBytes
# [  5]   7.00-8.00   sec  93.8 MBytes   786 Mbits/sec    0   3.82 MBytes
# [  5]   8.00-9.00   sec  93.8 MBytes   786 Mbits/sec    0   3.82 MBytes
# [  5]   9.00-10.00  sec  93.8 MBytes   786 Mbits/sec    0   3.82 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   928 MBytes   778 Mbits/sec    0             sender
# [  5]   0.00-10.03  sec   927 MBytes   775 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-4 to k8s-worker-6: 715 Mbits/sec
# Full output from bandwidth-measurement-ds-z4wqx to bandwidth-measurement-ds-vf5qp:
# Connecting to host 192.168.140.14, port 5201
# [  5] local 192.168.79.113 port 36300 connected to 192.168.140.14 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  89.9 MBytes   754 Mbits/sec    0   3.17 MBytes
# [  5]   1.00-2.00   sec  93.8 MBytes   786 Mbits/sec    0   3.17 MBytes
# [  5]   2.00-3.00   sec  93.8 MBytes   786 Mbits/sec    0   3.17 MBytes
# [  5]   3.00-4.00   sec  93.8 MBytes   786 Mbits/sec    0   3.17 MBytes
# [  5]   4.00-5.00   sec  92.5 MBytes   776 Mbits/sec    0   3.17 MBytes
# [  5]   5.00-6.00   sec  93.8 MBytes   786 Mbits/sec    0   3.17 MBytes
# [  5]   6.00-7.00   sec  93.8 MBytes   786 Mbits/sec    0   3.17 MBytes
# [  5]   7.00-8.00   sec  93.8 MBytes   786 Mbits/sec    0   3.17 MBytes
# [  5]   8.00-9.00   sec  93.8 MBytes   786 Mbits/sec    0   3.17 MBytes
# [  5]   9.00-10.00  sec  93.8 MBytes   786 Mbits/sec    0   3.17 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   932 MBytes   782 Mbits/sec    0             sender
# [  5]   0.00-10.03  sec   932 MBytes   779 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-4 to k8s-worker-2: 754 Mbits/sec
# Full output from bandwidth-measurement-ds-z4wqx to bandwidth-measurement-ds-z29qn:
# Connecting to host 192.168.5.57, port 5201
# [  5] local 192.168.79.113 port 46030 connected to 192.168.5.57 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  87.5 MBytes   734 Mbits/sec    0   3.60 MBytes
# [  5]   1.00-2.00   sec  93.8 MBytes   786 Mbits/sec    0   3.60 MBytes
# [  5]   2.00-3.00   sec  93.8 MBytes   787 Mbits/sec    0   3.60 MBytes
# [  5]   3.00-4.00   sec  92.5 MBytes   776 Mbits/sec    0   3.60 MBytes
# [  5]   4.00-5.00   sec  93.8 MBytes   786 Mbits/sec    0   3.60 MBytes
# [  5]   5.00-6.00   sec  93.8 MBytes   786 Mbits/sec    0   3.60 MBytes
# [  5]   6.00-7.00   sec  93.8 MBytes   786 Mbits/sec    0   3.60 MBytes
# [  5]   7.00-8.00   sec  93.8 MBytes   786 Mbits/sec    0   3.60 MBytes
# [  5]   8.00-9.00   sec  92.5 MBytes   776 Mbits/sec    0   3.60 MBytes
# [  5]   9.00-10.00  sec  93.8 MBytes   786 Mbits/sec    0   3.60 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   929 MBytes   779 Mbits/sec    0             sender
# [  5]   0.00-10.03  sec   929 MBytes   777 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-4 to k8s-worker-7: 734 Mbits/sec
# {'k8s-worker-3': {'k8s-worker-1': '1.22 Gbits/sec', 'k8s-worker-5': '1.86 Gbits/sec', 'k8s-worker-8': '359 Mbits/sec', 'k8s-worker-9': '2.04 Gbits/sec', 'k8s-worker-2': '1.24 Gbits/sec', 'k8s-worker-6': '574 Mbits/sec', 'k8s-worker-7': '1.52 Gbits/sec', 'k8s-worker-4': '1.13 Gbits/sec'}, 'k8s-worker-1': {'k8s-worker-3': '2.41 Gbits/sec', 'k8s-worker-8': '601 Mbits/sec', 'k8s-worker-5': '2.47 Gbits/sec', 'k8s-worker-9': '2.76 Gbits/sec', 'k8s-worker-2': '2.49 Gbits/sec', 'k8s-worker-6': '1.13 Gbits/sec', 'k8s-worker-7': '2.14 Gbits/sec', 'k8s-worker-4': '1.89 Gbits/sec'}, 'k8s-worker-8': {'k8s-worker-3': '725 Mbits/sec', 'k8s-worker-1': '588 Mbits/sec', 'k8s-worker-5': '744 Mbits/sec', 'k8s-worker-9': '778 Mbits/sec', 'k8s-worker-6': '757 Mbits/sec', 'k8s-worker-7': '715 Mbits/sec', 'k8s-worker-2': '454 Mbits/sec', 'k8s-worker-4': '702 Mbits/sec'}, 'k8s-worker-5': {'k8s-worker-3': '795 Mbits/sec', 'k8s-worker-1': '790 Mbits/sec', 'k8s-worker-8': '745 Mbits/sec', 'k8s-worker-9': '714 Mbits/sec', 'k8s-worker-6': '769 Mbits/sec', 'k8s-worker-2': '762 Mbits/sec', 'k8s-worker-7': '755 Mbits/sec', 'k8s-worker-4': '782 Mbits/sec'}, 'k8s-worker-9': {'k8s-worker-3': '801 Mbits/sec', 'k8s-worker-1': '804 Mbits/sec', 'k8s-worker-8': '779 Mbits/sec', 'k8s-worker-5': '706 Mbits/sec', 'k8s-worker-6': '732 Mbits/sec', 'k8s-worker-2': '758 Mbits/sec', 'k8s-worker-7': '767 Mbits/sec', 'k8s-worker-4': '734 Mbits/sec'}, 'k8s-worker-6': {'k8s-worker-3': '781 Mbits/sec', 'k8s-worker-1': '781 Mbits/sec', 'k8s-worker-8': '768 Mbits/sec', 'k8s-worker-5': '770 Mbits/sec', 'k8s-worker-9': '740 Mbits/sec', 'k8s-worker-7': '746 Mbits/sec', 'k8s-worker-2': '674 Mbits/sec', 'k8s-worker-4': '702 Mbits/sec'}, 'k8s-worker-2': {'k8s-worker-3': '766 Mbits/sec', 'k8s-worker-1': '795 Mbits/sec', 'k8s-worker-8': '479 Mbits/sec', 'k8s-worker-5': '744 Mbits/sec', 'k8s-worker-9': '743 Mbits/sec', 'k8s-worker-6': '698 Mbits/sec', 'k8s-worker-4': '749 Mbits/sec', 'k8s-worker-7': '723 Mbits/sec'}, 'k8s-worker-7': {'k8s-worker-3': '794 Mbits/sec', 'k8s-worker-1': '784 Mbits/sec', 'k8s-worker-8': '710 Mbits/sec', 'k8s-worker-5': '756 Mbits/sec', 'k8s-worker-9': '758 Mbits/sec', 'k8s-worker-6': '756 Mbits/sec', 'k8s-worker-2': '722 Mbits/sec', 'k8s-worker-4': '734 Mbits/sec'}, 'k8s-worker-4': {'k8s-worker-3': '798 Mbits/sec', 'k8s-worker-1': '754 Mbits/sec', 'k8s-worker-5': '777 Mbits/sec', 'k8s-worker-8': '689 Mbits/sec', 'k8s-worker-9': '737 Mbits/sec', 'k8s-worker-6': '715 Mbits/sec', 'k8s-worker-2': '754 Mbits/sec', 'k8s-worker-7': '734 Mbits/sec'}}

# %%
import json
import os
import datetime

# Pretty-print the dictionary in JSON-like format:
pretty_str = json.dumps(bandwidth_results, indent=4)
directory_path = "/home/ubuntu/iDynamics/iDynamicsPackagesModules/NetworkingDynamicsManager/iBandwidth/Measurer_bandwidth/data/"

# Specify a filename (e.g., bandwidth_data.json)
# filename = "bandwidth_data.json"

now = datetime.datetime.now()
filename = f"bandwidth_results_{now.strftime('%Y-%m-%d_%H-%M')}.json"
file_path = os.path.join(directory_path, filename)


# Write the pretty-printed JSON to the specified file
with open(file_path, "w") as f:
    f.write(pretty_str)

print(f"JSON data saved to {file_path}")
# Out:
# JSON data saved to /home/ubuntu/iDynamics/iDynamicsPackagesModules/NetworkingDynamicsManager/iBandwidth/Measurer_bandwidth/data/bandwidth_results_2025-03-11_04-20.json

# %%
import pandas as pd

# Convert the nested dictionary into a pandas DataFrame
df = pd.DataFrame(bandwidth_results)

# Transpose the DataFrame to align the source and destination workers as per convention
df = df.T

# Fill diagonal with 0's for self-latency (optional, if desired for clarity)
for worker in df.columns:
    df.at[worker, worker] = 0

# Save the DataFrame to a CSV file, and add the date, hour and minute to the file name
import datetime
now = datetime.datetime.now()
filename = f"bandwidth_results_{now.strftime('%Y-%m-%d_%H-%M')}.csv"
df.to_csv("/home/ubuntu/iDynamics/iDynamicsPackagesModules/NetworkingDynamicsManager/iBandwidth/Measurer_bandwidth/data/"+filename)
df
# Out:
#                 k8s-worker-1    k8s-worker-5   k8s-worker-8    k8s-worker-9  \
# k8s-worker-3  1.22 Gbits/sec  1.86 Gbits/sec  359 Mbits/sec  2.04 Gbits/sec
# k8s-worker-1               0  2.47 Gbits/sec  601 Mbits/sec  2.76 Gbits/sec
# k8s-worker-8   588 Mbits/sec   744 Mbits/sec              0   778 Mbits/sec
# k8s-worker-5   790 Mbits/sec               0  745 Mbits/sec   714 Mbits/sec
# k8s-worker-9   804 Mbits/sec   706 Mbits/sec  779 Mbits/sec               0
# k8s-worker-6   781 Mbits/sec   770 Mbits/sec  768 Mbits/sec   740 Mbits/sec
# k8s-worker-2   795 Mbits/sec   744 Mbits/sec  479 Mbits/sec   743 Mbits/sec
# k8s-worker-7   784 Mbits/sec   756 Mbits/sec  710 Mbits/sec   758 Mbits/sec
# k8s-worker-4   754 Mbits/sec   777 Mbits/sec  689 Mbits/sec   737 Mbits/sec
#
#                 k8s-worker-2    k8s-worker-6    k8s-worker-7    k8s-worker-4  \
# k8s-worker-3  1.24 Gbits/sec   574 Mbits/sec  1.52 Gbits/sec  1.13 Gbits/sec
# k8s-worker-1  2.49 Gbits/sec  1.13 Gbits/sec  2.14 Gbits/sec  1.89 Gbits/sec
# k8s-worker-8   454 Mbits/sec   757 Mbits/sec   715 Mbits/sec   702 Mbits/sec
# k8s-worker-5   762 Mbits/sec   769 Mbits/sec   755 Mbits/sec   782 Mbits/sec
# k8s-worker-9   758 Mbits/sec   732 Mbits/sec   767 Mbits/sec   734 Mbits/sec
# k8s-worker-6   674 Mbits/sec               0   746 Mbits/sec   702 Mbits/sec
# k8s-worker-2               0   698 Mbits/sec   723 Mbits/sec   749 Mbits/sec
# k8s-worker-7   722 Mbits/sec   756 Mbits/sec               0   734 Mbits/sec
# k8s-worker-4   754 Mbits/sec   715 Mbits/sec   734 Mbits/sec               0
#
#                 k8s-worker-3
# k8s-worker-3               0
# k8s-worker-1  2.41 Gbits/sec
# k8s-worker-8   725 Mbits/sec
# k8s-worker-5   795 Mbits/sec
# k8s-worker-9   801 Mbits/sec
# k8s-worker-6   781 Mbits/sec
# k8s-worker-2   766 Mbits/sec
# k8s-worker-7   794 Mbits/sec
# k8s-worker-4   798 Mbits/sec

# %%
# Out:
# Bandwidth from k8s-worker-3 to k8s-worker-1: 806 Mbits/sec
# Bandwidth from k8s-worker-3 to k8s-worker-8: 801 Mbits/sec
# Bandwidth from k8s-worker-3 to k8s-worker-5: 814 Mbits/sec
# Bandwidth from k8s-worker-3 to k8s-worker-9: 813 Mbits/sec
# Bandwidth from k8s-worker-3 to k8s-worker-6: 813 Mbits/sec
# Bandwidth from k8s-worker-3 to k8s-worker-2: 805 Mbits/sec
# Bandwidth from k8s-worker-3 to k8s-worker-7: 815 Mbits/sec
# Bandwidth from k8s-worker-3 to k8s-worker-4: 806 Mbits/sec
# Bandwidth from k8s-worker-1 to k8s-worker-3: 806 Mbits/sec
# Bandwidth from k8s-worker-1 to k8s-worker-8: 819 Mbits/sec
# Bandwidth from k8s-worker-1 to k8s-worker-5: 814 Mbits/sec
# Bandwidth from k8s-worker-1 to k8s-worker-9: 819 Mbits/sec
# Bandwidth from k8s-worker-1 to k8s-worker-6: 807 Mbits/sec
# Bandwidth from k8s-worker-1 to k8s-worker-2: 813 Mbits/sec
# Bandwidth from k8s-worker-1 to k8s-worker-7: 813 Mbits/sec
# Bandwidth from k8s-worker-1 to k8s-worker-4: 810 Mbits/sec
# Bandwidth from k8s-worker-8 to k8s-worker-3: 794 Mbits/sec
# Bandwidth from k8s-worker-8 to k8s-worker-1: 813 Mbits/sec
# Bandwidth from k8s-worker-8 to k8s-worker-5: 802 Mbits/sec
# Bandwidth from k8s-worker-8 to k8s-worker-9: 801 Mbits/sec
# Bandwidth from k8s-worker-8 to k8s-worker-6: 796 Mbits/sec
# Bandwidth from k8s-worker-8 to k8s-worker-2: 794 Mbits/sec
# Bandwidth from k8s-worker-8 to k8s-worker-7: 762 Mbits/sec
# Bandwidth from k8s-worker-8 to k8s-worker-4: 800 Mbits/sec
# Bandwidth from k8s-worker-5 to k8s-worker-3: 803 Mbits/sec
# Bandwidth from k8s-worker-5 to k8s-worker-1: 806 Mbits/sec
# Bandwidth from k8s-worker-5 to k8s-worker-8: 799 Mbits/sec
# Bandwidth from k8s-worker-5 to k8s-worker-9: 806 Mbits/sec
# Bandwidth from k8s-worker-5 to k8s-worker-6: 806 Mbits/sec
# Bandwidth from k8s-worker-5 to k8s-worker-2: 801 Mbits/sec
# Bandwidth from k8s-worker-5 to k8s-worker-7: 805 Mbits/sec
# Bandwidth from k8s-worker-5 to k8s-worker-4: 799 Mbits/sec
# Bandwidth from k8s-worker-9 to k8s-worker-3: 801 Mbits/sec
# Bandwidth from k8s-worker-9 to k8s-worker-1: 813 Mbits/sec
# Bandwidth from k8s-worker-9 to k8s-worker-8: 813 Mbits/sec
# Bandwidth from k8s-worker-9 to k8s-worker-5: 802 Mbits/sec
# Bandwidth from k8s-worker-9 to k8s-worker-6: 810 Mbits/sec
# Bandwidth from k8s-worker-9 to k8s-worker-2: 814 Mbits/sec
# Bandwidth from k8s-worker-9 to k8s-worker-7: 800 Mbits/sec
# Bandwidth from k8s-worker-9 to k8s-worker-4: 797 Mbits/sec
# Bandwidth from k8s-worker-6 to k8s-worker-3: 806 Mbits/sec
# Bandwidth from k8s-worker-6 to k8s-worker-1: 804 Mbits/sec
# Bandwidth from k8s-worker-6 to k8s-worker-8: 808 Mbits/sec
# Bandwidth from k8s-worker-6 to k8s-worker-5: 808 Mbits/sec
# Bandwidth from k8s-worker-6 to k8s-worker-9: 804 Mbits/sec
# Bandwidth from k8s-worker-6 to k8s-worker-2: 802 Mbits/sec
# Bandwidth from k8s-worker-6 to k8s-worker-7: 813 Mbits/sec
# Bandwidth from k8s-worker-6 to k8s-worker-4: 813 Mbits/sec
# Bandwidth from k8s-worker-2 to k8s-worker-3: 816 Mbits/sec
# Bandwidth from k8s-worker-2 to k8s-worker-1: 810 Mbits/sec
# Bandwidth from k8s-worker-2 to k8s-worker-8: 815 Mbits/sec
# Bandwidth from k8s-worker-2 to k8s-worker-5: 811 Mbits/sec
# Bandwidth from k8s-worker-2 to k8s-worker-9: 813 Mbits/sec
# Bandwidth from k8s-worker-2 to k8s-worker-6: 813 Mbits/sec
# Bandwidth from k8s-worker-2 to k8s-worker-7: 813 Mbits/sec
# Bandwidth from k8s-worker-2 to k8s-worker-4: 816 Mbits/sec
# Bandwidth from k8s-worker-7 to k8s-worker-3: 816 Mbits/sec
# Bandwidth from k8s-worker-7 to k8s-worker-1: 809 Mbits/sec
