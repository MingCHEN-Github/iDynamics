# %%
# from Policy1_demo_workloads import wrk_different_requests
# from iDynamicsPackagesModules.SchedulingPolicyExtender.my_cluster_utils import (
#     gather_all_nodes, build_nodeinfo_objects,
#     build_podinfo_objects, gather_all_pods)

# from iDynamicsPackagesModules.GraphDynamicsAnalyzer.graph_builder import build_call_graph
from iDynamicsPackagesModules.Evaluations.Cluster_15_Nodes.Policy1_eval_Graph_dynamics.Policy1_Call_Graph_Aware import Policy1CallGraphAware
# from iDynamicsPackagesModules.Evaluations.Policy2_eval_Delay_dynamics.Policy2_Latency_Aware import Policy2LatencyAware
# from iDynamicsPackagesModules.Evaluations.Policy3_eval_Bandwidth_dynamics.Policy3_Bandwidth_Aware import Policy3BandwidthAware

# from Policy1_demo_workloads import run_workload_varing_callGraph
# Out:
# Pods already exist in the namespace. Skipping DaemonSet deployment.

# %%
import time
import threading


def evaluate_policy1_scheudlder():
    # Initialize the scheduler with necessary parameters
    app1_prom_url = "http://10.105.116.175:9090"
    app1_qos_target = 300 #150 ms for 10 cluster nodes,  200 ms for 15 cluster nodes  # QoS target in milliseconds
    # time_window is the look_back window for the average response time
    app1_time_window = 1  # Time window in minutes,
    app1_namespace = 'social-network'
    app1_response_code = '200'  # HTTP response code to consider

    # Create an instance of the scheduler
    policy1 = Policy1CallGraphAware()
    policy1.initialize_policy(dynamics_config={"traffic_pairs": {}}, prom_url=app1_prom_url, 
                            qos_target = app1_qos_target, time_window = app1_time_window, 
                            namespace = app1_namespace, response_code = app1_response_code)

    # Run the scheduler
    while True:
        policy1.run()
        time.sleep(20) # Run the scheduler to regularly  check if the QoS if violated every 30 seconds

# wait 60*16*2 seconds till the default k8s policy evaluation first, and then Policy1
# 60*3 seconds is the sleep time two evaluations (default k8s policy first, and then Policy1)
# time.sleep(60*16*2 + 60*3) 
evaluate_policy1_scheudlder()

# (1) before running the Policy1 scheduler, we run the workload for the first time 
# to obtain performance in default k8s scheduler

# run_workload_varing_callGraph(each_wrk2_duration='3m') # eg., "30s", "1m", 5m", "10m", "15m"
#sleep for 2 mins
# time.sleep(180)

# (2) Conccurently run evaluate_policy1_scheudlder() and run_workload_varing_callGraph()
# workload_thread = threading.Thread(target = run_workload_varing_callGraph, kwargs={'each_wrk2_duration':'3m'})
# scheduler_thread = threading.Thread(target=evaluate_policy1_scheudlder)
# workload_thread.start()
# scheduler_thread.start()

# # Wait for both threads to finish
# workload_thread.join()
# scheduler_thread.join()
# Out:
# Average response time = 300.05 ms
# Trigger = True
# Ready Deployments: ['compose-post-service', 'home-timeline-redis', 'home-timeline-service', 'jaeger', 'media-frontend', 'media-memcached', 'media-mongodb', 'media-service', 'nginx-thrift', 'post-storage-memcached', 'post-storage-mongodb', 'post-storage-service', 'social-graph-mongodb', 'social-graph-redis', 'social-graph-service', 'text-service', 'unique-id-service', 'url-shorten-memcached', 'url-shorten-mongodb', 'url-shorten-service', 'user-memcached', 'user-mention-service', 'user-mongodb', 'user-service', 'user-timeline-mongodb', 'user-timeline-redis', 'user-timeline-service']
# from compose-post-service to home-timeline-service ~ 72.3 KB
# from compose-post-service to media-service ~ 96.8 KB
# from compose-post-service to post-storage-service ~ 396.7 KB
# from compose-post-service to text-service ~ 561.1 KB
# from compose-post-service to unique-id-service ~ 64.7 KB
# from compose-post-service to user-service ~ 85.5 KB
# from compose-post-service to user-timeline-service ~ 69.4 KB
# from home-timeline-service to social-graph-service ~ 59.5 KB
# from nginx-thrift to compose-post-service ~ 286.6 KB
# from post-storage-service to post-storage-mongodb ~ 219.1 KB
# from social-graph-service to social-graph-mongodb ~ 36.9 KB
# from social-graph-service to social-graph-redis ~ 19.6 KB
# from text-service to url-shorten-service ~ 285.4 KB
# from text-service to user-mention-service ~ 81.8 KB
# from url-shorten-service to url-shorten-mongodb ~ 110.7 KB
# from user-mention-service to user-memcached ~ 88.4 KB
# from user-mention-service to user-mongodb ~ 105.8 KB
# from user-service to user-mongodb ~ 0.0 KB
# from user-timeline-service to user-timeline-mongodb ~ 0.0 KB
# from user-timeline-service to user-timeline-redis ~ 31.4 KB
# [Policy1CallGraphAware] Updated traffic matrix for app in namespace social-network with 18 edges.
# === Scenario1: Call-Graph_Aware ===
#  Pod compose-post-service-5495944745-lrkkc -> schedule to Node k8s-worker-1
#  Pod text-service-b4dd75768-v6qg7 -> schedule to Node k8s-worker-1
#  Pod post-storage-service-689676c776-9l5pq -> schedule to Node k8s-worker-1
#  Pod post-storage-mongodb-655dcfc464-xmt6r -> schedule to Node k8s-worker-1
#  Pod url-shorten-service-5d8db86d79-cz986 -> schedule to Node k8s-worker-1
#  Pod url-shorten-mongodb-7bddc85c57-qjz98 -> schedule to Node k8s-worker-1
#  Pod user-mention-service-7bfd4c675b-pvstr -> schedule to Node k8s-worker-1
#  Pod user-mongodb-7b97984867-sdj2s -> schedule to Node k8s-worker-1
#  Pod home-timeline-service-5dbd8696bf-fxq9l -> schedule to Node k8s-worker-1
#  Pod social-graph-service-b9cb6fc9d-6xc4b -> schedule to Node k8s-worker-1
#  Pod user-timeline-service-7476cfdc65-x9s6h -> schedule to Node k8s-worker-1
#  Pod user-timeline-redis-fcc95ccc4-zvhvd -> schedule to Node k8s-worker-1
#  Pod home-timeline-redis-6dc89c45bb-f8zcg -> schedule to Node k8s-worker-10
#  Pod user-service-746f86888d-lv2mh -> schedule to Node k8s-worker-10
#  Pod user-timeline-mongodb-5dc87d474f-7bkcx -> schedule to Node k8s-worker-11
#  Pod media-frontend-65f456cb5d-sp8z2 -> schedule to Node k8s-worker-12
#  Pod media-memcached-7bf57b97f5-2xtch -> schedule to Node k8s-worker-13
#  Pod media-mongodb-5f68bc5cdd-s7nms -> schedule to Node k8s-worker-14
#  Pod media-service-cd556bbd9-r8lrc -> schedule to Node k8s-worker-2
#  Pod post-storage-memcached-6b6f4d9cbf-sddp4 -> schedule to Node k8s-worker-4
#  Pod social-graph-mongodb-5c6d49fd88-2lk4d -> schedule to Node k8s-worker-5
#  Pod social-graph-redis-84c998f45f-smlj4 -> schedule to Node k8s-worker-6
#  Pod unique-id-service-9fb95975-vjpp9 -> schedule to Node k8s-worker-7
#  Pod url-shorten-memcached-7b89bc4dd9-cdnbv -> schedule to Node k8s-worker-8
#  Pod user-memcached-78cfddb9c5-8xw67 -> schedule to Node k8s-worker-9
# Starting migration of compose-post-service to k8s-worker-1
# Starting migration of text-service to k8s-worker-1
# Starting migration of post-storage-service to k8s-worker-1
# Starting migration of post-storage-mongodb to k8s-worker-1
# Starting migration of url-shorten-service to k8s-worker-1
# Starting migration of url-shorten-mongodb to k8s-worker-1
# Starting migration of user-mention-service to k8s-worker-1
# Starting migration of user-mongodb to k8s-worker-1
# Starting migration of home-timeline-service to k8s-worker-1
# Starting migration of social-graph-service to k8s-worker-1
# Starting migration of user-timeline-service to k8s-worker-1
# Starting migration of user-timeline-redis to k8s-worker-1
# Starting migration of home-timeline-redis to k8s-worker-10
# Deployment 'text-service' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Starting migration of user-service to k8s-worker-10
# Deployment 'compose-post-service' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Deployment 'post-storage-service' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Deployment 'post-storage-mongodb' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Starting migration of user-timeline-mongodb to k8s-worker-11
# Starting migration of media-frontend to k8s-worker-12
# Starting migration of media-memcached to k8s-worker-13
# Starting migration of media-mongodb to k8s-worker-14
# Deployment 'social-graph-service' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Deployment 'user-mention-service' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Starting migration of media-service to k8s-worker-2
# Deployment 'user-mongodb' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Deployment 'url-shorten-mongodb' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Deployment 'home-timeline-service' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Deployment 'user-timeline-redis' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Deployment 'url-shorten-service' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Starting migration of post-storage-memcached to k8s-worker-4
# Deployment 'home-timeline-redis' patched to schedule pods on 'k8s-worker-10'.
# Waiting for the rolling update to complete...
# Starting migration of social-graph-mongodb to k8s-worker-5
# Deployment 'user-timeline-service' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Starting migration of social-graph-redis to k8s-worker-6
# Starting migration of unique-id-service to k8s-worker-7
# Starting migration of url-shorten-memcached to k8s-worker-8
# Starting migration of user-memcached to k8s-worker-9
# Deployment 'url-shorten-memcached' patched to schedule pods on 'k8s-worker-8'.
# Waiting for the rolling update to complete...
# Deployment 'media-service' patched to schedule pods on 'k8s-worker-2'.
# Waiting for the rolling update to complete...
# Deployment 'user-timeline-mongodb' patched to schedule pods on 'k8s-worker-11'.
# Waiting for the rolling update to complete...
# Deployment 'user-service' patched to schedule pods on 'k8s-worker-10'.
# Waiting for the rolling update to complete...
# Deployment 'post-storage-memcached' patched to schedule pods on 'k8s-worker-4'.
# Waiting for the rolling update to complete...
# Deployment 'media-memcached' patched to schedule pods on 'k8s-worker-13'.
# Waiting for the rolling update to complete...
# Deployment 'unique-id-service' patched to schedule pods on 'k8s-worker-7'.
# Waiting for the rolling update to complete...
# Deployment 'social-graph-mongodb' patched to schedule pods on 'k8s-worker-5'.
# Waiting for the rolling update to complete...
# Deployment 'media-mongodb' patched to schedule pods on 'k8s-worker-14'.
# Waiting for the rolling update to complete...
# Deployment 'social-graph-redis' patched to schedule pods on 'k8s-worker-6'.
# Waiting for the rolling update to complete...
# Deployment 'user-memcached' patched to schedule pods on 'k8s-worker-9'.
# Waiting for the rolling update to complete...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# Deployment 'media-frontend' patched to schedule pods on 'k8s-worker-12'.
# Waiting for the rolling update to complete...
# all_pods_updated= False
# len(pods)= 1
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 1
# Rolling update in progress...
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice user-timeline-service migrated successfully to k8s-worker-1.
# Migration result: Migration of user-timeline-service to k8s-worker-1 completed.
# all_pods_updated= False
# len(pods)= 1
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 1
# Rolling update in progress...
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice social-graph-mongodb migrated successfully to k8s-worker-5.
# Migration result: Migration of social-graph-mongodb to k8s-worker-5 completed.
# all_pods_updated= False
# len(pods)= 1
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 1
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 1
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 1
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 1
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 1
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 1
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 1
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 1
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 1
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 1
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= True
# len(pods)= 2
# All pods are running on the new node.
# Microservice post-storage-mongodb migrated successfully to k8s-worker-1.
# Migration result: Migration of post-storage-mongodb to k8s-worker-1 completed.
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= True
# len(pods)= 2
# All pods are running on the new node.
# Microservice text-service migrated successfully to k8s-worker-1.
# Migration result: Migration of text-service to k8s-worker-1 completed.
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice user-timeline-redis migrated successfully to k8s-worker-1.
# Migration result: Migration of user-timeline-redis to k8s-worker-1 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice post-storage-memcached migrated successfully to k8s-worker-4.
# Migration result: Migration of post-storage-memcached to k8s-worker-4 completed.
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice user-mongodb migrated successfully to k8s-worker-1.
# Migration result: Migration of user-mongodb to k8s-worker-1 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice url-shorten-mongodb migrated successfully to k8s-worker-1.
# Migration result: Migration of url-shorten-mongodb to k8s-worker-1 completed.
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice compose-post-service migrated successfully to k8s-worker-1.
# Migration result: Migration of compose-post-service to k8s-worker-1 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice media-service migrated successfully to k8s-worker-2.
# Migration result: Migration of media-service to k8s-worker-2 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice home-timeline-service migrated successfully to k8s-worker-1.
# Migration result: Migration of home-timeline-service to k8s-worker-1 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice social-graph-service migrated successfully to k8s-worker-1.
# Migration result: Migration of social-graph-service to k8s-worker-1 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice url-shorten-service migrated successfully to k8s-worker-1.
# Migration result: Migration of url-shorten-service to k8s-worker-1 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice user-mention-service migrated successfully to k8s-worker-1.
# Migration result: Migration of user-mention-service to k8s-worker-1 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice post-storage-service migrated successfully to k8s-worker-1.
# Migration result: Migration of post-storage-service to k8s-worker-1 completed.
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated=all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
#  False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# ...
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...

# %%
app1_prom_url = "http://10.105.116.175:9090"
app1_qos_target = 150  # QoS target in milliseconds
# time_window is the look_back window for the average response time
app1_time_window = 1  # Time window in minutes,
app1_namespace = 'social-network'
app1_response_code = '200'  # HTTP response code to consider

# Create an instance of the scheduler
policy1 = Policy1CallGraphAware()
policy1.initialize_policy(dynamics_config={"traffic_pairs": {}}, prom_url=app1_prom_url, 
                        qos_target = app1_qos_target, time_window = app1_time_window, 
                        namespace = app1_namespace, response_code = app1_response_code)

# Run the scheduler
while True:
    policy1.run()
    time.sleep(20) # Run the scheduler to regularly  check if the QoS if violated every 30 seconds

# %%
# 1) Gather cluster data
raw_nodes = gather_all_nodes()
candidate_nodes = build_nodeinfo_objects(raw_nodes)

# Gather pod data for each policy
# Deploye three instances of social-network application in different namespaces
# each policy will be applied to each namespace
raw_pods_Policy1 = gather_all_pods(namespace="social-network")
pods_Policy1 = build_podinfo_objects(raw_pods_Policy1)

raw_pods_Policy2 = gather_all_pods(namespace="social-network2")
pods_Policy2 = build_podinfo_objects(raw_pods_Policy2)

raw_pods_Policy3 = gather_all_pods(namespace="social-network3")
pods_Policy3 = build_podinfo_objects(raw_pods_Policy3)

# 2) (Optional) Build a call graph from 'graph_builder.py'
#    This might be used by Policy1 to place heavily communicating microservices.
G = build_call_graph(namespace="social-network")
# Convert the NetworkX graph to a simple dict: (src, dst) -> traffic_kb
traffic_matrix = {}
for (u, v, data) in G.edges(data=True):
    traffic_matrix[(u, v)] = data.get("weight", 0.0)  # store as KB

# 3) Initialize each policy with scenario-specific config
policy1 = Policy1CallGraphAware()
policy1.initialize_policy(dynamics_config={"traffic_matrix": traffic_matrix})

policy2 = Policy2LatencyAware()
policy2.initialize_policy(dynamics_config={"latency_threshold": 5.0})  # example

policy3 = Policy3BandwidthAware()
policy3.initialize_policy(dynamics_config={"high_traffic_threshold": 300.0})  # example

# 4) Choose which scenario you want to test
# Scenario 1: call-graph dynamics => we expect policy1 to shine
print("=== Scenario1: Call-Graph_Aware ===")
decisions_s1 = policy1.schedule_all(pods_Policy1, candidate_nodes)
for dec in decisions_s1:
    print(f"  Pod {dec.pod_name} -> Node {dec.selected_node}")

# Scenario 2: cross-node delays => policy2 might do better
print("\n=== Scenario2: Latency_Aware ===")
decisions_s2 = policy2.schedule_all(pods_Policy2, candidate_nodes)
for dec in decisions_s2:
    print(f"  Pod {dec.pod_name} -> Node {dec.selected_node}")

# Scenario 3: cross-node bandwidth changes => policy3 might do better
print("\n=== Scenario3: Bandwidth_Aware ===")
decisions_s3 = policy3.schedule_all(pods_Policy3, candidate_nodes)
for dec in decisions_s3:
    print(f"  Pod {dec.pod_name} -> Node {dec.selected_node}")
