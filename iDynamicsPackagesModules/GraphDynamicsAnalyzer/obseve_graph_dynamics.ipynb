# %%
# using wrk tool to run the four differnt test workloads (request A, request B, request C, request_mix ABC) for Social Network Application in name space of "social-network"
# this test is used to observe the different performace of the Social Network Application under different workloads(requests). Each type of request is running 5 mins

import os
import subprocess

# Define the parameters
thread_num = 4
connections = 100
duration = '2m'

# QPS = [50, 200, 400]
QPS = [20]

request_A_script_path = "/home/ubuntu/DeathStarBench/socialNetwork/wrk2/scripts/social-network/compose-post.lua"
request_B_script_path = "/home/ubuntu/DeathStarBench/socialNetwork/wrk2/scripts/social-network/read-home-timeline.lua"
request_C_script_path = "/home/ubuntu/DeathStarBench/socialNetwork/wrk2/scripts/social-network/read-user-timeline.lua"

request_mix_script_path = "/home/ubuntu/DeathStarBench/socialNetwork/wrk2/scripts/social-network/mixed-workload.lua" # default mix percentage: 60% A, 30% B, 10% C

script_path = [
    request_A_script_path,
    request_B_script_path,
    request_C_script_path,
    request_mix_script_path
]

url = [
    #diffferent namespace of social-network Application
    "http://nginx-thrift.social-network.svc.cluster.local:8080"       # in namespace of "social-network"
#     "http://nginx-thrift.social-network2.svc.cluster.local:8080",
#    "http://nginx-thrift.social-network3.svc.cluster.local:8080"
]


# Define the output file path in the current directory and file name with the format of current time (Year_MONTH_Day_Hour_Minute)

output_file = os.path.join(os.getcwd(), "/home/ubuntu/iDynamics/Evaluations/Policy1_eval_Graph_dynamics/output_result1.txt")

# Ensure the output file is empty at the start
with open(output_file, 'w') as f:
    f.write("")

for i in range(len(url)):
    for script in script_path:
        command = [
            "/home/ubuntu/DeathStarBench/wrk2/wrk",
            "-D", "exp",
            f"-t{thread_num}",
            f"-c{connections}",
            f"-d{duration}",
            "-L",
            "-s", script,
            url[i],
            f"-R{QPS[0]}"
        ]
        print(f"Running command: {' '.join(command)}")
        
        # make sure each loop runs one command, after finish current loop, run the next command
        # run the command
        process = subprocess.Popen(command, stdout=subprocess.PIPE)
        output, error = process.communicate()
        output = output.decode("utf-8")
        print(output)
        # Write the output to the output file
        with open(output_file, 'a') as f:
            f.write(output)
            f.write("\n\n")
        print(f"Finished running command: {' '.join(command)}")
        print("--------------------------------------------------")
print("All tests are done!")
# Out:
# Running command: /home/ubuntu/DeathStarBench/wrk2/wrk -D exp -t4 -c100 -d2m -L -s /home/ubuntu/DeathStarBench/socialNetwork/wrk2/scripts/social-network/compose-post.lua http://nginx-thrift.social-network.svc.cluster.local:8080 -R20
# Running 2m test @ http://nginx-thrift.social-network.svc.cluster.local:8080
#   4 threads and 100 connections
#
#   Thread calibration: mean lat.: 296.247ms, rate sampling interval: 836ms
#   Thread calibration: mean lat.: 323.799ms, rate sampling interval: 1064ms
#   Thread calibration: mean lat.: 334.664ms, rate sampling interval: 1020ms
#   Thread calibration: mean lat.: 301.371ms, rate sampling interval: 970ms
#
# -----------------------------------------------------------------------
# Test Results @ http://nginx-thrift.social-network.svc.cluster.local:8080
#   Thread Stats   Avg      Stdev     99%   +/- Stdev
#     Latency   248.13ms   34.23ms 435.97ms   90.45%
#     Req/Sec     4.44      2.23    10.00     82.60%
#   Latency Distribution (HdrHistogram - Recorded Latency)
#  50.000%  236.93ms
#  75.000%  239.74ms
#  90.000%  279.30ms
#  99.000%  435.97ms
#  99.900%  522.24ms
#  99.990%  552.96ms
#  99.999%  552.96ms
# 100.000%  552.96ms
#
#   Detailed Percentile spectrum:
#        Value   Percentile   TotalCount 1/(1-Percentile)
#
#      231.039     0.000000            1         1.00
#      234.239     0.100000          223         1.11
#      235.135     0.200000          480         1.25
#      235.775     0.300000          684         1.43
#      236.415     0.400000          928         1.67
#      236.927     0.500000         1117         2.00
#      237.183     0.550000         1218         2.22
#      237.567     0.600000         1319         2.50
#      238.079     0.650000         1441         2.86
#      238.719     0.700000         1546         3.33
#      239.743     0.750000         1651         4.00
#      241.535     0.775000         1704         4.44
#      245.503     0.800000         1759         5.00
#      249.471     0.825000         1814         5.71
#      255.359     0.850000         1869         6.67
#      189.823     0.775000         1711         4.44
#      190.591     0.800000         1756         5.00
#      198.399     0.825000         1813         5.71
#      204.031     0.850000         1866         6.67
#      205.439     0.875000         1921         8.00
#      206.719     0.887500         1948         8.89
#      209.919     0.900000         1976        10.00
#      223.999     0.912500         2003        11.43
#      235.135     0.925000         2030        13.33
#      248.063     0.937500         2057        16.00
#      252.543     0.943750         2071        17.78
#      261.631     0.950000         2085        20.00
#      269.311     0.956250         2099        22.86
#      275.455     0.962500         2112        26.67
#      289.023     0.968750         2126        32.00
#      300.543     0.971875         2133        35.56
#      306.943     0.975000         2140        40.00
#      312.063     0.978125         2148        45.71
#      318.719     0.981250         2153        53.33
#      321.791     0.984375         2160        64.00
#      323.583     0.985938         2164        71.11
#      324.351     0.987500         2167        80.00
#      326.911     0.989062         2171        91.43
#      328.959     0.990625         2174       106.67
#      336.639     0.992188         2177       128.00
#      337.663     0.992969         2179       142.22
#      340.735     0.993750         2181       160.00
#      346.879     0.994531         2183       182.86
#      349.183     0.995313         2184       213.33
#      351.999     0.996094         2186       256.00
#      359.935     0.996484         2187       284.44
#      360.191     0.996875         2188       320.00
#      364.799     0.997266         2189       365.71
#      364.799     0.997656         2189       426.67
#      382.207     0.998047         2190       512.00
#      386.303     0.998242         2191       568.89
#      386.303     0.998437         2191       640.00
#      397.567     0.998633         2193       731.43
#      397.567     0.998828         2193       853.33
#      397.567     0.999023         2193      1024.00
#      397.567     0.999121         2193      1137.78
#      397.567     0.999219         2193      1280.00
#      397.567     0.999316         2193      1462.86
#      397.567     0.999414         2193      1706.67
#      397.567     0.999512         2193      2048.00
#      492.799     0.999561         2194      2275.56
#      492.799     1.000000         2194          inf
# #[Mean    =      181.989, StdDeviation   =       37.973]
# #[Max     =      492.544, Total count    =         2194]
# #[Buckets =           27, SubBuckets     =         2048]
# -----------------------------------------------------------------------
#   2407 requests in 2.00m, 2.39MB read
#   Socket errors: connect 0, read 0, write 0, timeout 3968
#   Non-2xx or 3xx responses: 2275
# Requests/sec:     20.05
# Transfer/sec:     20.37KB
#
# Finished running command: /home/ubuntu/DeathStarBench/wrk2/wrk -D exp -t4 -c100 -d2m -L -s /home/ubuntu/DeathStarBench/socialNetwork/wrk2/scripts/social-network/read-user-timeline.lua http://nginx-thrift.social-network.svc.cluster.local:8080 -R20
# --------------------------------------------------
# Running command: /home/ubuntu/DeathStarBench/wrk2/wrk -D exp -t4 -c100 -d2m -L -s /home/ubuntu/DeathStarBench/socialNetwork/wrk2/scripts/social-network/mixed-workload.lua http://nginx-thrift.social-network.svc.cluster.local:8080 -R20
# Running 2m test @ http://nginx-thrift.social-network.svc.cluster.local:8080
#   4 threads and 100 connections
#
#   Thread calibration: mean lat.: 119.396ms, rate sampling interval: 376ms
#   Thread calibration: mean lat.: 105.761ms, rate sampling interval: 379ms
#   Thread calibration: mean lat.: 136.230ms, rate sampling interval: 464ms
#   Thread calibration: mean lat.: 112.700ms, rate sampling interval: 559ms
#
# -----------------------------------------------------------------------
# Test Results @ http://nginx-thrift.social-network.svc.cluster.local:8080
#   Thread Stats   Avg      Stdev     99%   +/- Stdev
#     Latency   121.93ms   88.54ms 377.34ms   86.48%
#     Req/Sec     4.53      3.16    13.00     78.21%
#   Latency Distribution (HdrHistogram - Recorded Latency)
#  50.000%   56.80ms
#  75.000%  179.07ms
#  90.000%  281.34ms
#  99.000%  377.34ms
#  99.900%  434.69ms
#  99.990%  454.91ms
#  99.999%  454.91ms
# 100.000%  454.91ms
#
#   Detailed Percentile spectrum:
#        Value   Percentile   TotalCount 1/(1-Percentile)
#
#       54.047     0.000000            1         1.00
#       55.327     0.100000          226         1.11
#       55.711     0.200000          441         1.25
#       55.999     0.300000          673         1.43
#       56.319     0.400000          891         1.67
#       56.799     0.500000         1102         2.00
#       57.535     0.550000         1209         2.22
#      123.647     0.600000         1319         2.50
#      165.887     0.650000         1433         2.86
#      168.319     0.700000         1543         3.33
#      179.071     0.750000         1652         4.00
#      181.759     0.775000         1704         4.44
#      187.903     0.800000         1759         5.00
#      190.719     0.825000         1816         5.71
#      204.927     0.850000         1868         6.67
#      239.359     0.875000         1923         8.00
#      277.247     0.887500         1950         8.89
#      282.111     0.900000         1978        10.00
#      287.999     0.912500         2006        11.43
#      289.535     0.925000         2033        13.33
#      291.071     0.937500         2064        16.00
#      291.327     0.943750         2074        17.78
#      292.351     0.950000         2089        20.00
#      297.471     0.956250         2101        22.86
#      303.615     0.962500         2115        26.67
#      316.159     0.968750         2129        32.00
#      326.911     0.971875         2136        35.56
#      330.751     0.975000         2143        40.00
#      338.175     0.978125         2149        45.71
#      345.087     0.981250         2156        53.33
#      353.535     0.984375         2163        64.00
#      361.471     0.985938         2167        71.11
#      367.871     0.987500         2170        80.00
#      371.199     0.989062         2173        91.43
#      382.975     0.990625         2177       106.67
#      388.607     0.992188         2180       128.00
#      389.375     0.992969         2182       142.22
#      397.823     0.993750         2185       160.00
#      397.823     0.994531         2185       182.86
#      404.991     0.995313         2187       213.33
#      406.271     0.996094         2189       256.00
#      412.415     0.996484         2190       284.44
#      412.671     0.996875         2191       320.00
#      412.671     0.997266         2191       365.71
#      414.975     0.997656         2192       426.67
#      419.839     0.998047         2193       512.00
#      421.887     0.998242         2194       568.89
#      421.887     0.998437         2194       640.00
#      421.887     0.998633         2194       731.43
#      434.687     0.998828         2195       853.33
#      434.687     0.999023         2195      1024.00
#      435.199     0.999121         2196      1137.78
#      435.199     0.999219         2196      1280.00
#      435.199     0.999316         2196      1462.86
#      435.199     0.999414         2196      1706.67
#      435.199     0.999512         2196      2048.00
#      454.911     0.999561         2197      2275.56
#      454.911     1.000000         2197          inf
# #[Mean    =      121.926, StdDeviation   =       88.542]
# #[Max     =      454.656, Total count    =         2197]
# #[Buckets =           27, SubBuckets     =         2048]
# -----------------------------------------------------------------------
#   2399 requests in 2.00m, 1.21MB read
#   Socket errors: connect 0, read 0, write 0, timeout 3962
#   Non-2xx or 3xx responses: 667
# Requests/sec:     19.99
# Transfer/sec:     10.35KB
#
# Finished running command: /home/ubuntu/DeathStarBench/wrk2/wrk -D exp -t4 -c100 -d2m -L -s /home/ubuntu/DeathStarBench/socialNetwork/wrk2/scripts/social-network/mixed-workload.lua http://nginx-thrift.social-network.svc.cluster.local:8080 -R20
# --------------------------------------------------
# All tests are done!
