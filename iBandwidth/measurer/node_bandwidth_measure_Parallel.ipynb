# %%
'''Deploy cross-node bandwidth measurement pods'''

from kubernetes import client, config

def check_pods_existence(namespace):
    core_v1 = client.CoreV1Api()
    try:
        pods = core_v1.list_namespaced_pod(namespace=namespace)
        return len(pods.items) > 0  # return True if pods exist
    except client.rest.ApiException as e:
        print(f"Exception when calling CoreV1Api->list_namespaced_pod: {e}")
        return False

def deploy_bandwidth_measurement_daemonset_if_needed():
    namespace = 'measure-nodes-bd'
    ds_name = 'bandwidth-measurement-ds'
    
    # Load Kubernetes configuration
    config.load_kube_config()
    apps_v1 = client.AppsV1Api()

    # Check if pods exist in the namespace
    pods_exist = check_pods_existence(namespace)

    # If no pods exist, deploy the DaemonSet
    if not pods_exist:
        # Define the body of the DaemonSet for `iperf3` server deployment
        ds_body = client.V1DaemonSet(
            api_version="apps/v1",
            kind="DaemonSet",
            metadata=client.V1ObjectMeta(name=ds_name),
            spec=client.V1DaemonSetSpec(
                selector=client.V1LabelSelector(
                    match_labels={"app": "bandwidth-measurement"}
                ),
                template=client.V1PodTemplateSpec(
                    metadata=client.V1ObjectMeta(labels={"app": "bandwidth-measurement"}),
                    spec=client.V1PodSpec(
                        containers=[client.V1Container(
                            name="iperf3-server",
                            image="networkstatic/iperf3",
                            args=["-s"],  # Run in server mode
                            ports=[client.V1ContainerPort(container_port=5201)]
                        )],
                        restart_policy="Always"
                    )
                )
            )
        )

        # Deploy the DaemonSet
        try:
            apps_v1.create_namespaced_daemon_set(namespace=namespace, body=ds_body)
            print(f"Deployed DaemonSet {ds_name} in namespace {namespace}")
        except client.rest.ApiException as e:
            print(f"Exception when calling AppsV1Api->create_namespaced_daemon_set: {e}")
    else:
        print("Pods already exist in the namespace. Skipping DaemonSet deployment.")

# Call the function to deploy the DaemonSet if needed
deploy_bandwidth_measurement_daemonset_if_needed()
# Out:
# Pods already exist in the namespace. Skipping DaemonSet deployment.

# %%
import re
from kubernetes import client, config, stream
import concurrent.futures
import time

# Load Kubernetes configuration
config.load_kube_config()
v1 = client.CoreV1Api()

# Function to measure bandwidth between source and target pods with retries
def measure_bandwidth_from_source_to_target(v1, namespace, source_pod, target_pod, test_duration=5, max_retries=3):
    source_pod_name = source_pod.metadata.name
    source_pod_node_name = source_pod.spec.node_name
    target_pod_ip = target_pod.status.pod_ip
    target_pod_name = target_pod.metadata.name
    target_pod_node_name = target_pod.spec.node_name
    result = (source_pod_node_name, target_pod_node_name, None)

    if source_pod_name != target_pod_name:
        exec_command = ['iperf3', '-c', target_pod_ip, '-t', str(test_duration)]
        attempts = 0

        while attempts < max_retries:
            try:
                # Run iperf3 command
                resp = stream.stream(v1.connect_get_namespaced_pod_exec,
                                     source_pod_name,
                                     namespace,
                                     command=exec_command,
                                     stderr=True,
                                     stdin=False,
                                     stdout=True,
                                     tty=False)

                # Check for "server is busy" in the output
                if "the server is busy" in resp:
                    print(f"Server is busy for connection from {source_pod_name} to {target_pod_name}. Retrying...")
                    attempts += 1
                    time.sleep(test_duration/2)  # Wait before retrying
                    continue

                # Parse the output for bandwidth
                print(f"Full output from {source_pod_name} to {target_pod_name}:\n{resp}")
                match = re.search(r'(\d+\.?\d*\s[MKG]bits/sec)', resp)
                if match:
                    bandwidth = match.group(1)
                    result = (source_pod_node_name, target_pod_node_name, bandwidth)
                    print(f"Bandwidth from {source_pod_node_name} to {target_pod_node_name}: {bandwidth}")
                else:
                    print(f"Could not extract bandwidth for connection from {source_pod_name} to {target_pod_name}.")
                    result = (source_pod_node_name, target_pod_node_name, "Parsing Error")
                break  # Exit loop on success

            except Exception as e:
                print(f"Error executing command in pod {source_pod_name}: {e}")
                result = (source_pod_node_name, target_pod_node_name, "Error")
                break

        if attempts == max_retries:
            print(f"Max retries reached for connection from {source_pod_name} to {target_pod_name}.")
            result = (source_pod_node_name, target_pod_node_name, "Server Busy Error")

    return result

def measure_bandwidth(namespace='measure-nodes-bd', max_concurrent_tasks=3, test_duration=5):
    v1 = client.CoreV1Api()
    pods = v1.list_namespaced_pod(namespace, label_selector="app=bandwidth-measurement").items
    bandwidth_results = {}

    # Use ThreadPoolExecutor for controlled concurrent execution
    with concurrent.futures.ThreadPoolExecutor(max_workers=max_concurrent_tasks) as executor:
        futures = []
        for source_pod in pods:
            for target_pod in pods:
                if source_pod.metadata.name != target_pod.metadata.name:  # Skip self-tests
                    futures.append(executor.submit(measure_bandwidth_from_source_to_target,
                                                   v1, namespace, source_pod, target_pod, test_duration))

        # Collect the completed results
        for future in concurrent.futures.as_completed(futures):
            source_pod_node_name, target_pod_node_name, bandwidth = future.result()
            if source_pod_node_name not in bandwidth_results:
                bandwidth_results[source_pod_node_name] = {}
            bandwidth_results[source_pod_node_name][target_pod_node_name] = bandwidth

    return bandwidth_results

# Call the function to measure bandwidth after deploying the DaemonSet
namespace = 'measure-nodes-bd'
# Reduced concurrency and added retry logic
bandwidth_results = measure_bandwidth(namespace=namespace, max_concurrent_tasks=3, test_duration=10)
print(bandwidth_results)
# Out:
# Full output from bandwidth-measurement-ds-6dldb to bandwidth-measurement-ds-p2vgl:
# Connecting to host 192.168.18.232, port 5201
# [  5] local 192.168.69.209 port 40846 connected to 192.168.18.232 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  17.7 MBytes   148 Mbits/sec    0    921 KBytes
# [  5]   1.00-2.00   sec  14.7 MBytes   124 Mbits/sec    0   1.59 MBytes
# [  5]   2.00-3.00   sec  16.2 MBytes   136 Mbits/sec    0   2.38 MBytes
# [  5]   3.00-4.00   sec  18.8 MBytes   157 Mbits/sec    0   3.15 MBytes
# [  5]   4.00-5.00   sec  15.0 MBytes   126 Mbits/sec   17   2.36 MBytes
# [  5]   5.00-6.00   sec  17.5 MBytes   147 Mbits/sec    0   2.68 MBytes
# [  5]   6.00-7.00   sec  17.5 MBytes   147 Mbits/sec    0   2.89 MBytes
# [  5]   7.00-8.00   sec  18.8 MBytes   157 Mbits/sec    0   3.02 MBytes
# [  5]   8.00-9.00   sec  17.5 MBytes   147 Mbits/sec    0   3.02 MBytes
# [  5]   9.00-10.00  sec  18.8 MBytes   157 Mbits/sec    0   3.02 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   172 MBytes   145 Mbits/sec   17             sender
# [  5]   0.00-10.15  sec   172 MBytes   142 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-3 to k8s-worker-5: 148 Mbits/sec
# Full output from bandwidth-measurement-ds-6dldb to bandwidth-measurement-ds-gnsh9:
# Connecting to host 192.168.230.44, port 5201
# [  5] local 192.168.69.209 port 53672 connected to 192.168.230.44 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  35.1 MBytes   295 Mbits/sec    0   2.13 MBytes
# [  5]   1.00-2.00   sec  30.0 MBytes   252 Mbits/sec    0   3.13 MBytes
# [  5]   2.00-3.00   sec  25.0 MBytes   210 Mbits/sec    0   3.13 MBytes
# [  5]   3.00-4.00   sec  21.2 MBytes   178 Mbits/sec    0   3.13 MBytes
# [  5]   4.00-5.00   sec  20.0 MBytes   168 Mbits/sec    0   3.13 MBytes
# [  5]   5.00-6.00   sec  18.8 MBytes   157 Mbits/sec    0   3.13 MBytes
# [  5]   6.00-7.00   sec  17.5 MBytes   147 Mbits/sec    0   3.13 MBytes
# [  5]   7.00-8.00   sec  16.2 MBytes   136 Mbits/sec    1   2.38 MBytes
# [  5]   8.00-9.00   sec  17.5 MBytes   147 Mbits/sec    0   2.70 MBytes
# [  5]   9.00-10.00  sec  17.5 MBytes   147 Mbits/sec    0   2.90 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   219 MBytes   184 Mbits/sec    1             sender
# [  5]   0.00-10.15  sec   219 MBytes   181 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-3 to k8s-worker-1: 295 Mbits/sec
# Full output from bandwidth-measurement-ds-6dldb to bandwidth-measurement-ds-nrznp:
# Connecting to host 192.168.231.226, port 5201
# [  5] local 192.168.69.209 port 58354 connected to 192.168.231.226 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  11.2 MBytes  94.0 Mbits/sec    0    660 KBytes
# [  5]   1.00-2.00   sec  11.0 MBytes  92.6 Mbits/sec    0   1.15 MBytes
# [  5]   2.00-3.00   sec  11.2 MBytes  94.4 Mbits/sec    0   1.71 MBytes
# [  5]   3.00-4.00   sec  16.2 MBytes   136 Mbits/sec    0   2.50 MBytes
# [  5]   4.00-5.00   sec  17.5 MBytes   147 Mbits/sec    0   3.15 MBytes
# [  5]   5.00-6.00   sec  17.5 MBytes   147 Mbits/sec    0   3.15 MBytes
# [  5]   6.00-7.00   sec  17.5 MBytes   147 Mbits/sec    0   3.15 MBytes
# [  5]   7.00-8.00   sec  21.2 MBytes   178 Mbits/sec    0   3.15 MBytes
# [  5]   8.00-9.00   sec  17.5 MBytes   147 Mbits/sec    0   3.15 MBytes
# [  5]   9.00-10.00  sec  20.0 MBytes   168 Mbits/sec    0   3.15 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   161 MBytes   135 Mbits/sec    0             sender
# [  5]   0.00-10.15  sec   160 MBytes   133 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-3 to k8s-worker-8: 94.0 Mbits/sec
# Full output from bandwidth-measurement-ds-6dldb to bandwidth-measurement-ds-rfvj2:
# Connecting to host 192.168.227.155, port 5201
# [  5] local 192.168.69.209 port 40650 connected to 192.168.227.155 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  23.6 MBytes   198 Mbits/sec    0   1.36 MBytes
# [  5]   1.00-2.00   sec  20.0 MBytes   168 Mbits/sec    0   2.38 MBytes
# [  5]   2.00-3.00   sec  20.0 MBytes   168 Mbits/sec    0   3.14 MBytes
# [  5]   3.00-4.00   sec  20.0 MBytes   168 Mbits/sec    0   3.14 MBytes
# [  5]   4.00-5.00   sec  21.2 MBytes   178 Mbits/sec    0   3.14 MBytes
# [  5]   5.00-6.00   sec  17.5 MBytes   147 Mbits/sec    0   3.14 MBytes
# [  5]   6.00-7.00   sec  18.8 MBytes   157 Mbits/sec    0   3.14 MBytes
# [  5]   7.00-8.00   sec  18.8 MBytes   157 Mbits/sec    0   3.14 MBytes
# [  5]   8.00-9.00   sec  17.5 MBytes   147 Mbits/sec    0   3.14 MBytes
# [  5]   9.00-10.00  sec  17.5 MBytes   147 Mbits/sec    0   3.14 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   195 MBytes   163 Mbits/sec    0             sender
# [  5]   0.00-10.12  sec   195 MBytes   162 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-3 to k8s-worker-6: 198 Mbits/sec
# Full output from bandwidth-measurement-ds-6dldb to bandwidth-measurement-ds-vf5qp:
# Connecting to host 192.168.140.9, port 5201
# [  5] local 192.168.69.209 port 51842 connected to 192.168.140.9 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  21.0 MBytes   176 Mbits/sec    0   1.19 MBytes
# [  5]   1.00-2.00   sec  17.5 MBytes   147 Mbits/sec    0   2.08 MBytes
# [  5]   2.00-3.00   sec  18.8 MBytes   157 Mbits/sec    0   3.02 MBytes
# [  5]   3.00-4.00   sec  15.0 MBytes   126 Mbits/sec    7   2.39 MBytes
# [  5]   4.00-5.00   sec  18.8 MBytes   157 Mbits/sec    0   2.70 MBytes
# [  5]   5.00-6.00   sec  17.5 MBytes   147 Mbits/sec    0   2.89 MBytes
# [  5]   6.00-7.00   sec  17.5 MBytes   147 Mbits/sec    0   3.00 MBytes
# [  5]   7.00-8.00   sec  18.8 MBytes   157 Mbits/sec    0   3.02 MBytes
# [  5]   8.00-9.00   sec  18.8 MBytes   157 Mbits/sec    0   3.02 MBytes
# [  5]   9.00-10.00  sec  17.5 MBytes   147 Mbits/sec    0   3.02 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   181 MBytes   152 Mbits/sec    7             sender
# [  5]   0.00-10.12  sec   181 MBytes   150 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-3 to k8s-worker-2: 176 Mbits/sec
# Full output from bandwidth-measurement-ds-6dldb to bandwidth-measurement-ds-r7ftn:
# Connecting to host 192.168.251.65, port 5201
# [  5] local 192.168.69.209 port 57554 connected to 192.168.251.65 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  20.2 MBytes   170 Mbits/sec    0   1017 KBytes
# [  5]   1.00-2.00   sec  16.2 MBytes   136 Mbits/sec    0   1.78 MBytes
# [  5]   2.00-3.00   sec  15.0 MBytes   126 Mbits/sec    0   2.52 MBytes
# [  5]   3.00-4.00   sec  18.8 MBytes   157 Mbits/sec    0   3.14 MBytes
# [  5]   4.00-5.00   sec  15.0 MBytes   126 Mbits/sec    5   2.22 MBytes
# [  5]   5.00-6.00   sec  17.5 MBytes   147 Mbits/sec    0   2.60 MBytes
# [  5]   6.00-7.00   sec  18.8 MBytes   157 Mbits/sec    0   2.85 MBytes
# [  5]   7.00-8.00   sec  17.5 MBytes   147 Mbits/sec    0   3.01 MBytes
# [  5]   8.00-9.00   sec  17.5 MBytes   147 Mbits/sec    0   3.05 MBytes
# [  5]   9.00-10.00  sec  17.5 MBytes   147 Mbits/sec    0   3.05 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   174 MBytes   146 Mbits/sec    5             sender
# [  5]   0.00-10.15  sec   174 MBytes   144 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-3 to k8s-worker-9: 170 Mbits/sec
# Full output from bandwidth-measurement-ds-6dldb to bandwidth-measurement-ds-z29qn:
# Connecting to host 192.168.5.12, port 5201
# [  5] local 192.168.69.209 port 36428 connected to 192.168.5.12 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  16.2 MBytes   136 Mbits/sec    0    834 KBytes
# [  5]   1.00-2.00   sec  15.8 MBytes   133 Mbits/sec    0   1.54 MBytes
# [  5]   2.00-3.00   sec  21.2 MBytes   178 Mbits/sec    0   2.64 MBytes
# [  5]   3.00-4.00   sec  27.5 MBytes   231 Mbits/sec    0   3.16 MBytes
# [  5]   4.00-5.00   sec  27.5 MBytes   231 Mbits/sec    0   3.16 MBytes
# [  5]   5.00-6.00   sec  26.2 MBytes   220 Mbits/sec    0   3.16 MBytes
# [  5]   6.00-7.00   sec  26.2 MBytes   220 Mbits/sec    0   3.16 MBytes
# [  5]   7.00-8.00   sec  27.5 MBytes   231 Mbits/sec    0   3.16 MBytes
# [  5]   8.00-9.00   sec  27.5 MBytes   231 Mbits/sec    0   3.16 MBytes
# [  5]   9.00-10.00  sec  26.2 MBytes   220 Mbits/sec    0   3.16 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   242 MBytes   203 Mbits/sec    0             sender
# [  5]   0.00-10.11  sec   242 MBytes   201 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-3 to k8s-worker-7: 136 Mbits/sec
# Full output from bandwidth-measurement-ds-6dldb to bandwidth-measurement-ds-z4wqx:
# Connecting to host 192.168.79.76, port 5201
# [  5] local 192.168.69.209 port 45842 connected to 192.168.79.76 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  43.9 MBytes   368 Mbits/sec    0   2.64 MBytes
# [  5]   1.00-2.00   sec  40.0 MBytes   336 Mbits/sec    0   3.14 MBytes
# [  5]   2.00-3.00   sec  31.2 MBytes   262 Mbits/sec    0   3.14 MBytes
# [  5]   3.00-4.00   sec  27.5 MBytes   231 Mbits/sec    0   3.14 MBytes
# [  5]   4.00-5.00   sec  26.2 MBytes   220 Mbits/sec    0   3.14 MBytes
# [  5]   5.00-6.00   sec  27.5 MBytes   231 Mbits/sec    0   3.14 MBytes
# [  5]   6.00-7.00   sec  27.5 MBytes   231 Mbits/sec    0   3.14 MBytes
# [  5]   7.00-8.00   sec  26.2 MBytes   220 Mbits/sec    0   3.14 MBytes
# [  5]   8.00-9.00   sec  26.2 MBytes   220 Mbits/sec    0   3.14 MBytes
# [  5]   9.00-10.00  sec  28.8 MBytes   241 Mbits/sec    0   3.14 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   305 MBytes   256 Mbits/sec    0             sender
# [  5]   0.00-10.11  sec   304 MBytes   253 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-3 to k8s-worker-4: 368 Mbits/sec
# Full output from bandwidth-measurement-ds-gnsh9 to bandwidth-measurement-ds-6dldb:
# Connecting to host 192.168.69.209, port 5201
# [  5] local 192.168.230.44 port 58124 connected to 192.168.69.209 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  13.7 MBytes   115 Mbits/sec    0    739 KBytes
# [  5]   1.00-2.00   sec  14.0 MBytes   117 Mbits/sec    0   1.37 MBytes
# [  5]   2.00-3.00   sec  20.0 MBytes   168 Mbits/sec    0   2.34 MBytes
# [  5]   3.00-4.00   sec  25.0 MBytes   210 Mbits/sec    0   3.14 MBytes
# [  5]   4.00-5.00   sec  27.5 MBytes   231 Mbits/sec    0   3.14 MBytes
# [  5]   5.00-6.00   sec  26.2 MBytes   220 Mbits/sec    0   3.14 MBytes
# [  5]   6.00-7.00   sec  26.2 MBytes   220 Mbits/sec    0   3.14 MBytes
# [  5]   7.00-8.00   sec  26.2 MBytes   220 Mbits/sec    0   3.14 MBytes
# [  5]   8.00-9.00   sec  26.2 MBytes   220 Mbits/sec    0   3.14 MBytes
# [  5]   9.00-10.00  sec  26.2 MBytes   220 Mbits/sec    0   3.14 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   232 MBytes   194 Mbits/sec    0             sender
# [  5]   0.00-10.00  sec   232 MBytes   194 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-1 to k8s-worker-3: 115 Mbits/sec
# Full output from bandwidth-measurement-ds-gnsh9 to bandwidth-measurement-ds-nrznp:
# Connecting to host 192.168.231.226, port 5201
# [  5] local 192.168.230.44 port 42370 connected to 192.168.231.226 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  15.0 MBytes   125 Mbits/sec    0    799 KBytes
# [  5]   1.00-2.00   sec  16.8 MBytes   141 Mbits/sec    0   1.54 MBytes
# [  5]   2.00-3.00   sec  21.2 MBytes   178 Mbits/sec    0   2.60 MBytes
# [  5]   3.00-4.00   sec  26.2 MBytes   220 Mbits/sec    0   3.16 MBytes
# [  5]   4.00-5.00   sec  27.5 MBytes   231 Mbits/sec    0   3.16 MBytes
# [  5]   5.00-6.00   sec  25.0 MBytes   210 Mbits/sec    0   3.16 MBytes
# [  5]   6.00-7.00   sec  23.8 MBytes   199 Mbits/sec    2   2.21 MBytes
# [  5]   7.00-8.00   sec  23.8 MBytes   199 Mbits/sec    0   2.56 MBytes
# [  5]   8.00-9.00   sec  25.0 MBytes   210 Mbits/sec    0   2.83 MBytes
# [  5]   9.00-10.00  sec  25.0 MBytes   210 Mbits/sec    0   3.00 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   229 MBytes   192 Mbits/sec    2             sender
# [  5]   0.00-10.12  sec   229 MBytes   190 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-1 to k8s-worker-8: 125 Mbits/sec
# Full output from bandwidth-measurement-ds-gnsh9 to bandwidth-measurement-ds-r7ftn:
# Connecting to host 192.168.251.65, port 5201
# [  5] local 192.168.230.44 port 39640 connected to 192.168.251.65 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  52.0 MBytes   436 Mbits/sec    0   3.15 MBytes
# [  5]   1.00-2.00   sec  41.2 MBytes   346 Mbits/sec    0   3.15 MBytes
# [  5]   2.00-3.00   sec  31.2 MBytes   262 Mbits/sec    0   3.15 MBytes
# [  5]   3.00-4.00   sec  25.0 MBytes   210 Mbits/sec    1   2.30 MBytes
# [  5]   4.00-5.00   sec  21.2 MBytes   178 Mbits/sec    0   2.63 MBytes
# [  5]   5.00-6.00   sec  25.0 MBytes   210 Mbits/sec    0   2.87 MBytes
# [  5]   6.00-7.00   sec  22.5 MBytes   189 Mbits/sec    2   2.10 MBytes
# [  5]   7.00-8.00   sec  21.2 MBytes   178 Mbits/sec    0   2.30 MBytes
# [  5]   8.00-9.00   sec  21.2 MBytes   178 Mbits/sec    0   2.44 MBytes
# [  5]   9.00-10.00  sec  21.2 MBytes   178 Mbits/sec    0   2.52 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   282 MBytes   237 Mbits/sec    3             sender
# [  5]   0.00-10.11  sec   282 MBytes   234 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-1 to k8s-worker-9: 436 Mbits/sec
# Full output from bandwidth-measurement-ds-gnsh9 to bandwidth-measurement-ds-p2vgl:
# Connecting to host 192.168.18.232, port 5201
# [  5] local 192.168.230.44 port 34922 connected to 192.168.18.232 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  11.0 MBytes  91.9 Mbits/sec    0    678 KBytes
# [  5]   1.00-2.00   sec  13.7 MBytes   115 Mbits/sec    0   1.31 MBytes
# [  5]   2.00-3.00   sec  17.5 MBytes   147 Mbits/sec    0   2.16 MBytes
# [  5]   3.00-4.00   sec  18.8 MBytes   157 Mbits/sec   12   1.93 MBytes
# [  5]   4.00-5.00   sec  18.8 MBytes   157 Mbits/sec    0   2.23 MBytes
# [  5]   5.00-6.00   sec  21.2 MBytes   178 Mbits/sec    0   2.43 MBytes
# [  5]   6.00-7.00   sec  22.5 MBytes   189 Mbits/sec    0   2.55 MBytes
# [  5]   7.00-8.00   sec  25.0 MBytes   210 Mbits/sec    0   2.61 MBytes
# [  5]   8.00-9.00   sec  23.8 MBytes   199 Mbits/sec    0   2.63 MBytes
# [  5]   9.00-10.00  sec  23.8 MBytes   199 Mbits/sec    0   2.63 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   196 MBytes   164 Mbits/sec   12             sender
# [  5]   0.00-10.11  sec   195 MBytes   162 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-1 to k8s-worker-5: 91.9 Mbits/sec
# Full output from bandwidth-measurement-ds-gnsh9 to bandwidth-measurement-ds-vf5qp:
# Connecting to host 192.168.140.9, port 5201
# [  5] local 192.168.230.44 port 53736 connected to 192.168.140.9 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  18.1 MBytes   152 Mbits/sec    0    904 KBytes
# [  5]   1.00-2.00   sec  16.2 MBytes   136 Mbits/sec    0   1.66 MBytes
# [  5]   2.00-3.00   sec  18.8 MBytes   157 Mbits/sec    0   2.65 MBytes
# [  5]   3.00-4.00   sec  20.0 MBytes   168 Mbits/sec   35   2.21 MBytes
# [  5]   4.00-5.00   sec  21.2 MBytes   178 Mbits/sec    0   2.48 MBytes
# [  5]   5.00-6.00   sec  18.8 MBytes   157 Mbits/sec    5   43.4 KBytes
# [  5]   6.00-7.00   sec  22.5 MBytes   189 Mbits/sec    0   2.04 MBytes
# [  5]   7.00-8.00   sec  21.2 MBytes   178 Mbits/sec    0   2.16 MBytes
# [  5]   8.00-9.00   sec  20.0 MBytes   168 Mbits/sec    0   2.23 MBytes
# [  5]   9.00-10.00  sec  21.2 MBytes   178 Mbits/sec    0   2.25 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   198 MBytes   166 Mbits/sec   40             sender
# [  5]   0.00-10.11  sec   197 MBytes   163 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-1 to k8s-worker-2: 152 Mbits/sec
# Full output from bandwidth-measurement-ds-gnsh9 to bandwidth-measurement-ds-rfvj2:
# Connecting to host 192.168.227.155, port 5201
# [  5] local 192.168.230.44 port 49302 connected to 192.168.227.155 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  20.5 MBytes   172 Mbits/sec    0   1008 KBytes
# [  5]   1.00-2.00   sec  17.4 MBytes   146 Mbits/sec    0   1.84 MBytes
# [  5]   2.00-3.00   sec  21.2 MBytes   178 Mbits/sec    0   2.96 MBytes
# [  5]   3.00-4.00   sec  30.0 MBytes   252 Mbits/sec    0   3.15 MBytes
# [  5]   4.00-5.00   sec  26.2 MBytes   220 Mbits/sec    0   3.15 MBytes
# [  5]   5.00-6.00   sec  22.5 MBytes   189 Mbits/sec    1   2.86 MBytes
# [  5]   6.00-7.00   sec  26.2 MBytes   220 Mbits/sec    0   2.53 MBytes
# [  5]   7.00-8.00   sec  26.2 MBytes   220 Mbits/sec    0   2.81 MBytes
# [  5]   8.00-9.00   sec  27.5 MBytes   231 Mbits/sec    0   2.99 MBytes
# [  5]   9.00-10.00  sec  26.2 MBytes   220 Mbits/sec    0   3.03 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   244 MBytes   205 Mbits/sec    1             sender
# [  5]   0.00-10.11  sec   244 MBytes   203 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-1 to k8s-worker-6: 172 Mbits/sec
# Full output from bandwidth-measurement-ds-gnsh9 to bandwidth-measurement-ds-z29qn:
# Connecting to host 192.168.5.12, port 5201
# [  5] local 192.168.230.44 port 56914 connected to 192.168.5.12 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  41.9 MBytes   351 Mbits/sec    0   2.45 MBytes
# [  5]   1.00-2.00   sec  35.0 MBytes   294 Mbits/sec    0   3.13 MBytes
# [  5]   2.00-3.00   sec  28.8 MBytes   241 Mbits/sec    0   3.13 MBytes
# [  5]   3.00-4.00   sec  21.2 MBytes   178 Mbits/sec    5   2.44 MBytes
# [  5]   4.00-5.00   sec  22.5 MBytes   189 Mbits/sec    0   2.73 MBytes
# [  5]   5.00-6.00   sec  22.5 MBytes   189 Mbits/sec    2   2.03 MBytes
# [  5]   6.00-7.00   sec  23.8 MBytes   199 Mbits/sec    0   2.22 MBytes
# [  5]   7.00-8.00   sec  22.5 MBytes   189 Mbits/sec    0   2.36 MBytes
# [  5]   8.00-9.00   sec  23.8 MBytes   199 Mbits/sec    0   2.44 MBytes
# [  5]   9.00-10.00  sec  21.2 MBytes   178 Mbits/sec    0   2.46 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   263 MBytes   221 Mbits/sec    7             sender
# [  5]   0.00-10.10  sec   263 MBytes   218 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-1 to k8s-worker-7: 351 Mbits/sec
# Full output from bandwidth-measurement-ds-gnsh9 to bandwidth-measurement-ds-z4wqx:
# Connecting to host 192.168.79.76, port 5201
# [  5] local 192.168.230.44 port 59222 connected to 192.168.79.76 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  73.0 MBytes   612 Mbits/sec    0   3.17 MBytes
# [  5]   1.00-2.00   sec  68.8 MBytes   577 Mbits/sec    0   3.17 MBytes
# [  5]   2.00-3.00   sec  70.0 MBytes   587 Mbits/sec    0   3.17 MBytes
# [  5]   3.00-4.00   sec  68.8 MBytes   577 Mbits/sec    0   3.17 MBytes
# [  5]   4.00-5.00   sec  70.0 MBytes   587 Mbits/sec    0   3.17 MBytes
# [  5]   5.00-6.00   sec  68.8 MBytes   577 Mbits/sec    0   3.17 MBytes
# [  5]   6.00-7.00   sec  70.0 MBytes   587 Mbits/sec    0   3.17 MBytes
# [  5]   7.00-8.00   sec  68.8 MBytes   577 Mbits/sec    0   3.17 MBytes
# [  5]   8.00-9.00   sec  70.0 MBytes   587 Mbits/sec    0   3.17 MBytes
# [  5]   9.00-10.00  sec  68.8 MBytes   577 Mbits/sec    0   3.17 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   697 MBytes   584 Mbits/sec    0             sender
# [  5]   0.00-10.04  sec   697 MBytes   582 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-1 to k8s-worker-4: 612 Mbits/sec
# Full output from bandwidth-measurement-ds-nrznp to bandwidth-measurement-ds-gnsh9:
# Connecting to host 192.168.230.44, port 5201
# [  5] local 192.168.231.226 port 46016 connected to 192.168.230.44 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  26.1 MBytes   219 Mbits/sec    0   1.65 MBytes
# [  5]   1.00-2.00   sec  20.0 MBytes   168 Mbits/sec    0   2.69 MBytes
# [  5]   2.00-3.00   sec  26.2 MBytes   220 Mbits/sec    0   3.13 MBytes
# [  5]   3.00-4.00   sec  27.5 MBytes   231 Mbits/sec    0   3.13 MBytes
# [  5]   4.00-5.00   sec  26.2 MBytes   220 Mbits/sec    0   3.13 MBytes
# [  5]   5.00-6.00   sec  26.2 MBytes   220 Mbits/sec    0   3.13 MBytes
# [  5]   6.00-7.00   sec  26.2 MBytes   220 Mbits/sec    0   3.13 MBytes
# [  5]   7.00-8.00   sec  26.2 MBytes   220 Mbits/sec    0   3.13 MBytes
# [  5]   8.00-9.00   sec  27.5 MBytes   231 Mbits/sec    0   3.13 MBytes
# [  5]   9.00-10.00  sec  26.2 MBytes   220 Mbits/sec    0   3.13 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   259 MBytes   217 Mbits/sec    0             sender
# [  5]   0.00-10.07  sec   258 MBytes   215 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-8 to k8s-worker-1: 219 Mbits/sec
# Full output from bandwidth-measurement-ds-nrznp to bandwidth-measurement-ds-6dldb:
# Connecting to host 192.168.69.209, port 5201
# [  5] local 192.168.231.226 port 53576 connected to 192.168.69.209 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  48.8 MBytes   409 Mbits/sec    0   2.44 MBytes
# [  5]   1.00-2.00   sec  48.8 MBytes   409 Mbits/sec    0   3.16 MBytes
# [  5]   2.00-3.00   sec  42.5 MBytes   357 Mbits/sec    0   3.16 MBytes
# [  5]   3.00-4.00   sec  43.8 MBytes   367 Mbits/sec    0   3.16 MBytes
# [  5]   4.00-5.00   sec  42.5 MBytes   357 Mbits/sec    0   3.16 MBytes
# [  5]   5.00-6.00   sec  42.5 MBytes   357 Mbits/sec    0   3.16 MBytes
# [  5]   6.00-7.00   sec  43.8 MBytes   367 Mbits/sec    0   3.16 MBytes
# [  5]   7.00-8.00   sec  42.5 MBytes   357 Mbits/sec    0   3.16 MBytes
# [  5]   8.00-9.00   sec  42.5 MBytes   357 Mbits/sec    0   3.16 MBytes
# [  5]   9.00-10.00  sec  43.8 MBytes   367 Mbits/sec    0   3.16 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   441 MBytes   370 Mbits/sec    0             sender
# [  5]   0.00-10.07  sec   440 MBytes   367 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-8 to k8s-worker-3: 409 Mbits/sec
# Full output from bandwidth-measurement-ds-nrznp to bandwidth-measurement-ds-rfvj2:
# Connecting to host 192.168.227.155, port 5201
# [  5] local 192.168.231.226 port 52788 connected to 192.168.227.155 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  39.4 MBytes   330 Mbits/sec    0   2.44 MBytes
# [  5]   1.00-2.00   sec  33.8 MBytes   283 Mbits/sec    0   3.17 MBytes
# [  5]   2.00-3.00   sec  26.2 MBytes   220 Mbits/sec    0   3.17 MBytes
# [  5]   3.00-4.00   sec  27.5 MBytes   231 Mbits/sec    0   3.17 MBytes
# [  5]   4.00-5.00   sec  26.2 MBytes   220 Mbits/sec    0   3.17 MBytes
# [  5]   5.00-6.00   sec  25.0 MBytes   210 Mbits/sec    0   3.17 MBytes
# [  5]   6.00-7.00   sec  26.2 MBytes   220 Mbits/sec    0   3.17 MBytes
# [  5]   7.00-8.00   sec  26.2 MBytes   220 Mbits/sec    0   3.17 MBytes
# [  5]   8.00-9.00   sec  25.0 MBytes   210 Mbits/sec    0   3.17 MBytes
# [  5]   9.00-10.00  sec  25.0 MBytes   210 Mbits/sec    0   3.17 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   281 MBytes   235 Mbits/sec    0             sender
# [  5]   0.00-10.09  sec   280 MBytes   233 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-8 to k8s-worker-6: 330 Mbits/sec
# Full output from bandwidth-measurement-ds-nrznp to bandwidth-measurement-ds-p2vgl:
# Connecting to host 192.168.18.232, port 5201
# [  5] local 192.168.231.226 port 40070 connected to 192.168.18.232 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  27.6 MBytes   232 Mbits/sec    0   1.34 MBytes
# [  5]   1.00-2.00   sec  20.0 MBytes   168 Mbits/sec    0   2.40 MBytes
# [  5]   2.00-3.00   sec  25.0 MBytes   210 Mbits/sec    0   3.15 MBytes
# [  5]   3.00-4.00   sec  22.5 MBytes   189 Mbits/sec    2   2.38 MBytes
# [  5]   4.00-5.00   sec  22.5 MBytes   189 Mbits/sec    0   2.70 MBytes
# [  5]   5.00-6.00   sec  22.5 MBytes   189 Mbits/sec    0   2.90 MBytes
# [  5]   6.00-7.00   sec  26.2 MBytes   220 Mbits/sec    0   3.03 MBytes
# [  5]   7.00-8.00   sec  26.2 MBytes   220 Mbits/sec    0   3.03 MBytes
# [  5]   8.00-9.00   sec  26.2 MBytes   220 Mbits/sec    0   3.03 MBytes
# [  5]   9.00-10.00  sec  23.8 MBytes   199 Mbits/sec    0   3.03 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   243 MBytes   204 Mbits/sec    2             sender
# [  5]   0.00-10.12  sec   243 MBytes   201 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-8 to k8s-worker-5: 232 Mbits/sec
# Full output from bandwidth-measurement-ds-nrznp to bandwidth-measurement-ds-r7ftn:
# Connecting to host 192.168.251.65, port 5201
# [  5] local 192.168.231.226 port 45044 connected to 192.168.251.65 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  15.2 MBytes   127 Mbits/sec    0    895 KBytes
# [  5]   1.00-2.00   sec  14.8 MBytes   124 Mbits/sec    0   1.56 MBytes
# [  5]   2.00-3.00   sec  16.2 MBytes   136 Mbits/sec    0   2.43 MBytes
# [  5]   3.00-4.00   sec  21.2 MBytes   178 Mbits/sec    5   2.06 MBytes
# [  5]   4.00-5.00   sec  20.0 MBytes   168 Mbits/sec    0   2.32 MBytes
# [  5]   5.00-6.00   sec  18.8 MBytes   157 Mbits/sec    0   2.49 MBytes
# [  5]   6.00-7.00   sec  18.8 MBytes   157 Mbits/sec    1   1.86 MBytes
# [  5]   7.00-8.00   sec  17.5 MBytes   147 Mbits/sec    0   2.02 MBytes
# [  5]   8.00-9.00   sec  18.8 MBytes   157 Mbits/sec    0   2.11 MBytes
# [  5]   9.00-10.00  sec  17.5 MBytes   147 Mbits/sec    0   2.16 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   179 MBytes   150 Mbits/sec    6             sender
# [  5]   0.00-10.08  sec   178 MBytes   148 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-8 to k8s-worker-9: 127 Mbits/sec
# Full output from bandwidth-measurement-ds-nrznp to bandwidth-measurement-ds-vf5qp:
# Connecting to host 192.168.140.9, port 5201
# [  5] local 192.168.231.226 port 60672 connected to 192.168.140.9 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  14.6 MBytes   123 Mbits/sec    0    747 KBytes
# [  5]   1.00-2.00   sec  14.2 MBytes   119 Mbits/sec    0   1.44 MBytes
# [  5]   2.00-3.00   sec  20.0 MBytes   168 Mbits/sec    0   2.40 MBytes
# [  5]   3.00-4.00   sec  20.0 MBytes   168 Mbits/sec    4   2.11 MBytes
# [  5]   4.00-5.00   sec  20.0 MBytes   168 Mbits/sec    0   2.43 MBytes
# [  5]   5.00-6.00   sec  22.5 MBytes   189 Mbits/sec    0   2.63 MBytes
# [  5]   6.00-7.00   sec  21.2 MBytes   178 Mbits/sec    1   1.98 MBytes
# [  5]   7.00-8.00   sec  18.8 MBytes   157 Mbits/sec    0   2.15 MBytes
# [  5]   8.00-9.00   sec  21.2 MBytes   178 Mbits/sec    0   2.24 MBytes
# [  5]   9.00-10.00  sec  21.2 MBytes   178 Mbits/sec    0   2.28 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   194 MBytes   163 Mbits/sec    5             sender
# [  5]   0.00-10.11  sec   193 MBytes   160 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-8 to k8s-worker-2: 123 Mbits/sec
# Full output from bandwidth-measurement-ds-nrznp to bandwidth-measurement-ds-z4wqx:
# Connecting to host 192.168.79.76, port 5201
# [  5] local 192.168.231.226 port 51012 connected to 192.168.79.76 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  46.8 MBytes   392 Mbits/sec    0   3.15 MBytes
# [  5]   1.00-2.00   sec  41.2 MBytes   346 Mbits/sec    0   3.15 MBytes
# [  5]   2.00-3.00   sec  28.8 MBytes   241 Mbits/sec    0   3.15 MBytes
# [  5]   3.00-4.00   sec  28.8 MBytes   241 Mbits/sec    0   3.15 MBytes
# [  5]   4.00-5.00   sec  26.2 MBytes   220 Mbits/sec    0   3.15 MBytes
# [  5]   5.00-6.00   sec  26.2 MBytes   220 Mbits/sec    0   3.15 MBytes
# [  5]   6.00-7.00   sec  26.2 MBytes   220 Mbits/sec    0   3.15 MBytes
# [  5]   7.00-8.00   sec  30.0 MBytes   252 Mbits/sec    0   3.15 MBytes
# [  5]   8.00-9.00   sec  26.2 MBytes   220 Mbits/sec    0   3.15 MBytes
# [  5]   9.00-10.00  sec  26.2 MBytes   220 Mbits/sec    0   3.15 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   307 MBytes   257 Mbits/sec    0             sender
# [  5]   0.00-10.10  sec   307 MBytes   255 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-8 to k8s-worker-4: 392 Mbits/sec
# Full output from bandwidth-measurement-ds-nrznp to bandwidth-measurement-ds-z29qn:
# Connecting to host 192.168.5.12, port 5201
# [  5] local 192.168.231.226 port 35270 connected to 192.168.5.12 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  14.9 MBytes   125 Mbits/sec    0    791 KBytes
# [  5]   1.00-2.00   sec  16.8 MBytes   141 Mbits/sec    0   1.54 MBytes
# [  5]   2.00-3.00   sec  18.8 MBytes   157 Mbits/sec    0   2.50 MBytes
# [  5]   3.00-4.00   sec  21.2 MBytes   178 Mbits/sec   23   2.23 MBytes
# [  5]   4.00-5.00   sec  21.2 MBytes   178 Mbits/sec    0   2.55 MBytes
# [  5]   5.00-6.00   sec  23.8 MBytes   199 Mbits/sec    0   2.77 MBytes
# [  5]   6.00-7.00   sec  20.0 MBytes   168 Mbits/sec    3   2.06 MBytes
# [  5]   7.00-8.00   sec  21.2 MBytes   178 Mbits/sec    0   2.24 MBytes
# [  5]   8.00-9.00   sec  20.0 MBytes   168 Mbits/sec    0   2.34 MBytes
# [  5]   9.00-10.00  sec  22.5 MBytes   189 Mbits/sec    0   2.39 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   200 MBytes   168 Mbits/sec   26             sender
# [  5]   0.00-10.11  sec   199 MBytes   165 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-8 to k8s-worker-7: 125 Mbits/sec
# Full output from bandwidth-measurement-ds-p2vgl to bandwidth-measurement-ds-gnsh9:
# Connecting to host 192.168.230.44, port 5201
# [  5] local 192.168.18.232 port 47784 connected to 192.168.230.44 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  20.9 MBytes   175 Mbits/sec    0   1.04 MBytes
# [  5]   1.00-2.00   sec  18.8 MBytes   157 Mbits/sec    0   1.96 MBytes
# [  5]   2.00-3.00   sec  26.2 MBytes   220 Mbits/sec   13   2.09 MBytes
# [  5]   3.00-4.00   sec  25.0 MBytes   210 Mbits/sec    0   2.44 MBytes
# [  5]   4.00-5.00   sec  26.2 MBytes   220 Mbits/sec    0   2.66 MBytes
# [  5]   5.00-6.00   sec  25.0 MBytes   210 Mbits/sec    5   1.99 MBytes
# [  5]   6.00-7.00   sec  26.2 MBytes   220 Mbits/sec    0   2.17 MBytes
# [  5]   7.00-8.00   sec  25.0 MBytes   210 Mbits/sec    0   2.27 MBytes
# [  5]   8.00-9.00   sec  25.0 MBytes   210 Mbits/sec    0   2.33 MBytes
# [  5]   9.00-10.00  sec  26.2 MBytes   220 Mbits/sec    0   2.33 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   245 MBytes   205 Mbits/sec   18             sender
# [  5]   0.00-10.09  sec   243 MBytes   202 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-5 to k8s-worker-1: 175 Mbits/sec
# Full output from bandwidth-measurement-ds-p2vgl to bandwidth-measurement-ds-6dldb:
# Connecting to host 192.168.69.209, port 5201
# [  5] local 192.168.18.232 port 52836 connected to 192.168.69.209 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  23.8 MBytes   199 Mbits/sec    0   1.13 MBytes
# [  5]   1.00-2.00   sec  20.0 MBytes   168 Mbits/sec    0   2.15 MBytes
# [  5]   2.00-3.00   sec  25.0 MBytes   210 Mbits/sec   18   2.21 MBytes
# [  5]   3.00-4.00   sec  27.5 MBytes   231 Mbits/sec    0   2.56 MBytes
# [  5]   4.00-5.00   sec  26.2 MBytes   220 Mbits/sec    0   2.81 MBytes
# [  5]   5.00-6.00   sec  28.8 MBytes   241 Mbits/sec    1   2.11 MBytes
# [  5]   6.00-7.00   sec  26.2 MBytes   220 Mbits/sec    0   2.29 MBytes
# [  5]   7.00-8.00   sec  27.5 MBytes   231 Mbits/sec    0   2.41 MBytes
# [  5]   8.00-9.00   sec  26.2 MBytes   220 Mbits/sec    0   2.46 MBytes
# [  5]   9.00-10.00  sec  27.5 MBytes   231 Mbits/sec    0   2.47 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   259 MBytes   217 Mbits/sec   19             sender
# [  5]   0.00-10.09  sec   258 MBytes   215 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-5 to k8s-worker-3: 199 Mbits/sec
# Full output from bandwidth-measurement-ds-p2vgl to bandwidth-measurement-ds-nrznp:
# Connecting to host 192.168.231.226, port 5201
# [  5] local 192.168.18.232 port 48990 connected to 192.168.231.226 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  46.8 MBytes   392 Mbits/sec    0   2.77 MBytes
# [  5]   1.00-2.00   sec  37.5 MBytes   315 Mbits/sec    0   3.16 MBytes
# [  5]   2.00-3.00   sec  28.8 MBytes   241 Mbits/sec   16   2.26 MBytes
# [  5]   3.00-4.00   sec  28.8 MBytes   241 Mbits/sec    0   2.62 MBytes
# [  5]   4.00-5.00   sec  27.5 MBytes   231 Mbits/sec    0   2.86 MBytes
# [  5]   5.00-6.00   sec  25.0 MBytes   210 Mbits/sec    3   2.14 MBytes
# [  5]   6.00-7.00   sec  26.2 MBytes   220 Mbits/sec    0   2.33 MBytes
# [  5]   7.00-8.00   sec  28.8 MBytes   241 Mbits/sec    0   2.44 MBytes
# [  5]   8.00-9.00   sec  27.5 MBytes   231 Mbits/sec    0   2.49 MBytes
# [  5]   9.00-10.00  sec  26.2 MBytes   220 Mbits/sec    0   2.49 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   303 MBytes   254 Mbits/sec   19             sender
# [  5]   0.00-10.09  sec   303 MBytes   252 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-5 to k8s-worker-8: 392 Mbits/sec
# Full output from bandwidth-measurement-ds-p2vgl to bandwidth-measurement-ds-rfvj2:
# Connecting to host 192.168.227.155, port 5201
# [  5] local 192.168.18.232 port 52646 connected to 192.168.227.155 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  46.8 MBytes   392 Mbits/sec    0   2.69 MBytes
# [  5]   1.00-2.00   sec  37.5 MBytes   315 Mbits/sec    0   3.16 MBytes
# [  5]   2.00-3.00   sec  28.8 MBytes   241 Mbits/sec    3   2.30 MBytes
# [  5]   3.00-4.00   sec  25.0 MBytes   210 Mbits/sec    0   2.64 MBytes
# [  5]   4.00-5.00   sec  26.2 MBytes   220 Mbits/sec    0   2.88 MBytes
# [  5]   5.00-6.00   sec  32.5 MBytes   273 Mbits/sec    0   3.02 MBytes
# [  5]   6.00-7.00   sec  31.2 MBytes   262 Mbits/sec    0   3.02 MBytes
# [  5]   7.00-8.00   sec  28.8 MBytes   241 Mbits/sec    0   3.02 MBytes
# [  5]   8.00-9.00   sec  30.0 MBytes   252 Mbits/sec    0   3.02 MBytes
# [  5]   9.00-10.00  sec  28.8 MBytes   241 Mbits/sec    0   3.02 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   316 MBytes   265 Mbits/sec    3             sender
# [  5]   0.00-10.10  sec   315 MBytes   262 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-5 to k8s-worker-6: 392 Mbits/sec
# Full output from bandwidth-measurement-ds-p2vgl to bandwidth-measurement-ds-vf5qp:
# Connecting to host 192.168.140.9, port 5201
# [  5] local 192.168.18.232 port 36628 connected to 192.168.140.9 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  22.0 MBytes   185 Mbits/sec    0   1.09 MBytes
# [  5]   1.00-2.00   sec  20.0 MBytes   168 Mbits/sec    0   2.05 MBytes
# [  5]   2.00-3.00   sec  27.5 MBytes   231 Mbits/sec    0   3.17 MBytes
# [  5]   3.00-4.00   sec  31.2 MBytes   262 Mbits/sec    0   3.17 MBytes
# [  5]   4.00-5.00   sec  27.5 MBytes   231 Mbits/sec    0   3.17 MBytes
# [  5]   5.00-6.00   sec  25.0 MBytes   210 Mbits/sec    9   2.47 MBytes
# [  5]   6.00-7.00   sec  27.5 MBytes   231 Mbits/sec    0   2.77 MBytes
# [  5]   7.00-8.00   sec  28.8 MBytes   241 Mbits/sec    0   2.96 MBytes
# [  5]   8.00-9.00   sec  28.8 MBytes   241 Mbits/sec    0   3.02 MBytes
# [  5]   9.00-10.00  sec  30.0 MBytes   252 Mbits/sec    0   3.02 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   268 MBytes   225 Mbits/sec    9             sender
# [  5]   0.00-10.10  sec   267 MBytes   222 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-5 to k8s-worker-2: 185 Mbits/sec
# Full output from bandwidth-measurement-ds-p2vgl to bandwidth-measurement-ds-r7ftn:
# Connecting to host 192.168.251.65, port 5201
# [  5] local 192.168.18.232 port 52186 connected to 192.168.251.65 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  22.8 MBytes   191 Mbits/sec    0   1.09 MBytes
# [  5]   1.00-2.00   sec  21.2 MBytes   178 Mbits/sec    0   2.15 MBytes
# [  5]   2.00-3.00   sec  22.5 MBytes   189 Mbits/sec   12   2.10 MBytes
# [  5]   3.00-4.00   sec  23.8 MBytes   199 Mbits/sec    0   2.44 MBytes
# [  5]   4.00-5.00   sec  25.0 MBytes   210 Mbits/sec    0   2.66 MBytes
# [  5]   5.00-6.00   sec  23.8 MBytes   199 Mbits/sec    2   2.02 MBytes
# [  5]   6.00-7.00   sec  20.0 MBytes   168 Mbits/sec    0   2.16 MBytes
# [  5]   7.00-8.00   sec  22.5 MBytes   189 Mbits/sec    0   2.25 MBytes
# [  5]   8.00-9.00   sec  22.5 MBytes   189 Mbits/sec    0   2.28 MBytes
# [  5]   9.00-10.00  sec  22.5 MBytes   189 Mbits/sec    0   2.28 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   226 MBytes   190 Mbits/sec   14             sender
# [  5]   0.00-10.10  sec   225 MBytes   187 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-5 to k8s-worker-9: 191 Mbits/sec
# Full output from bandwidth-measurement-ds-r7ftn to bandwidth-measurement-ds-6dldb:
# Connecting to host 192.168.69.209, port 5201
# [  5] local 192.168.251.65 port 42976 connected to 192.168.69.209 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  93.1 MBytes   781 Mbits/sec    0   3.15 MBytes
# [  5]   1.00-2.00   sec  90.0 MBytes   755 Mbits/sec    0   3.15 MBytes
# [  5]   2.00-3.00   sec  90.0 MBytes   755 Mbits/sec    0   3.15 MBytes
# [  5]   3.00-4.00   sec  90.0 MBytes   755 Mbits/sec    0   3.15 MBytes
# [  5]   4.00-5.00   sec  90.0 MBytes   755 Mbits/sec    0   3.15 MBytes
# [  5]   5.00-6.00   sec  90.0 MBytes   755 Mbits/sec    0   3.15 MBytes
# [  5]   6.00-7.00   sec  88.8 MBytes   744 Mbits/sec    0   3.15 MBytes
# [  5]   7.00-8.00   sec  90.0 MBytes   755 Mbits/sec    0   3.15 MBytes
# [  5]   8.00-9.00   sec  90.0 MBytes   755 Mbits/sec    0   3.15 MBytes
# [  5]   9.00-10.00  sec  90.0 MBytes   755 Mbits/sec    0   3.15 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   902 MBytes   757 Mbits/sec    0             sender
# [  5]   0.00-10.03  sec   902 MBytes   754 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-9 to k8s-worker-3: 781 Mbits/sec
# Full output from bandwidth-measurement-ds-p2vgl to bandwidth-measurement-ds-z29qn:
# Connecting to host 192.168.5.12, port 5201
# [  5] local 192.168.18.232 port 38368 connected to 192.168.5.12 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  58.1 MBytes   488 Mbits/sec    0   3.15 MBytes
# [  5]   1.00-2.00   sec  45.0 MBytes   377 Mbits/sec    0   3.15 MBytes
# [  5]   2.00-3.00   sec  41.2 MBytes   346 Mbits/sec    0   3.15 MBytes
# [  5]   3.00-4.00   sec  38.8 MBytes   325 Mbits/sec    0   3.15 MBytes
# [  5]   4.00-5.00   sec  40.0 MBytes   336 Mbits/sec    0   3.15 MBytes
# [  5]   5.00-6.00   sec  41.2 MBytes   346 Mbits/sec    0   3.15 MBytes
# [  5]   6.00-7.00   sec  38.8 MBytes   325 Mbits/sec    0   3.15 MBytes
# [  5]   7.00-8.00   sec  40.0 MBytes   336 Mbits/sec    0   3.15 MBytes
# [  5]   8.00-9.00   sec  40.0 MBytes   336 Mbits/sec    0   3.15 MBytes
# [  5]   9.00-10.00  sec  40.0 MBytes   336 Mbits/sec    0   3.15 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   423 MBytes   355 Mbits/sec    0             sender
# [  5]   0.00-10.07  sec   423 MBytes   352 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-5 to k8s-worker-7: 488 Mbits/sec
# Full output from bandwidth-measurement-ds-p2vgl to bandwidth-measurement-ds-z4wqx:
# Connecting to host 192.168.79.76, port 5201
# [  5] local 192.168.18.232 port 53602 connected to 192.168.79.76 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  29.6 MBytes   248 Mbits/sec    0   1.43 MBytes
# [  5]   1.00-2.00   sec  32.5 MBytes   273 Mbits/sec    0   3.09 MBytes
# [  5]   2.00-3.00   sec  41.2 MBytes   346 Mbits/sec    0   3.17 MBytes
# [  5]   3.00-4.00   sec  38.8 MBytes   325 Mbits/sec    0   3.17 MBytes
# [  5]   4.00-5.00   sec  40.0 MBytes   336 Mbits/sec    0   3.17 MBytes
# [  5]   5.00-6.00   sec  41.2 MBytes   346 Mbits/sec    0   3.17 MBytes
# [  5]   6.00-7.00   sec  38.8 MBytes   325 Mbits/sec    0   3.17 MBytes
# [  5]   7.00-8.00   sec  40.0 MBytes   336 Mbits/sec    0   3.17 MBytes
# [  5]   8.00-9.00   sec  40.0 MBytes   336 Mbits/sec    0   3.17 MBytes
# [  5]   9.00-10.00  sec  41.2 MBytes   346 Mbits/sec    0   3.17 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   383 MBytes   322 Mbits/sec    0             sender
# [  5]   0.00-10.07  sec   383 MBytes   319 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-5 to k8s-worker-4: 248 Mbits/sec
# Full output from bandwidth-measurement-ds-r7ftn to bandwidth-measurement-ds-gnsh9:
# Connecting to host 192.168.230.44, port 5201
# [  5] local 192.168.251.65 port 43294 connected to 192.168.230.44 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  50.6 MBytes   425 Mbits/sec    1   1.32 MBytes
# [  5]   1.00-2.00   sec  28.8 MBytes   241 Mbits/sec    0   1.41 MBytes
# [  5]   2.00-3.00   sec  23.8 MBytes   199 Mbits/sec    0   1.49 MBytes
# [  5]   3.00-4.00   sec  23.8 MBytes   199 Mbits/sec    0   1.55 MBytes
# [  5]   4.00-5.00   sec  25.0 MBytes   210 Mbits/sec    0   1.63 MBytes
# [  5]   5.00-6.00   sec  25.0 MBytes   210 Mbits/sec    0   1.82 MBytes
# [  5]   6.00-7.00   sec  27.5 MBytes   231 Mbits/sec    0   2.19 MBytes
# [  5]   7.00-8.00   sec  28.8 MBytes   241 Mbits/sec    0   2.70 MBytes
# [  5]   8.00-9.00   sec  30.0 MBytes   252 Mbits/sec    2   2.22 MBytes
# [  5]   9.00-10.00  sec  31.2 MBytes   262 Mbits/sec    0   2.54 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   294 MBytes   247 Mbits/sec    3             sender
# [  5]   0.00-10.08  sec   293 MBytes   244 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-9 to k8s-worker-1: 425 Mbits/sec
# Full output from bandwidth-measurement-ds-r7ftn to bandwidth-measurement-ds-p2vgl:
# Connecting to host 192.168.18.232, port 5201
# [  5] local 192.168.251.65 port 45960 connected to 192.168.18.232 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  24.8 MBytes   208 Mbits/sec    0   1.32 MBytes
# [  5]   1.00-2.00   sec  42.5 MBytes   357 Mbits/sec    0   3.14 MBytes
# [  5]   2.00-3.00   sec  46.2 MBytes   388 Mbits/sec    0   3.14 MBytes
# ...
# [  5]   4.00-5.00   sec  28.8 MBytes   241 Mbits/sec    0   3.15 MBytes
# [  5]   5.00-6.00   sec  23.8 MBytes   199 Mbits/sec   19   2.27 MBytes
# [  5]   6.00-7.00   sec  21.2 MBytes   178 Mbits/sec    0   2.60 MBytes
# [  5]   7.00-8.00   sec  27.5 MBytes   231 Mbits/sec    0   2.86 MBytes
# [  5]   8.00-9.00   sec  26.2 MBytes   220 Mbits/sec    0   3.02 MBytes
# [  5]   9.00-10.00  sec  26.2 MBytes   220 Mbits/sec    0   3.02 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   301 MBytes   252 Mbits/sec   19             sender
# [  5]   0.00-10.11  sec   300 MBytes   249 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-7 to k8s-worker-6: 364 Mbits/sec
# Full output from bandwidth-measurement-ds-z29qn to bandwidth-measurement-ds-z4wqx:
# Connecting to host 192.168.79.76, port 5201
# [  5] local 192.168.5.12 port 57034 connected to 192.168.79.76 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  16.7 MBytes   140 Mbits/sec    0    834 KBytes
# [  5]   1.00-2.00   sec  12.2 MBytes   102 Mbits/sec    0   1.43 MBytes
# [  5]   2.00-3.00   sec  13.8 MBytes   115 Mbits/sec    0   2.07 MBytes
# [  5]   3.00-4.00   sec  16.2 MBytes   136 Mbits/sec    0   2.91 MBytes
# [  5]   4.00-5.00   sec  15.0 MBytes   126 Mbits/sec    0   3.13 MBytes
# [  5]   5.00-6.00   sec  13.8 MBytes   115 Mbits/sec    0   3.13 MBytes
# [  5]   6.00-7.00   sec  12.5 MBytes   105 Mbits/sec    0   3.13 MBytes
# [  5]   7.00-8.00   sec  12.5 MBytes   105 Mbits/sec    0   3.13 MBytes
# [  5]   8.00-9.00   sec  12.5 MBytes   105 Mbits/sec    0   3.13 MBytes
# [  5]   9.00-10.00  sec  12.5 MBytes   105 Mbits/sec    0   3.13 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   138 MBytes   115 Mbits/sec    0             sender
# [  5]   0.00-10.00  sec   137 MBytes   115 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-7 to k8s-worker-4: 140 Mbits/sec
# Full output from bandwidth-measurement-ds-z4wqx to bandwidth-measurement-ds-6dldb:
# Connecting to host 192.168.69.209, port 5201
# [  5] local 192.168.79.76 port 55614 connected to 192.168.69.209 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  7.27 MBytes  61.0 Mbits/sec    0    400 KBytes
# [  5]   1.00-2.00   sec  6.12 MBytes  51.3 Mbits/sec    0    686 KBytes
# [  5]   2.00-3.00   sec  7.19 MBytes  60.3 Mbits/sec    0   1008 KBytes
# [  5]   3.00-4.00   sec  8.67 MBytes  72.7 Mbits/sec    0   1.38 MBytes
# [  5]   4.00-5.00   sec  8.75 MBytes  73.4 Mbits/sec    0   1.85 MBytes
# [  5]   5.00-6.00   sec  12.5 MBytes   105 Mbits/sec    0   2.44 MBytes
# [  5]   6.00-7.00   sec  12.5 MBytes   105 Mbits/sec    0   3.07 MBytes
# [  5]   7.00-8.00   sec  12.5 MBytes   105 Mbits/sec    0   3.15 MBytes
# [  5]   8.00-9.00   sec  12.5 MBytes   105 Mbits/sec    0   3.15 MBytes
# [  5]   9.00-10.00  sec  12.5 MBytes   105 Mbits/sec    0   3.15 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   100 MBytes  84.3 Mbits/sec    0             sender
# [  5]   0.00-10.21  sec   100 MBytes  82.5 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-4 to k8s-worker-3: 61.0 Mbits/sec
# Full output from bandwidth-measurement-ds-z4wqx to bandwidth-measurement-ds-gnsh9:
# Connecting to host 192.168.230.44, port 5201
# [  5] local 192.168.79.76 port 50000 connected to 192.168.230.44 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  22.9 MBytes   192 Mbits/sec    0   1.29 MBytes
# [  5]   1.00-2.00   sec  18.8 MBytes   157 Mbits/sec    0   2.27 MBytes
# [  5]   2.00-3.00   sec  20.0 MBytes   168 Mbits/sec    0   3.16 MBytes
# [  5]   3.00-4.00   sec  16.2 MBytes   136 Mbits/sec    0   3.16 MBytes
# [  5]   4.00-5.00   sec  16.2 MBytes   136 Mbits/sec    0   3.16 MBytes
# [  5]   5.00-6.00   sec  12.5 MBytes   105 Mbits/sec    0   3.16 MBytes
# [  5]   6.00-7.00   sec  12.5 MBytes   105 Mbits/sec    0   3.16 MBytes
# [  5]   7.00-8.00   sec  12.5 MBytes   105 Mbits/sec    0   3.16 MBytes
# [  5]   8.00-9.00   sec  12.5 MBytes   105 Mbits/sec    0   3.16 MBytes
# [  5]   9.00-10.00  sec  12.5 MBytes   105 Mbits/sec    0   3.16 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   157 MBytes   131 Mbits/sec    0             sender
# [  5]   0.00-10.20  sec   157 MBytes   129 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-4 to k8s-worker-1: 192 Mbits/sec
# Full output from bandwidth-measurement-ds-z4wqx to bandwidth-measurement-ds-r7ftn:
# Connecting to host 192.168.251.65, port 5201
# [  5] local 192.168.79.76 port 54582 connected to 192.168.251.65 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  13.2 MBytes   110 Mbits/sec    0    747 KBytes
# [  5]   1.00-2.00   sec  10.5 MBytes  87.8 Mbits/sec    0   1.22 MBytes
# [  5]   2.00-3.00   sec  10.0 MBytes  83.9 Mbits/sec    0   1.73 MBytes
# [  5]   3.00-4.00   sec  10.0 MBytes  83.9 Mbits/sec    0   2.27 MBytes
# [  5]   4.00-5.00   sec  11.2 MBytes  94.4 Mbits/sec    0   2.81 MBytes
# [  5]   5.00-6.00   sec  11.2 MBytes  94.4 Mbits/sec    0   3.14 MBytes
# [  5]   6.00-7.00   sec  10.0 MBytes  83.9 Mbits/sec    0   3.14 MBytes
# [  5]   7.00-8.00   sec  7.50 MBytes  62.9 Mbits/sec    0   3.14 MBytes
# [  5]   8.00-9.00   sec  10.0 MBytes  83.9 Mbits/sec    0   3.14 MBytes
# [  5]   9.00-10.00  sec  8.75 MBytes  73.4 Mbits/sec    0   3.14 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   102 MBytes  85.9 Mbits/sec    0             sender
# [  5]   0.00-10.30  sec   102 MBytes  82.9 Mbits/sec                  receiver
#
# iperf Done.
# Full output from bandwidth-measurement-ds-z4wqx to bandwidth-measurement-ds-nrznp:
# Connecting to host 192.168.231.226, port 5201
# [  5] local 192.168.79.76 port 55594 connected to 192.168.231.226 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  5.96 MBytes  50.0 Mbits/sec    0    417 KBytes
# [  5]   1.00-2.00   sec  6.12 MBytes  51.3 Mbits/sec    0    713 KBytes
# [  5]   2.00-3.00   sec  7.42 MBytes  62.3 Mbits/sec    0   1008 KBytes
# [  5]   3.00-4.00   sec  5.00 MBytes  41.9 Mbits/sec    0   1.26 MBytes
# [  5]   4.00-5.00   sec  7.50 MBytes  62.9 Mbits/sec    0   1.60 MBytes
# [  5]   5.00-6.00   sec  6.25 MBytes  52.4 Mbits/sec    0   1.93 MBytes
# [  5]   6.00-7.00   sec  8.75 MBytes  73.4 Mbits/sec    0   2.35 MBytes
# [  5]   7.00-8.00   sec  8.75 MBytes  73.4 Mbits/sec    0   2.83 MBytes
# [  5]   8.00-9.00   sec  8.75 MBytes  73.4 Mbits/sec    0   3.16 MBytes
# [  5]   9.00-10.00  sec  8.75 MBytes  73.4 Mbits/sec    0   3.16 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec  73.2 MBytes  61.4 Mbits/sec    0             sender
# [  5]   0.00-10.30  sec  73.2 MBytes  59.6 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-4 to k8s-worker-8: 50.0 Mbits/sec
#
# Bandwidth from k8s-worker-4 to k8s-worker-9: 110 Mbits/sec
# Full output from bandwidth-measurement-ds-z4wqx to bandwidth-measurement-ds-p2vgl:
# Connecting to host 192.168.18.232, port 5201
# [  5] local 192.168.79.76 port 49886 connected to 192.168.18.232 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  12.7 MBytes   107 Mbits/sec    0    686 KBytes
# [  5]   1.00-2.00   sec  11.0 MBytes  92.4 Mbits/sec    0   1.14 MBytes
# [  5]   2.00-3.00   sec  10.0 MBytes  83.9 Mbits/sec    0   1.63 MBytes
# [  5]   3.00-4.00   sec  8.75 MBytes  73.4 Mbits/sec    0   2.10 MBytes
# [  5]   4.00-5.00   sec  7.50 MBytes  62.9 Mbits/sec    1   1.64 MBytes
# [  5]   5.00-6.00   sec  7.50 MBytes  62.9 Mbits/sec    0   1.85 MBytes
# [  5]   6.00-7.00   sec  7.50 MBytes  62.9 Mbits/sec    0   1.99 MBytes
# [  5]   7.00-8.00   sec  7.50 MBytes  62.9 Mbits/sec    0   2.07 MBytes
# [  5]   8.00-9.00   sec  6.25 MBytes  52.4 Mbits/sec    0   2.10 MBytes
# [  5]   9.00-10.00  sec  7.50 MBytes  62.9 Mbits/sec    0   2.10 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec  86.2 MBytes  72.4 Mbits/sec    1             sender
# [  5]   0.00-10.29  sec  85.6 MBytes  69.8 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-4 to k8s-worker-5: 107 Mbits/sec
# Full output from bandwidth-measurement-ds-z4wqx to bandwidth-measurement-ds-rfvj2:
# Connecting to host 192.168.227.155, port 5201
# [  5] local 192.168.79.76 port 38842 connected to 192.168.227.155 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  14.6 MBytes   123 Mbits/sec    0    965 KBytes
# [  5]   1.00-2.00   sec  13.6 MBytes   114 Mbits/sec    0   1.59 MBytes
# [  5]   2.00-3.00   sec  12.5 MBytes   105 Mbits/sec    0   2.20 MBytes
# [  5]   3.00-4.00   sec  12.5 MBytes   105 Mbits/sec    0   2.83 MBytes
# [  5]   4.00-5.00   sec  10.0 MBytes  83.9 Mbits/sec    0   3.15 MBytes
# [  5]   5.00-6.00   sec  10.0 MBytes  83.9 Mbits/sec    0   3.15 MBytes
# [  5]   6.00-7.00   sec  10.0 MBytes  83.9 Mbits/sec    0   3.15 MBytes
# [  5]   7.00-8.00   sec  7.50 MBytes  62.9 Mbits/sec    0   3.15 MBytes
# [  5]   8.00-9.00   sec  7.50 MBytes  62.9 Mbits/sec    0   3.15 MBytes
# [  5]   9.00-10.00  sec  8.75 MBytes  73.4 Mbits/sec    1   2.20 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   107 MBytes  89.8 Mbits/sec    1             sender
# [  5]   0.00-10.31  sec   107 MBytes  86.8 Mbits/sec                  receiver
#
# iperf Done.
# Full output from bandwidth-measurement-ds-z4wqx to bandwidth-measurement-ds-z29qn:
# Connecting to host 192.168.5.12, port 5201
# [  5] local 192.168.79.76 port 60808 connected to 192.168.5.12 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  7.15 MBytes  60.0 Mbits/sec    0    495 KBytes
# [  5]   1.00-2.00   sec  7.25 MBytes  60.8 Mbits/sec    0    808 KBytes
# [  5]   2.00-3.00   sec  6.85 MBytes  57.5 Mbits/sec    0   1.11 MBytes
# [  5]   3.00-4.00   sec  6.25 MBytes  52.4 Mbits/sec    0   1.43 MBytes
# [  5]   4.00-5.00   sec  7.50 MBytes  62.9 Mbits/sec    0   1.80 MBytes
# [  5]   5.00-6.00   sec  7.50 MBytes  62.9 Mbits/sec    0   2.16 MBytes
# [  5]   6.00-7.00   sec  7.50 MBytes  62.9 Mbits/sec    0   2.55 MBytes
# [  5]   7.00-8.00   sec  7.50 MBytes  62.9 Mbits/sec    0   2.94 MBytes
# [  5]   8.00-9.00   sec  10.0 MBytes  83.9 Mbits/sec    0   3.13 MBytes
# [  5]   9.00-10.00  sec  7.50 MBytes  62.9 Mbits/sec    0   3.13 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec  75.0 MBytes  62.9 Mbits/sec    0             sender
# [  5]   0.00-10.28  sec  75.0 MBytes  61.2 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-4 to k8s-worker-7: 60.0 Mbits/sec
#
# Bandwidth from k8s-worker-4 to k8s-worker-6: 123 Mbits/sec
# Full output from bandwidth-measurement-ds-z4wqx to bandwidth-measurement-ds-vf5qp:
# Connecting to host 192.168.140.9, port 5201
# [  5] local 192.168.79.76 port 48030 connected to 192.168.140.9 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  9.35 MBytes  78.4 Mbits/sec    0    513 KBytes
# [  5]   1.00-2.00   sec  6.65 MBytes  55.8 Mbits/sec    0    843 KBytes
# [  5]   2.00-3.00   sec  7.12 MBytes  59.7 Mbits/sec    0   1.15 MBytes
# [  5]   3.00-4.00   sec  6.25 MBytes  52.4 Mbits/sec    0   1.47 MBytes
# [  5]   4.00-5.00   sec  8.75 MBytes  73.4 Mbits/sec    0   1.87 MBytes
# [  5]   5.00-6.00   sec  7.50 MBytes  62.9 Mbits/sec    0   2.27 MBytes
# [  5]   6.00-7.00   sec  7.50 MBytes  62.9 Mbits/sec    0   2.63 MBytes
# [  5]   7.00-8.00   sec  8.75 MBytes  73.4 Mbits/sec    0   3.07 MBytes
# [  5]   8.00-9.00   sec  8.75 MBytes  73.4 Mbits/sec    0   3.16 MBytes
# [  5]   9.00-10.00  sec  8.75 MBytes  73.4 Mbits/sec    0   3.16 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec  79.4 MBytes  66.6 Mbits/sec    0             sender
# [  5]   0.00-10.31  sec  78.7 MBytes  64.1 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-4 to k8s-worker-2: 78.4 Mbits/sec
# {'k8s-worker-3': {'k8s-worker-5': '148 Mbits/sec', 'k8s-worker-1': '295 Mbits/sec', 'k8s-worker-8': '94.0 Mbits/sec', 'k8s-worker-6': '198 Mbits/sec', 'k8s-worker-2': '176 Mbits/sec', 'k8s-worker-9': '170 Mbits/sec', 'k8s-worker-7': '136 Mbits/sec', 'k8s-worker-4': '368 Mbits/sec'}, 'k8s-worker-1': {'k8s-worker-3': '115 Mbits/sec', 'k8s-worker-8': '125 Mbits/sec', 'k8s-worker-9': '436 Mbits/sec', 'k8s-worker-5': '91.9 Mbits/sec', 'k8s-worker-2': '152 Mbits/sec', 'k8s-worker-6': '172 Mbits/sec', 'k8s-worker-7': '351 Mbits/sec', 'k8s-worker-4': '612 Mbits/sec'}, 'k8s-worker-8': {'k8s-worker-1': '219 Mbits/sec', 'k8s-worker-3': '409 Mbits/sec', 'k8s-worker-6': '330 Mbits/sec', 'k8s-worker-5': '232 Mbits/sec', 'k8s-worker-9': '127 Mbits/sec', 'k8s-worker-2': '123 Mbits/sec', 'k8s-worker-4': '392 Mbits/sec', 'k8s-worker-7': '125 Mbits/sec'}, 'k8s-worker-5': {'k8s-worker-1': '175 Mbits/sec', 'k8s-worker-3': '199 Mbits/sec', 'k8s-worker-8': '392 Mbits/sec', 'k8s-worker-6': '392 Mbits/sec', 'k8s-worker-2': '185 Mbits/sec', 'k8s-worker-9': '191 Mbits/sec', 'k8s-worker-7': '488 Mbits/sec', 'k8s-worker-4': '248 Mbits/sec'}, 'k8s-worker-9': {'k8s-worker-3': '781 Mbits/sec', 'k8s-worker-1': '425 Mbits/sec', 'k8s-worker-5': '208 Mbits/sec', 'k8s-worker-8': '259 Mbits/sec', 'k8s-worker-6': '186 Mbits/sec', 'k8s-worker-7': '187 Mbits/sec', 'k8s-worker-2': '476 Mbits/sec', 'k8s-worker-4': '782 Mbits/sec'}, 'k8s-worker-6': {'k8s-worker-3': '177 Mbits/sec', 'k8s-worker-1': '168 Mbits/sec', 'k8s-worker-8': '116 Mbits/sec', 'k8s-worker-5': '156 Mbits/sec', 'k8s-worker-9': '105 Mbits/sec', 'k8s-worker-2': '78.9 Mbits/sec', 'k8s-worker-7': '246 Mbits/sec', 'k8s-worker-4': '18.9 Mbits/sec'}, 'k8s-worker-2': {'k8s-worker-1': '291 Mbits/sec', 'k8s-worker-3': '322 Mbits/sec', 'k8s-worker-8': '192 Mbits/sec', 'k8s-worker-6': '482 Mbits/sec', 'k8s-worker-9': '158 Mbits/sec', 'k8s-worker-5': '177 Mbits/sec', 'k8s-worker-7': '109 Mbits/sec', 'k8s-worker-4': '651 Mbits/sec'}, 'k8s-worker-7': {'k8s-worker-3': '645 Mbits/sec', 'k8s-worker-1': '273 Mbits/sec', 'k8s-worker-8': '273 Mbits/sec', 'k8s-worker-5': '179 Mbits/sec', 'k8s-worker-2': '27.0 Mbits/sec', 'k8s-worker-9': '289 Mbits/sec', 'k8s-worker-6': '364 Mbits/sec', 'k8s-worker-4': '140 Mbits/sec'}, 'k8s-worker-4': {'k8s-worker-3': '61.0 Mbits/sec', 'k8s-worker-1': '192 Mbits/sec', 'k8s-worker-8': '50.0 Mbits/sec', 'k8s-worker-9': '110 Mbits/sec', 'k8s-worker-5': '107 Mbits/sec', 'k8s-worker-7': '60.0 Mbits/sec', 'k8s-worker-6': '123 Mbits/sec', 'k8s-worker-2': '78.4 Mbits/sec'}}

# %%
import pandas as pd

# Convert the nested dictionary into a pandas DataFrame
df = pd.DataFrame(bandwidth_results)

# Transpose the DataFrame to align the source and destination workers as per convention
df = df.T

# Fill diagonal with 0's for self-latency (optional, if desired for clarity)
for worker in df.columns:
    df.at[worker, worker] = 0

# Save the DataFrame to a CSV file, and add the date, hour and minute to the file name
import datetime
now = datetime.datetime.now()
filename = f"bandwidth_results_{now.strftime('%Y-%m-%d_%H-%M')}.csv"
df.to_csv("/home/ubuntu/iDynamics/iBandwidth/measurer/data/"+filename)
df
# Out:
#                 k8s-worker-5   k8s-worker-1    k8s-worker-8   k8s-worker-6  \
# k8s-worker-3   148 Mbits/sec  295 Mbits/sec  94.0 Mbits/sec  198 Mbits/sec
# k8s-worker-1  91.9 Mbits/sec              0   125 Mbits/sec  172 Mbits/sec
# k8s-worker-8   232 Mbits/sec  219 Mbits/sec               0  330 Mbits/sec
# k8s-worker-5               0  175 Mbits/sec   392 Mbits/sec  392 Mbits/sec
# k8s-worker-9   208 Mbits/sec  425 Mbits/sec   259 Mbits/sec  186 Mbits/sec
# k8s-worker-6   156 Mbits/sec  168 Mbits/sec   116 Mbits/sec              0
# k8s-worker-2   177 Mbits/sec  291 Mbits/sec   192 Mbits/sec  482 Mbits/sec
# k8s-worker-7   179 Mbits/sec  273 Mbits/sec   273 Mbits/sec  364 Mbits/sec
# k8s-worker-4   107 Mbits/sec  192 Mbits/sec  50.0 Mbits/sec  123 Mbits/sec
#
#                 k8s-worker-2   k8s-worker-9    k8s-worker-7    k8s-worker-4  \
# k8s-worker-3   176 Mbits/sec  170 Mbits/sec   136 Mbits/sec   368 Mbits/sec
# k8s-worker-1   152 Mbits/sec  436 Mbits/sec   351 Mbits/sec   612 Mbits/sec
# k8s-worker-8   123 Mbits/sec  127 Mbits/sec   125 Mbits/sec   392 Mbits/sec
# k8s-worker-5   185 Mbits/sec  191 Mbits/sec   488 Mbits/sec   248 Mbits/sec
# k8s-worker-9   476 Mbits/sec              0   187 Mbits/sec   782 Mbits/sec
# k8s-worker-6  78.9 Mbits/sec  105 Mbits/sec   246 Mbits/sec  18.9 Mbits/sec
# k8s-worker-2               0  158 Mbits/sec   109 Mbits/sec   651 Mbits/sec
# k8s-worker-7  27.0 Mbits/sec  289 Mbits/sec               0   140 Mbits/sec
# k8s-worker-4  78.4 Mbits/sec  110 Mbits/sec  60.0 Mbits/sec               0
#
#                 k8s-worker-3
# k8s-worker-3               0
# k8s-worker-1   115 Mbits/sec
# k8s-worker-8   409 Mbits/sec
# k8s-worker-5   199 Mbits/sec
# k8s-worker-9   781 Mbits/sec
# k8s-worker-6   177 Mbits/sec
# k8s-worker-2   322 Mbits/sec
# k8s-worker-7   645 Mbits/sec
# k8s-worker-4  61.0 Mbits/sec

# %%
# Out:
# Bandwidth from k8s-worker-3 to k8s-worker-1: 806 Mbits/sec
# Bandwidth from k8s-worker-3 to k8s-worker-8: 801 Mbits/sec
# Bandwidth from k8s-worker-3 to k8s-worker-5: 814 Mbits/sec
# Bandwidth from k8s-worker-3 to k8s-worker-9: 813 Mbits/sec
# Bandwidth from k8s-worker-3 to k8s-worker-6: 813 Mbits/sec
# Bandwidth from k8s-worker-3 to k8s-worker-2: 805 Mbits/sec
# Bandwidth from k8s-worker-3 to k8s-worker-7: 815 Mbits/sec
# Bandwidth from k8s-worker-3 to k8s-worker-4: 806 Mbits/sec
# Bandwidth from k8s-worker-1 to k8s-worker-3: 806 Mbits/sec
# Bandwidth from k8s-worker-1 to k8s-worker-8: 819 Mbits/sec
# Bandwidth from k8s-worker-1 to k8s-worker-5: 814 Mbits/sec
# Bandwidth from k8s-worker-1 to k8s-worker-9: 819 Mbits/sec
# Bandwidth from k8s-worker-1 to k8s-worker-6: 807 Mbits/sec
# Bandwidth from k8s-worker-1 to k8s-worker-2: 813 Mbits/sec
# Bandwidth from k8s-worker-1 to k8s-worker-7: 813 Mbits/sec
# Bandwidth from k8s-worker-1 to k8s-worker-4: 810 Mbits/sec
# Bandwidth from k8s-worker-8 to k8s-worker-3: 794 Mbits/sec
# Bandwidth from k8s-worker-8 to k8s-worker-1: 813 Mbits/sec
# Bandwidth from k8s-worker-8 to k8s-worker-5: 802 Mbits/sec
# Bandwidth from k8s-worker-8 to k8s-worker-9: 801 Mbits/sec
# Bandwidth from k8s-worker-8 to k8s-worker-6: 796 Mbits/sec
# Bandwidth from k8s-worker-8 to k8s-worker-2: 794 Mbits/sec
# Bandwidth from k8s-worker-8 to k8s-worker-7: 762 Mbits/sec
# Bandwidth from k8s-worker-8 to k8s-worker-4: 800 Mbits/sec
# Bandwidth from k8s-worker-5 to k8s-worker-3: 803 Mbits/sec
# Bandwidth from k8s-worker-5 to k8s-worker-1: 806 Mbits/sec
# Bandwidth from k8s-worker-5 to k8s-worker-8: 799 Mbits/sec
# Bandwidth from k8s-worker-5 to k8s-worker-9: 806 Mbits/sec
# Bandwidth from k8s-worker-5 to k8s-worker-6: 806 Mbits/sec
# Bandwidth from k8s-worker-5 to k8s-worker-2: 801 Mbits/sec
# Bandwidth from k8s-worker-5 to k8s-worker-7: 805 Mbits/sec
# Bandwidth from k8s-worker-5 to k8s-worker-4: 799 Mbits/sec
# Bandwidth from k8s-worker-9 to k8s-worker-3: 801 Mbits/sec
# Bandwidth from k8s-worker-9 to k8s-worker-1: 813 Mbits/sec
# Bandwidth from k8s-worker-9 to k8s-worker-8: 813 Mbits/sec
# Bandwidth from k8s-worker-9 to k8s-worker-5: 802 Mbits/sec
# Bandwidth from k8s-worker-9 to k8s-worker-6: 810 Mbits/sec
# Bandwidth from k8s-worker-9 to k8s-worker-2: 814 Mbits/sec
# Bandwidth from k8s-worker-9 to k8s-worker-7: 800 Mbits/sec
# Bandwidth from k8s-worker-9 to k8s-worker-4: 797 Mbits/sec
# Bandwidth from k8s-worker-6 to k8s-worker-3: 806 Mbits/sec
# Bandwidth from k8s-worker-6 to k8s-worker-1: 804 Mbits/sec
# Bandwidth from k8s-worker-6 to k8s-worker-8: 808 Mbits/sec
# Bandwidth from k8s-worker-6 to k8s-worker-5: 808 Mbits/sec
# Bandwidth from k8s-worker-6 to k8s-worker-9: 804 Mbits/sec
# Bandwidth from k8s-worker-6 to k8s-worker-2: 802 Mbits/sec
# Bandwidth from k8s-worker-6 to k8s-worker-7: 813 Mbits/sec
# Bandwidth from k8s-worker-6 to k8s-worker-4: 813 Mbits/sec
# Bandwidth from k8s-worker-2 to k8s-worker-3: 816 Mbits/sec
# Bandwidth from k8s-worker-2 to k8s-worker-1: 810 Mbits/sec
# Bandwidth from k8s-worker-2 to k8s-worker-8: 815 Mbits/sec
# Bandwidth from k8s-worker-2 to k8s-worker-5: 811 Mbits/sec
# Bandwidth from k8s-worker-2 to k8s-worker-9: 813 Mbits/sec
# Bandwidth from k8s-worker-2 to k8s-worker-6: 813 Mbits/sec
# Bandwidth from k8s-worker-2 to k8s-worker-7: 813 Mbits/sec
# Bandwidth from k8s-worker-2 to k8s-worker-4: 816 Mbits/sec
# Bandwidth from k8s-worker-7 to k8s-worker-3: 816 Mbits/sec
# Bandwidth from k8s-worker-7 to k8s-worker-1: 809 Mbits/sec
