# %%
'''Deploy cross-node bandwidth measurement pods'''

from kubernetes import client, config

def check_pods_existence(namespace):
    core_v1 = client.CoreV1Api()
    try:
        pods = core_v1.list_namespaced_pod(namespace=namespace)
        return len(pods.items) > 0  # return True if pods exist
    except client.rest.ApiException as e:
        print(f"Exception when calling CoreV1Api->list_namespaced_pod: {e}")
        return False

def deploy_bandwidth_measurement_daemonset_if_needed():
    namespace = 'measure-nodes-bd'
    ds_name = 'bandwidth-measurement-ds'
    
    # Load Kubernetes configuration
    config.load_kube_config()
    apps_v1 = client.AppsV1Api()

    # Check if pods exist in the namespace
    pods_exist = check_pods_existence(namespace)

    # If no pods exist, deploy the DaemonSet
    if not pods_exist:
        # Define the body of the DaemonSet for `iperf3` server deployment
        ds_body = client.V1DaemonSet(
            api_version="apps/v1",
            kind="DaemonSet",
            metadata=client.V1ObjectMeta(name=ds_name),
            spec=client.V1DaemonSetSpec(
                selector=client.V1LabelSelector(
                    match_labels={"app": "bandwidth-measurement"}
                ),
                template=client.V1PodTemplateSpec(
                    metadata=client.V1ObjectMeta(labels={"app": "bandwidth-measurement"}),
                    spec=client.V1PodSpec(
                        containers=[client.V1Container(
                            name="iperf3-server",
                            image="networkstatic/iperf3",
                            args=["-s"],  # Run in server mode
                            ports=[client.V1ContainerPort(container_port=5201)]
                        )],
                        restart_policy="Always"
                    )
                )
            )
        )

        # Deploy the DaemonSet
        try:
            apps_v1.create_namespaced_daemon_set(namespace=namespace, body=ds_body)
            print(f"Deployed DaemonSet {ds_name} in namespace {namespace}")
        except client.rest.ApiException as e:
            print(f"Exception when calling AppsV1Api->create_namespaced_daemon_set: {e}")
    else:
        print("Pods already exist in the namespace. Skipping DaemonSet deployment.")

# Call the function to deploy the DaemonSet if needed
deploy_bandwidth_measurement_daemonset_if_needed()
# Out:
# Pods already exist in the namespace. Skipping DaemonSet deployment.

# %%
import re
from kubernetes import client, config, stream
import concurrent.futures
import time

# Load Kubernetes configuration
config.load_kube_config()
v1 = client.CoreV1Api()

# Function to measure bandwidth between source and target pods with retries
def measure_bandwidth_from_source_to_target(v1, namespace, source_pod, target_pod, test_duration=5, max_retries=3):
    source_pod_name = source_pod.metadata.name
    source_pod_node_name = source_pod.spec.node_name
    target_pod_ip = target_pod.status.pod_ip
    target_pod_name = target_pod.metadata.name
    target_pod_node_name = target_pod.spec.node_name
    result = (source_pod_node_name, target_pod_node_name, None)

    if source_pod_name != target_pod_name:
        exec_command = ['iperf3', '-c', target_pod_ip, '-t', str(test_duration)]
        attempts = 0

        while attempts < max_retries:
            try:
                # Run iperf3 command
                resp = stream.stream(v1.connect_get_namespaced_pod_exec,
                                     source_pod_name,
                                     namespace,
                                     command=exec_command,
                                     stderr=True,
                                     stdin=False,
                                     stdout=True,
                                     tty=False)

                # Check for "server is busy" in the output
                if "the server is busy" in resp:
                    print(f"Server is busy for connection from {source_pod_name} to {target_pod_name}. Retrying...")
                    attempts += 1
                    time.sleep(test_duration/2)  # Wait before retrying
                    continue

                # Parse the output for bandwidth
                print(f"Full output from {source_pod_name} to {target_pod_name}:\n{resp}")
                match = re.search(r'(\d+\.?\d*\s[MKG]bits/sec)', resp)
                if match:
                    bandwidth = match.group(1)
                    result = (source_pod_node_name, target_pod_node_name, bandwidth)
                    print(f"Bandwidth from {source_pod_node_name} to {target_pod_node_name}: {bandwidth}")
                else:
                    print(f"Could not extract bandwidth for connection from {source_pod_name} to {target_pod_name}.")
                    result = (source_pod_node_name, target_pod_node_name, "Parsing Error")
                break  # Exit loop on success

            except Exception as e:
                print(f"Error executing command in pod {source_pod_name}: {e}")
                result = (source_pod_node_name, target_pod_node_name, "Error")
                break

        if attempts == max_retries:
            print(f"Max retries reached for connection from {source_pod_name} to {target_pod_name}.")
            result = (source_pod_node_name, target_pod_node_name, "Server Busy Error")

    return result

def measure_bandwidth(namespace='measure-nodes-bd', max_concurrent_tasks=3, test_duration=5):
    v1 = client.CoreV1Api()
    pods = v1.list_namespaced_pod(namespace, label_selector="app=bandwidth-measurement").items
    bandwidth_results = {}

    # Use ThreadPoolExecutor for controlled concurrent execution
    with concurrent.futures.ThreadPoolExecutor(max_workers=max_concurrent_tasks) as executor:
        futures = []
        for source_pod in pods:
            for target_pod in pods:
                if source_pod.metadata.name != target_pod.metadata.name:  # Skip self-tests
                    futures.append(executor.submit(measure_bandwidth_from_source_to_target,
                                                   v1, namespace, source_pod, target_pod, test_duration))

        # Collect the completed results
        for future in concurrent.futures.as_completed(futures):
            source_pod_node_name, target_pod_node_name, bandwidth = future.result()
            if source_pod_node_name not in bandwidth_results:
                bandwidth_results[source_pod_node_name] = {}
            bandwidth_results[source_pod_node_name][target_pod_node_name] = bandwidth

    return bandwidth_results

# Call the function to measure bandwidth after deploying the DaemonSet
namespace = 'measure-nodes-bd'
# Reduced concurrency and added retry logic
bandwidth_results = measure_bandwidth(namespace=namespace, max_concurrent_tasks=3, test_duration=10)
print(bandwidth_results)
# Out:
# Full output from bandwidth-measurement-ds-6dldb to bandwidth-measurement-ds-gnsh9:
# Connecting to host 192.168.230.44, port 5201
# [  5] local 192.168.69.209 port 35900 connected to 192.168.230.44 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  31.4 MBytes   263 Mbits/sec    0   1.82 MBytes
# [  5]   1.00-2.00   sec  27.5 MBytes   231 Mbits/sec    0   3.16 MBytes
# [  5]   2.00-3.00   sec  23.8 MBytes   199 Mbits/sec    0   3.16 MBytes
# [  5]   3.00-4.00   sec  20.0 MBytes   168 Mbits/sec    0   3.16 MBytes
# [  5]   4.00-5.00   sec  16.2 MBytes   136 Mbits/sec    4   2.45 MBytes
# [  5]   5.00-6.00   sec  18.8 MBytes   157 Mbits/sec    0   2.76 MBytes
# [  5]   6.00-7.00   sec  17.5 MBytes   147 Mbits/sec    0   2.95 MBytes
# [  5]   7.00-8.00   sec  17.5 MBytes   147 Mbits/sec    0   3.03 MBytes
# [  5]   8.00-9.00   sec  17.5 MBytes   147 Mbits/sec    0   3.03 MBytes
# [  5]   9.00-10.00  sec  17.5 MBytes   147 Mbits/sec    0   3.03 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   208 MBytes   174 Mbits/sec    4             sender
# [  5]   0.00-10.15  sec   208 MBytes   172 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-3 to k8s-worker-1: 263 Mbits/sec
# Full output from bandwidth-measurement-ds-6dldb to bandwidth-measurement-ds-p2vgl:
# Connecting to host 192.168.18.232, port 5201
# [  5] local 192.168.69.209 port 45848 connected to 192.168.18.232 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  18.9 MBytes   158 Mbits/sec    0   1.11 MBytes
# [  5]   1.00-2.00   sec  16.2 MBytes   136 Mbits/sec    0   1.90 MBytes
# [  5]   2.00-3.00   sec  17.5 MBytes   147 Mbits/sec    0   2.81 MBytes
# [  5]   3.00-4.00   sec  20.0 MBytes   168 Mbits/sec    0   3.14 MBytes
# [  5]   4.00-5.00   sec  22.5 MBytes   189 Mbits/sec    0   3.14 MBytes
# [  5]   5.00-6.00   sec  21.2 MBytes   178 Mbits/sec    0   3.14 MBytes
# [  5]   6.00-7.00   sec  20.0 MBytes   168 Mbits/sec    0   3.14 MBytes
# [  5]   7.00-8.00   sec  18.8 MBytes   157 Mbits/sec    0   3.14 MBytes
# [  5]   8.00-9.00   sec  18.8 MBytes   157 Mbits/sec    0   3.14 MBytes
# [  5]   9.00-10.00  sec  17.5 MBytes   147 Mbits/sec    0   3.14 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   191 MBytes   161 Mbits/sec    0             sender
# [  5]   0.00-10.12  sec   191 MBytes   159 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-3 to k8s-worker-5: 158 Mbits/sec
# Full output from bandwidth-measurement-ds-6dldb to bandwidth-measurement-ds-nrznp:
# Connecting to host 192.168.231.226, port 5201
# [  5] local 192.168.69.209 port 58632 connected to 192.168.231.226 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  13.6 MBytes   114 Mbits/sec    0    704 KBytes
# [  5]   1.00-2.00   sec  11.8 MBytes  98.6 Mbits/sec    0   1.21 MBytes
# [  5]   2.00-3.00   sec  11.2 MBytes  94.4 Mbits/sec    0   1.81 MBytes
# [  5]   3.00-4.00   sec  15.0 MBytes   126 Mbits/sec    0   2.54 MBytes
# [  5]   4.00-5.00   sec  15.0 MBytes   126 Mbits/sec   14   2.05 MBytes
# [  5]   5.00-6.00   sec  15.0 MBytes   126 Mbits/sec    0   2.32 MBytes
# [  5]   6.00-7.00   sec  16.2 MBytes   136 Mbits/sec    0   2.49 MBytes
# [  5]   7.00-8.00   sec  17.5 MBytes   147 Mbits/sec    0   2.60 MBytes
# [  5]   8.00-9.00   sec  20.0 MBytes   168 Mbits/sec    0   2.64 MBytes
# [  5]   9.00-10.00  sec  17.5 MBytes   147 Mbits/sec    0   2.65 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   153 MBytes   128 Mbits/sec   14             sender
# [  5]   0.00-10.15  sec   153 MBytes   126 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-3 to k8s-worker-8: 114 Mbits/sec
# Full output from bandwidth-measurement-ds-6dldb to bandwidth-measurement-ds-vf5qp:
# Connecting to host 192.168.140.9, port 5201
# [  5] local 192.168.69.209 port 38728 connected to 192.168.140.9 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  31.4 MBytes   263 Mbits/sec    0   1.97 MBytes
# [  5]   1.00-2.00   sec  27.5 MBytes   231 Mbits/sec    0   3.15 MBytes
# [  5]   2.00-3.00   sec  22.5 MBytes   189 Mbits/sec    0   3.15 MBytes
# [  5]   3.00-4.00   sec  20.0 MBytes   168 Mbits/sec    0   3.15 MBytes
# [  5]   4.00-5.00   sec  16.2 MBytes   136 Mbits/sec    1   1.12 MBytes
# [  5]   5.00-6.00   sec  17.5 MBytes   147 Mbits/sec    0   2.51 MBytes
# [  5]   6.00-7.00   sec  17.5 MBytes   147 Mbits/sec    0   2.78 MBytes
# [  5]   7.00-8.00   sec  17.5 MBytes   147 Mbits/sec    0   2.97 MBytes
# [  5]   8.00-9.00   sec  17.5 MBytes   147 Mbits/sec    1   2.13 MBytes
# [  5]   9.00-10.00  sec  16.2 MBytes   136 Mbits/sec    0   2.33 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   204 MBytes   171 Mbits/sec    2             sender
# [  5]   0.00-10.14  sec   203 MBytes   168 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-3 to k8s-worker-2: 263 Mbits/sec
# Full output from bandwidth-measurement-ds-6dldb to bandwidth-measurement-ds-r7ftn:
# Connecting to host 192.168.251.65, port 5201
# [  5] local 192.168.69.209 port 32788 connected to 192.168.251.65 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  14.2 MBytes   119 Mbits/sec    0    739 KBytes
# [  5]   1.00-2.00   sec  11.4 MBytes  95.7 Mbits/sec    0   1.24 MBytes
# [  5]   2.00-3.00   sec  11.2 MBytes  94.4 Mbits/sec    0   1.82 MBytes
# [  5]   3.00-4.00   sec  15.0 MBytes   126 Mbits/sec    0   2.57 MBytes
# [  5]   4.00-5.00   sec  20.0 MBytes   168 Mbits/sec    0   3.16 MBytes
# [  5]   5.00-6.00   sec  22.5 MBytes   189 Mbits/sec    0   3.16 MBytes
# [  5]   6.00-7.00   sec  17.5 MBytes   147 Mbits/sec    0   3.16 MBytes
# [  5]   7.00-8.00   sec  18.8 MBytes   157 Mbits/sec    0   3.16 MBytes
# [  5]   8.00-9.00   sec  21.2 MBytes   178 Mbits/sec    0   3.16 MBytes
# [  5]   9.00-10.00  sec  21.2 MBytes   178 Mbits/sec    0   3.16 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   173 MBytes   145 Mbits/sec    0             sender
# [  5]   0.00-10.14  sec   173 MBytes   143 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-3 to k8s-worker-9: 119 Mbits/sec
# Full output from bandwidth-measurement-ds-6dldb to bandwidth-measurement-ds-rfvj2:
# Connecting to host 192.168.227.155, port 5201
# [  5] local 192.168.69.209 port 60868 connected to 192.168.227.155 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  18.6 MBytes   156 Mbits/sec    0   1.13 MBytes
# [  5]   1.00-2.00   sec  16.2 MBytes   136 Mbits/sec    0   1.95 MBytes
# [  5]   2.00-3.00   sec  18.8 MBytes   157 Mbits/sec    0   2.89 MBytes
# [  5]   3.00-4.00   sec  17.5 MBytes   147 Mbits/sec    0   3.15 MBytes
# [  5]   4.00-5.00   sec  16.2 MBytes   136 Mbits/sec    3   1.09 MBytes
# [  5]   5.00-6.00   sec  18.8 MBytes   157 Mbits/sec    0   2.52 MBytes
# [  5]   6.00-7.00   sec  17.5 MBytes   147 Mbits/sec    0   2.80 MBytes
# [  5]   7.00-8.00   sec  17.5 MBytes   147 Mbits/sec    0   2.98 MBytes
# [  5]   8.00-9.00   sec  16.2 MBytes   136 Mbits/sec    3   2.13 MBytes
# [  5]   9.00-10.00  sec  17.5 MBytes   147 Mbits/sec    0   2.35 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   175 MBytes   147 Mbits/sec    6             sender
# [  5]   0.00-10.14  sec   174 MBytes   144 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-3 to k8s-worker-6: 156 Mbits/sec
# Full output from bandwidth-measurement-ds-gnsh9 to bandwidth-measurement-ds-6dldb:
# Connecting to host 192.168.69.209, port 5201
# [  5] local 192.168.230.44 port 33048 connected to 192.168.69.209 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  14.8 MBytes   124 Mbits/sec    0    791 KBytes
# [  5]   1.00-2.00   sec  15.5 MBytes   130 Mbits/sec    0   1.47 MBytes
# [  5]   2.00-3.00   sec  18.8 MBytes   157 Mbits/sec    0   2.41 MBytes
# [  5]   3.00-4.00   sec  25.0 MBytes   210 Mbits/sec    0   3.14 MBytes
# [  5]   4.00-5.00   sec  26.2 MBytes   220 Mbits/sec    0   3.14 MBytes
# [  5]   5.00-6.00   sec  26.2 MBytes   220 Mbits/sec    0   3.14 MBytes
# [  5]   6.00-7.00   sec  26.2 MBytes   220 Mbits/sec    0   3.14 MBytes
# [  5]   7.00-8.00   sec  27.5 MBytes   231 Mbits/sec    0   3.14 MBytes
# [  5]   8.00-9.00   sec  26.2 MBytes   220 Mbits/sec    0   3.14 MBytes
# [  5]   9.00-10.00  sec  26.2 MBytes   220 Mbits/sec    0   3.14 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   233 MBytes   195 Mbits/sec    0             sender
# [  5]   0.00-10.00  sec   233 MBytes   195 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-1 to k8s-worker-3: 124 Mbits/sec
# Full output from bandwidth-measurement-ds-6dldb to bandwidth-measurement-ds-z4wqx:
# Connecting to host 192.168.79.76, port 5201
# [  5] local 192.168.69.209 port 49536 connected to 192.168.79.76 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  41.2 MBytes   346 Mbits/sec    0   2.47 MBytes
# [  5]   1.00-2.00   sec  37.5 MBytes   315 Mbits/sec    0   3.17 MBytes
# [  5]   2.00-3.00   sec  30.0 MBytes   252 Mbits/sec    0   3.17 MBytes
# [  5]   3.00-4.00   sec  27.5 MBytes   231 Mbits/sec    0   3.17 MBytes
# [  5]   4.00-5.00   sec  27.5 MBytes   231 Mbits/sec    0   3.17 MBytes
# [  5]   5.00-6.00   sec  26.2 MBytes   220 Mbits/sec    0   3.17 MBytes
# [  5]   6.00-7.00   sec  26.2 MBytes   220 Mbits/sec    0   3.17 MBytes
# [  5]   7.00-8.00   sec  27.5 MBytes   231 Mbits/sec    0   3.17 MBytes
# [  5]   8.00-9.00   sec  27.5 MBytes   231 Mbits/sec    0   3.17 MBytes
# [  5]   9.00-10.00  sec  27.5 MBytes   231 Mbits/sec    0   3.17 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   299 MBytes   251 Mbits/sec    0             sender
# [  5]   0.00-10.09  sec   298 MBytes   248 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-3 to k8s-worker-4: 346 Mbits/sec
# Full output from bandwidth-measurement-ds-6dldb to bandwidth-measurement-ds-z29qn:
# Connecting to host 192.168.5.12, port 5201
# [  5] local 192.168.69.209 port 38872 connected to 192.168.5.12 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  19.2 MBytes   161 Mbits/sec    0    982 KBytes
# [  5]   1.00-2.00   sec  17.4 MBytes   146 Mbits/sec    0   1.80 MBytes
# [  5]   2.00-3.00   sec  23.8 MBytes   199 Mbits/sec    0   2.99 MBytes
# [  5]   3.00-4.00   sec  27.5 MBytes   231 Mbits/sec    0   3.17 MBytes
# [  5]   4.00-5.00   sec  26.2 MBytes   220 Mbits/sec    0   3.17 MBytes
# [  5]   5.00-6.00   sec  26.2 MBytes   220 Mbits/sec    0   3.17 MBytes
# [  5]   6.00-7.00   sec  27.5 MBytes   231 Mbits/sec    0   3.17 MBytes
# [  5]   7.00-8.00   sec  27.5 MBytes   231 Mbits/sec    0   3.17 MBytes
# [  5]   8.00-9.00   sec  26.2 MBytes   220 Mbits/sec    0   3.17 MBytes
# [  5]   9.00-10.00  sec  26.2 MBytes   220 Mbits/sec    0   3.17 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   248 MBytes   208 Mbits/sec    0             sender
# [  5]   0.00-10.10  sec   248 MBytes   206 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-3 to k8s-worker-7: 161 Mbits/sec
# Full output from bandwidth-measurement-ds-gnsh9 to bandwidth-measurement-ds-nrznp:
# Connecting to host 192.168.231.226, port 5201
# [  5] local 192.168.230.44 port 41904 connected to 192.168.231.226 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  17.6 MBytes   148 Mbits/sec    0    886 KBytes
# [  5]   1.00-2.00   sec  17.3 MBytes   145 Mbits/sec    0   1.71 MBytes
# [  5]   2.00-3.00   sec  23.8 MBytes   199 Mbits/sec    0   2.88 MBytes
# [  5]   3.00-4.00   sec  26.2 MBytes   220 Mbits/sec    0   3.16 MBytes
# [  5]   4.00-5.00   sec  26.2 MBytes   220 Mbits/sec    0   3.16 MBytes
# [  5]   5.00-6.00   sec  26.2 MBytes   220 Mbits/sec    0   3.16 MBytes
# [  5]   6.00-7.00   sec  23.8 MBytes   199 Mbits/sec    0   3.16 MBytes
# [  5]   7.00-8.00   sec  31.2 MBytes   262 Mbits/sec    0   3.16 MBytes
# [  5]   8.00-9.00   sec  27.5 MBytes   231 Mbits/sec    0   3.16 MBytes
# [  5]   9.00-10.00  sec  26.2 MBytes   220 Mbits/sec    0   3.16 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   246 MBytes   206 Mbits/sec    0             sender
# [  5]   0.00-10.11  sec   246 MBytes   204 Mbits/sec                  receiver
#
# iperf Done.
# Full output from bandwidth-measurement-ds-gnsh9 to bandwidth-measurement-ds-p2vgl:
# Connecting to host 192.168.18.232, port 5201
# [  5] local 192.168.230.44 port 54740 connected to 192.168.18.232 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  10.5 MBytes  88.4 Mbits/sec    0    660 KBytes
# [  5]   1.00-2.00   sec  13.3 MBytes   112 Mbits/sec    0   1.26 MBytes
# [  5]   2.00-3.00   sec  16.2 MBytes   136 Mbits/sec    0   2.06 MBytes
# [  5]   3.00-4.00   sec  17.5 MBytes   147 Mbits/sec   16   1.90 MBytes
# [  5]   4.00-5.00   sec  21.2 MBytes   178 Mbits/sec    0   2.22 MBytes
# [  5]   5.00-6.00   sec  20.0 MBytes   168 Mbits/sec    0   2.43 MBytes
# [  5]   6.00-7.00   sec  18.8 MBytes   157 Mbits/sec    4    765 KBytes
# [  5]   7.00-8.00   sec  18.8 MBytes   157 Mbits/sec    0   1.95 MBytes
# [  5]   8.00-9.00   sec  20.0 MBytes   168 Mbits/sec    0   2.08 MBytes
# [  5]   9.00-10.00  sec  20.0 MBytes   168 Mbits/sec    0   2.15 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   176 MBytes   148 Mbits/sec   20             sender
# [  5]   0.00-10.08  sec   175 MBytes   146 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-1 to k8s-worker-5: 88.4 Mbits/sec
#
# Bandwidth from k8s-worker-1 to k8s-worker-8: 148 Mbits/sec
# Full output from bandwidth-measurement-ds-gnsh9 to bandwidth-measurement-ds-r7ftn:
# Connecting to host 192.168.251.65, port 5201
# [  5] local 192.168.230.44 port 45502 connected to 192.168.251.65 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  50.6 MBytes   425 Mbits/sec    0   3.16 MBytes
# [  5]   1.00-2.00   sec  41.2 MBytes   346 Mbits/sec    0   3.16 MBytes
# [  5]   2.00-3.00   sec  30.0 MBytes   252 Mbits/sec    0   3.16 MBytes
# [  5]   3.00-4.00   sec  25.0 MBytes   210 Mbits/sec    2   2.26 MBytes
# [  5]   4.00-5.00   sec  22.5 MBytes   189 Mbits/sec    0   2.61 MBytes
# [  5]   5.00-6.00   sec  25.0 MBytes   210 Mbits/sec    0   2.86 MBytes
# [  5]   6.00-7.00   sec  22.5 MBytes   189 Mbits/sec    0   3.01 MBytes
# [  5]   7.00-8.00   sec  22.5 MBytes   189 Mbits/sec    2   2.29 MBytes
# [  5]   8.00-9.00   sec  22.5 MBytes   189 Mbits/sec    0   2.44 MBytes
# [  5]   9.00-10.00  sec  22.5 MBytes   189 Mbits/sec    0   2.53 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   284 MBytes   239 Mbits/sec    4             sender
# [  5]   0.00-10.08  sec   284 MBytes   236 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-1 to k8s-worker-9: 425 Mbits/sec
# Full output from bandwidth-measurement-ds-gnsh9 to bandwidth-measurement-ds-vf5qp:
# Connecting to host 192.168.140.9, port 5201
# [  5] local 192.168.230.44 port 38854 connected to 192.168.140.9 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  13.6 MBytes   114 Mbits/sec    0    721 KBytes
# [  5]   1.00-2.00   sec  15.1 MBytes   126 Mbits/sec    0   1.38 MBytes
# [  5]   2.00-3.00   sec  18.8 MBytes   157 Mbits/sec    0   2.36 MBytes
# [  5]   3.00-4.00   sec  21.2 MBytes   178 Mbits/sec    6   2.10 MBytes
# [  5]   4.00-5.00   sec  21.2 MBytes   178 Mbits/sec    0   2.42 MBytes
# [  5]   5.00-6.00   sec  21.2 MBytes   178 Mbits/sec    0   2.61 MBytes
# [  5]   6.00-7.00   sec  21.2 MBytes   178 Mbits/sec    2   1.93 MBytes
# [  5]   7.00-8.00   sec  20.0 MBytes   168 Mbits/sec    0   2.12 MBytes
# [  5]   8.00-9.00   sec  21.2 MBytes   178 Mbits/sec    0   2.23 MBytes
# [  5]   9.00-10.00  sec  21.2 MBytes   178 Mbits/sec    0   2.29 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   195 MBytes   163 Mbits/sec    8             sender
# [  5]   0.00-10.11  sec   194 MBytes   161 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-1 to k8s-worker-2: 114 Mbits/sec
# Full output from bandwidth-measurement-ds-gnsh9 to bandwidth-measurement-ds-rfvj2:
# Connecting to host 192.168.227.155, port 5201
# [  5] local 192.168.230.44 port 59172 connected to 192.168.227.155 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  52.9 MBytes   444 Mbits/sec    0   3.14 MBytes
# [  5]   1.00-2.00   sec  41.2 MBytes   346 Mbits/sec    0   3.14 MBytes
# [  5]   2.00-3.00   sec  28.8 MBytes   241 Mbits/sec    0   3.14 MBytes
# [  5]   3.00-4.00   sec  28.8 MBytes   241 Mbits/sec    0   3.14 MBytes
# [  5]   4.00-5.00   sec  26.2 MBytes   220 Mbits/sec    0   3.14 MBytes
# [  5]   5.00-6.00   sec  26.2 MBytes   220 Mbits/sec    0   3.14 MBytes
# [  5]   6.00-7.00   sec  26.2 MBytes   220 Mbits/sec    0   3.14 MBytes
# [  5]   7.00-8.00   sec  30.0 MBytes   252 Mbits/sec    0   3.14 MBytes
# [  5]   8.00-9.00   sec  26.2 MBytes   220 Mbits/sec    0   3.14 MBytes
# [  5]   9.00-10.00  sec  28.8 MBytes   241 Mbits/sec    0   3.14 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   315 MBytes   265 Mbits/sec    0             sender
# [  5]   0.00-10.11  sec   315 MBytes   261 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-1 to k8s-worker-6: 444 Mbits/sec
# Full output from bandwidth-measurement-ds-gnsh9 to bandwidth-measurement-ds-z29qn:
# Connecting to host 192.168.5.12, port 5201
# [  5] local 192.168.230.44 port 52706 connected to 192.168.5.12 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  12.3 MBytes   103 Mbits/sec    0    817 KBytes
# [  5]   1.00-2.00   sec  16.9 MBytes   141 Mbits/sec    0   1.57 MBytes
# [  5]   2.00-3.00   sec  20.0 MBytes   168 Mbits/sec    0   2.56 MBytes
# [  5]   3.00-4.00   sec  21.2 MBytes   178 Mbits/sec   17   2.24 MBytes
# [  5]   4.00-5.00   sec  21.2 MBytes   178 Mbits/sec    0   2.55 MBytes
# [  5]   5.00-6.00   sec  23.8 MBytes   199 Mbits/sec    0   2.76 MBytes
# [  5]   6.00-7.00   sec  20.0 MBytes   168 Mbits/sec    1   2.04 MBytes
# [  5]   7.00-8.00   sec  21.2 MBytes   178 Mbits/sec    0   2.23 MBytes
# [  5]   8.00-9.00   sec  22.5 MBytes   189 Mbits/sec    0   2.33 MBytes
# [  5]   9.00-10.00  sec  21.2 MBytes   178 Mbits/sec    0   2.39 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   200 MBytes   168 Mbits/sec   18             sender
# [  5]   0.00-10.09  sec   200 MBytes   166 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-1 to k8s-worker-7: 103 Mbits/sec
# Full output from bandwidth-measurement-ds-gnsh9 to bandwidth-measurement-ds-z4wqx:
# Connecting to host 192.168.79.76, port 5201
# [  5] local 192.168.230.44 port 41118 connected to 192.168.79.76 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  72.9 MBytes   611 Mbits/sec    0   3.15 MBytes
# [  5]   1.00-2.00   sec  70.0 MBytes   587 Mbits/sec    0   3.15 MBytes
# [  5]   2.00-3.00   sec  68.8 MBytes   577 Mbits/sec    0   3.15 MBytes
# [  5]   3.00-4.00   sec  70.0 MBytes   587 Mbits/sec    0   3.15 MBytes
# [  5]   4.00-5.00   sec  70.0 MBytes   587 Mbits/sec    0   3.15 MBytes
# [  5]   5.00-6.00   sec  68.8 MBytes   577 Mbits/sec    0   3.15 MBytes
# [  5]   6.00-7.00   sec  70.0 MBytes   587 Mbits/sec    0   3.15 MBytes
# [  5]   7.00-8.00   sec  70.0 MBytes   587 Mbits/sec    0   3.15 MBytes
# [  5]   8.00-9.00   sec  68.8 MBytes   577 Mbits/sec    0   3.15 MBytes
# [  5]   9.00-10.00  sec  70.0 MBytes   587 Mbits/sec    0   3.15 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   699 MBytes   586 Mbits/sec    0             sender
# [  5]   0.00-10.04  sec   699 MBytes   584 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-1 to k8s-worker-4: 611 Mbits/sec
# Full output from bandwidth-measurement-ds-nrznp to bandwidth-measurement-ds-6dldb:
# Connecting to host 192.168.69.209, port 5201
# [  5] local 192.168.231.226 port 33188 connected to 192.168.69.209 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  44.6 MBytes   374 Mbits/sec    0   2.20 MBytes
# [  5]   1.00-2.00   sec  46.2 MBytes   388 Mbits/sec    0   3.17 MBytes
# [  5]   2.00-3.00   sec  42.5 MBytes   357 Mbits/sec    0   3.17 MBytes
# [  5]   3.00-4.00   sec  42.5 MBytes   357 Mbits/sec    0   3.17 MBytes
# [  5]   4.00-5.00   sec  42.5 MBytes   357 Mbits/sec    0   3.17 MBytes
# [  5]   5.00-6.00   sec  43.8 MBytes   367 Mbits/sec    0   3.17 MBytes
# [  5]   6.00-7.00   sec  42.5 MBytes   356 Mbits/sec    0   3.17 MBytes
# [  5]   7.00-8.00   sec  42.5 MBytes   357 Mbits/sec    0   3.17 MBytes
# [  5]   8.00-9.00   sec  42.5 MBytes   356 Mbits/sec    0   3.17 MBytes
# [  5]   9.00-10.00  sec  43.8 MBytes   367 Mbits/sec    0   3.17 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   433 MBytes   364 Mbits/sec    0             sender
# [  5]   0.00-10.07  sec   433 MBytes   361 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-8 to k8s-worker-3: 374 Mbits/sec
# Full output from bandwidth-measurement-ds-nrznp to bandwidth-measurement-ds-gnsh9:
# Connecting to host 192.168.230.44, port 5201
# [  5] local 192.168.231.226 port 47980 connected to 192.168.230.44 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  30.2 MBytes   254 Mbits/sec    0   1.90 MBytes
# [  5]   1.00-2.00   sec  22.5 MBytes   189 Mbits/sec    0   3.07 MBytes
# [  5]   2.00-3.00   sec  26.2 MBytes   220 Mbits/sec    0   3.14 MBytes
# [  5]   3.00-4.00   sec  27.5 MBytes   231 Mbits/sec    0   3.14 MBytes
# [  5]   4.00-5.00   sec  26.2 MBytes   220 Mbits/sec    0   3.14 MBytes
# [  5]   5.00-6.00   sec  26.2 MBytes   220 Mbits/sec    0   3.14 MBytes
# [  5]   6.00-7.00   sec  26.2 MBytes   220 Mbits/sec    0   3.14 MBytes
# [  5]   7.00-8.00   sec  26.2 MBytes   220 Mbits/sec    0   3.14 MBytes
# [  5]   8.00-9.00   sec  25.0 MBytes   210 Mbits/sec    0   3.14 MBytes
# [  5]   9.00-10.00  sec  26.2 MBytes   220 Mbits/sec    0   3.14 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   263 MBytes   220 Mbits/sec    0             sender
# [  5]   0.00-10.07  sec   263 MBytes   219 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-8 to k8s-worker-1: 254 Mbits/sec
# Full output from bandwidth-measurement-ds-nrznp to bandwidth-measurement-ds-p2vgl:
# Connecting to host 192.168.18.232, port 5201
# [  5] local 192.168.231.226 port 54928 connected to 192.168.18.232 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  31.0 MBytes   260 Mbits/sec    0   1.54 MBytes
# [  5]   1.00-2.00   sec  26.2 MBytes   220 Mbits/sec    0   2.83 MBytes
# [  5]   2.00-3.00   sec  22.5 MBytes   189 Mbits/sec   14   2.21 MBytes
# [  5]   3.00-4.00   sec  21.2 MBytes   178 Mbits/sec    0   2.59 MBytes
# [  5]   4.00-5.00   sec  21.2 MBytes   178 Mbits/sec    8   1.95 MBytes
# [  5]   5.00-6.00   sec  20.0 MBytes   168 Mbits/sec    0   2.15 MBytes
# [  5]   6.00-7.00   sec  18.8 MBytes   157 Mbits/sec    0   2.27 MBytes
# [  5]   7.00-8.00   sec  20.0 MBytes   168 Mbits/sec    0   2.34 MBytes
# [  5]   8.00-9.00   sec  20.0 MBytes   168 Mbits/sec    0   2.36 MBytes
# [  5]   9.00-10.00  sec  20.0 MBytes   168 Mbits/sec    0   2.36 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   221 MBytes   185 Mbits/sec   22             sender
# [  5]   0.00-10.12  sec   220 MBytes   182 Mbits/sec                  receiver
#
# iperf Done.
# Full output from bandwidth-measurement-ds-nrznp to bandwidth-measurement-ds-r7ftn:
# Connecting to host 192.168.251.65, port 5201
# [  5] local 192.168.231.226 port 48300 connected to 192.168.251.65 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  22.1 MBytes   186 Mbits/sec    0   1.16 MBytes
# [  5]   1.00-2.00   sec  18.8 MBytes   157 Mbits/sec    0   2.13 MBytes
# [  5]   2.00-3.00   sec  23.8 MBytes   199 Mbits/sec    0   3.13 MBytes
# [  5]   3.00-4.00   sec  26.2 MBytes   220 Mbits/sec    0   3.13 MBytes
# [  5]   4.00-5.00   sec  22.5 MBytes   189 Mbits/sec    5   2.21 MBytes
# [  5]   5.00-6.00   sec  22.5 MBytes   189 Mbits/sec    0   2.57 MBytes
# [  5]   6.00-7.00   sec  23.8 MBytes   199 Mbits/sec    0   2.83 MBytes
# [  5]   7.00-8.00   sec  23.8 MBytes   199 Mbits/sec    0   2.99 MBytes
# [  5]   8.00-9.00   sec  25.0 MBytes   210 Mbits/sec    0   3.06 MBytes
# [  5]   9.00-10.00  sec  25.0 MBytes   210 Mbits/sec    0   3.06 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   233 MBytes   196 Mbits/sec    5             sender
# [  5]   0.00-10.11  sec   233 MBytes   193 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-8 to k8s-worker-9: 186 Mbits/sec
# Full output from bandwidth-measurement-ds-nrznp to bandwidth-measurement-ds-rfvj2:
# Connecting to host 192.168.227.155, port 5201
# [  5] local 192.168.231.226 port 45528 connected to 192.168.227.155 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  26.9 MBytes   225 Mbits/sec    0   1.54 MBytes
# [  5]   1.00-2.00   sec  25.0 MBytes   210 Mbits/sec    0   2.78 MBytes
# [  5]   2.00-3.00   sec  22.5 MBytes   189 Mbits/sec   14   2.29 MBytes
# [  5]   3.00-4.00   sec  21.2 MBytes   178 Mbits/sec    0   2.63 MBytes
# [  5]   4.00-5.00   sec  26.2 MBytes   220 Mbits/sec    0   2.89 MBytes
# [  5]   5.00-6.00   sec  27.5 MBytes   231 Mbits/sec    0   3.03 MBytes
# [  5]   6.00-7.00   sec  26.2 MBytes   220 Mbits/sec    0   3.04 MBytes
# [  5]   7.00-8.00   sec  25.0 MBytes   210 Mbits/sec    0   3.04 MBytes
# [  5]   8.00-9.00   sec  25.0 MBytes   210 Mbits/sec    0   3.04 MBytes
# [  5]   9.00-10.00  sec  23.8 MBytes   199 Mbits/sec    0   3.04 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   249 MBytes   209 Mbits/sec   14             sender
# [  5]   0.00-10.11  sec   249 MBytes   207 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-8 to k8s-worker-6: 225 Mbits/sec
#
# Bandwidth from k8s-worker-8 to k8s-worker-5: 260 Mbits/sec
# Full output from bandwidth-measurement-ds-nrznp to bandwidth-measurement-ds-z29qn:
# Connecting to host 192.168.5.12, port 5201
# [  5] local 192.168.231.226 port 51496 connected to 192.168.5.12 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  45.9 MBytes   385 Mbits/sec    0   2.77 MBytes
# [  5]   1.00-2.00   sec  37.5 MBytes   315 Mbits/sec    0   3.14 MBytes
# [  5]   2.00-3.00   sec  28.8 MBytes   241 Mbits/sec    0   3.14 MBytes
# [  5]   3.00-4.00   sec  23.8 MBytes   199 Mbits/sec   14   2.44 MBytes
# [  5]   4.00-5.00   sec  23.8 MBytes   199 Mbits/sec    0   2.73 MBytes
# [  5]   5.00-6.00   sec  23.8 MBytes   199 Mbits/sec    0   2.94 MBytes
# [  5]   6.00-7.00   sec  21.2 MBytes   178 Mbits/sec    3   2.20 MBytes
# [  5]   7.00-8.00   sec  21.2 MBytes   178 Mbits/sec    0   2.37 MBytes
# [  5]   8.00-9.00   sec  22.5 MBytes   189 Mbits/sec    0   2.47 MBytes
# [  5]   9.00-10.00  sec  22.5 MBytes   189 Mbits/sec    0   2.52 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   271 MBytes   227 Mbits/sec   17             sender
# [  5]   0.00-10.11  sec   270 MBytes   224 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-8 to k8s-worker-7: 385 Mbits/sec
# Full output from bandwidth-measurement-ds-nrznp to bandwidth-measurement-ds-z4wqx:
# Connecting to host 192.168.79.76, port 5201
# [  5] local 192.168.231.226 port 47360 connected to 192.168.79.76 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  18.8 MBytes   158 Mbits/sec    0    973 KBytes
# [  5]   1.00-2.00   sec  17.4 MBytes   146 Mbits/sec    0   1.79 MBytes
# [  5]   2.00-3.00   sec  20.0 MBytes   168 Mbits/sec    0   2.83 MBytes
# [  5]   3.00-4.00   sec  23.8 MBytes   199 Mbits/sec    6   2.36 MBytes
# [  5]   4.00-5.00   sec  23.8 MBytes   199 Mbits/sec    0   2.66 MBytes
# [  5]   5.00-6.00   sec  22.5 MBytes   189 Mbits/sec    0   2.85 MBytes
# [  5]   6.00-7.00   sec  21.2 MBytes   178 Mbits/sec    3   2.13 MBytes
# [  5]   7.00-8.00   sec  21.2 MBytes   178 Mbits/sec    0   2.30 MBytes
# [  5]   8.00-9.00   sec  21.2 MBytes   178 Mbits/sec    0   2.40 MBytes
# [  5]   9.00-10.00  sec  22.5 MBytes   189 Mbits/sec    0   2.44 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   212 MBytes   178 Mbits/sec    9             sender
# [  5]   0.00-10.11  sec   212 MBytes   176 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-8 to k8s-worker-4: 158 Mbits/sec
# Full output from bandwidth-measurement-ds-nrznp to bandwidth-measurement-ds-vf5qp:
# Connecting to host 192.168.140.9, port 5201
# [  5] local 192.168.231.226 port 33572 connected to 192.168.140.9 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  14.6 MBytes   122 Mbits/sec    0    921 KBytes
# [  5]   1.00-2.00   sec  16.2 MBytes   136 Mbits/sec    0   1.65 MBytes
# [  5]   2.00-3.00   sec  20.0 MBytes   168 Mbits/sec    0   2.68 MBytes
# [  5]   3.00-4.00   sec  22.5 MBytes   189 Mbits/sec   16   2.23 MBytes
# [  5]   4.00-5.00   sec  21.2 MBytes   178 Mbits/sec    0   2.49 MBytes
# [  5]   5.00-6.00   sec  22.5 MBytes   189 Mbits/sec    0   2.66 MBytes
# [  5]   6.00-7.00   sec  27.5 MBytes   231 Mbits/sec    0   2.77 MBytes
# [  5]   7.00-8.00   sec  25.0 MBytes   210 Mbits/sec    0   2.82 MBytes
# [  5]   8.00-9.00   sec  26.2 MBytes   220 Mbits/sec    0   2.83 MBytes
# [  5]   9.00-10.00  sec  25.0 MBytes   210 Mbits/sec    0   2.83 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   221 MBytes   185 Mbits/sec   16             sender
# [  5]   0.00-10.09  sec   220 MBytes   183 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-8 to k8s-worker-2: 122 Mbits/sec
# Full output from bandwidth-measurement-ds-p2vgl to bandwidth-measurement-ds-gnsh9:
# Connecting to host 192.168.230.44, port 5201
# [  5] local 192.168.18.232 port 58132 connected to 192.168.230.44 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  15.1 MBytes   127 Mbits/sec    0    808 KBytes
# [  5]   1.00-2.00   sec  18.1 MBytes   152 Mbits/sec    0   1.63 MBytes
# [  5]   2.00-3.00   sec  22.5 MBytes   189 Mbits/sec    3   2.52 MBytes
# [  5]   3.00-4.00   sec  21.2 MBytes   178 Mbits/sec    7   2.19 MBytes
# [  5]   4.00-5.00   sec  22.5 MBytes   189 Mbits/sec    0   2.44 MBytes
# [  5]   5.00-6.00   sec  26.2 MBytes   220 Mbits/sec    1   1.82 MBytes
# [  5]   6.00-7.00   sec  21.2 MBytes   178 Mbits/sec    0   1.99 MBytes
# [  5]   7.00-8.00   sec  22.5 MBytes   189 Mbits/sec    0   2.11 MBytes
# [  5]   8.00-9.00   sec  23.8 MBytes   199 Mbits/sec    0   2.18 MBytes
# [  5]   9.00-10.00  sec  22.5 MBytes   189 Mbits/sec    0   2.20 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   216 MBytes   181 Mbits/sec   11             sender
# [  5]   0.00-10.10  sec   215 MBytes   179 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-5 to k8s-worker-1: 127 Mbits/sec
# Full output from bandwidth-measurement-ds-p2vgl to bandwidth-measurement-ds-nrznp:
# Connecting to host 192.168.231.226, port 5201
# [  5] local 192.168.18.232 port 50298 connected to 192.168.231.226 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  57.0 MBytes   478 Mbits/sec    0   3.14 MBytes
# [  5]   1.00-2.00   sec  42.5 MBytes   357 Mbits/sec    0   3.14 MBytes
# [  5]   2.00-3.00   sec  31.2 MBytes   262 Mbits/sec    0   3.14 MBytes
# [  5]   3.00-4.00   sec  35.0 MBytes   294 Mbits/sec    0   3.14 MBytes
# [  5]   4.00-5.00   sec  28.8 MBytes   241 Mbits/sec    0   3.14 MBytes
# [  5]   5.00-6.00   sec  30.0 MBytes   252 Mbits/sec    0   3.14 MBytes
# [  5]   6.00-7.00   sec  35.0 MBytes   294 Mbits/sec    0   3.14 MBytes
# [  5]   7.00-8.00   sec  31.2 MBytes   262 Mbits/sec    0   3.14 MBytes
# [  5]   8.00-9.00   sec  31.2 MBytes   262 Mbits/sec    0   3.14 MBytes
# [  5]   9.00-10.00  sec  30.0 MBytes   252 Mbits/sec    0   3.14 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   352 MBytes   295 Mbits/sec    0             sender
# [  5]   0.00-10.09  sec   352 MBytes   293 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-5 to k8s-worker-8: 478 Mbits/sec
# Full output from bandwidth-measurement-ds-p2vgl to bandwidth-measurement-ds-6dldb:
# Connecting to host 192.168.69.209, port 5201
# [  5] local 192.168.18.232 port 51664 connected to 192.168.69.209 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  17.8 MBytes   150 Mbits/sec    0    886 KBytes
# [  5]   1.00-2.00   sec  18.7 MBytes   157 Mbits/sec    0   1.82 MBytes
# [  5]   2.00-3.00   sec  25.0 MBytes   210 Mbits/sec    2   2.96 MBytes
# [  5]   3.00-4.00   sec  25.0 MBytes   210 Mbits/sec   13   2.42 MBytes
# [  5]   4.00-5.00   sec  26.2 MBytes   220 Mbits/sec    0   2.70 MBytes
# [  5]   5.00-6.00   sec  23.8 MBytes   199 Mbits/sec    6   1.99 MBytes
# [  5]   6.00-7.00   sec  25.0 MBytes   210 Mbits/sec    0   2.20 MBytes
# [  5]   7.00-8.00   sec  25.0 MBytes   210 Mbits/sec    0   2.33 MBytes
# [  5]   8.00-9.00   sec  25.0 MBytes   210 Mbits/sec    0   2.40 MBytes
# [  5]   9.00-10.00  sec  25.0 MBytes   210 Mbits/sec    0   2.42 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   236 MBytes   198 Mbits/sec   21             sender
# [  5]   0.00-10.10  sec   236 MBytes   196 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-5 to k8s-worker-3: 150 Mbits/sec
# Full output from bandwidth-measurement-ds-p2vgl to bandwidth-measurement-ds-rfvj2:
# Connecting to host 192.168.227.155, port 5201
# [  5] local 192.168.18.232 port 39560 connected to 192.168.227.155 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  27.5 MBytes   231 Mbits/sec    0   1.34 MBytes
# [  5]   1.00-2.00   sec  23.8 MBytes   199 Mbits/sec    0   2.51 MBytes
# [  5]   2.00-3.00   sec  25.0 MBytes   210 Mbits/sec    2   2.30 MBytes
# [  5]   3.00-4.00   sec  26.2 MBytes   220 Mbits/sec    0   2.63 MBytes
# [  5]   4.00-5.00   sec  26.2 MBytes   220 Mbits/sec    0   2.86 MBytes
# [  5]   5.00-6.00   sec  26.2 MBytes   220 Mbits/sec    1   2.10 MBytes
# [  5]   6.00-7.00   sec  22.5 MBytes   189 Mbits/sec    0   2.32 MBytes
# [  5]   7.00-8.00   sec  25.0 MBytes   210 Mbits/sec    0   2.44 MBytes
# [  5]   8.00-9.00   sec  23.8 MBytes   199 Mbits/sec    0   2.51 MBytes
# [  5]   9.00-10.00  sec  25.0 MBytes   210 Mbits/sec    0   2.54 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   251 MBytes   211 Mbits/sec    3             sender
# [  5]   0.00-10.10  sec   251 MBytes   208 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-5 to k8s-worker-6: 231 Mbits/sec
# Full output from bandwidth-measurement-ds-p2vgl to bandwidth-measurement-ds-r7ftn:
# Connecting to host 192.168.251.65, port 5201
# [  5] local 192.168.18.232 port 38710 connected to 192.168.251.65 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  19.9 MBytes   167 Mbits/sec    0   1.05 MBytes
# [  5]   1.00-2.00   sec  18.8 MBytes   157 Mbits/sec    0   1.98 MBytes
# [  5]   2.00-3.00   sec  22.5 MBytes   189 Mbits/sec    1   1.93 MBytes
# [  5]   3.00-4.00   sec  22.5 MBytes   189 Mbits/sec    0   2.24 MBytes
# [  5]   4.00-5.00   sec  23.8 MBytes   199 Mbits/sec    0   2.44 MBytes
# [  5]   5.00-6.00   sec  25.0 MBytes   210 Mbits/sec    0   2.56 MBytes
# [  5]   6.00-7.00   sec  25.0 MBytes   210 Mbits/sec    0   2.63 MBytes
# [  5]   7.00-8.00   sec  26.2 MBytes   220 Mbits/sec    0   2.65 MBytes
# [  5]   8.00-9.00   sec  26.2 MBytes   220 Mbits/sec    0   2.65 MBytes
# [  5]   9.00-10.00  sec  26.2 MBytes   220 Mbits/sec    0   2.65 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   236 MBytes   198 Mbits/sec    1             sender
# [  5]   0.00-10.09  sec   236 MBytes   196 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-5 to k8s-worker-9: 167 Mbits/sec
# Full output from bandwidth-measurement-ds-p2vgl to bandwidth-measurement-ds-vf5qp:
# Connecting to host 192.168.140.9, port 5201
# [  5] local 192.168.18.232 port 33464 connected to 192.168.140.9 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  45.2 MBytes   380 Mbits/sec    0   2.91 MBytes
# [  5]   1.00-2.00   sec  36.2 MBytes   304 Mbits/sec    0   3.15 MBytes
# [  5]   2.00-3.00   sec  31.2 MBytes   262 Mbits/sec    0   3.15 MBytes
# [  5]   3.00-4.00   sec  31.2 MBytes   262 Mbits/sec    0   3.15 MBytes
# [  5]   4.00-5.00   sec  28.8 MBytes   241 Mbits/sec    0   3.15 MBytes
# [  5]   5.00-6.00   sec  30.0 MBytes   252 Mbits/sec    0   3.15 MBytes
# [  5]   6.00-7.00   sec  30.0 MBytes   252 Mbits/sec    0   3.15 MBytes
# [  5]   7.00-8.00   sec  28.8 MBytes   241 Mbits/sec    0   3.15 MBytes
# [  5]   8.00-9.00   sec  30.0 MBytes   252 Mbits/sec    0   3.15 MBytes
# [  5]   9.00-10.00  sec  28.8 MBytes   241 Mbits/sec    0   3.15 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   320 MBytes   269 Mbits/sec    0             sender
# [  5]   0.00-10.08  sec   320 MBytes   266 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-5 to k8s-worker-2: 380 Mbits/sec
# Full output from bandwidth-measurement-ds-r7ftn to bandwidth-measurement-ds-6dldb:
# Connecting to host 192.168.69.209, port 5201
# [  5] local 192.168.251.65 port 39828 connected to 192.168.69.209 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  91.5 MBytes   768 Mbits/sec    0   3.14 MBytes
# [  5]   1.00-2.00   sec  90.0 MBytes   755 Mbits/sec    0   3.14 MBytes
# [  5]   2.00-3.00   sec  88.8 MBytes   744 Mbits/sec    0   3.14 MBytes
# [  5]   3.00-4.00   sec  90.0 MBytes   755 Mbits/sec    0   3.14 MBytes
# [  5]   4.00-5.00   sec  90.0 MBytes   755 Mbits/sec    0   3.14 MBytes
# [  5]   5.00-6.00   sec  88.8 MBytes   745 Mbits/sec    0   3.14 MBytes
# [  5]   6.00-7.00   sec  90.0 MBytes   755 Mbits/sec    0   3.14 MBytes
# [  5]   7.00-8.00   sec  88.8 MBytes   745 Mbits/sec    0   3.14 MBytes
# [  5]   8.00-9.00   sec  90.0 MBytes   755 Mbits/sec    0   3.14 MBytes
# [  5]   9.00-10.00  sec  88.8 MBytes   744 Mbits/sec    0   3.14 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   896 MBytes   752 Mbits/sec    0             sender
# [  5]   0.00-10.03  sec   896 MBytes   749 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-9 to k8s-worker-3: 768 Mbits/sec
# Full output from bandwidth-measurement-ds-p2vgl to bandwidth-measurement-ds-z29qn:
# Connecting to host 192.168.5.12, port 5201
# [  5] local 192.168.18.232 port 54338 connected to 192.168.5.12 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  29.9 MBytes   251 Mbits/sec    0   1.49 MBytes
# [  5]   1.00-2.00   sec  35.0 MBytes   294 Mbits/sec    0   3.14 MBytes
# [  5]   2.00-3.00   sec  40.0 MBytes   336 Mbits/sec    0   3.14 MBytes
# [  5]   3.00-4.00   sec  38.8 MBytes   325 Mbits/sec    0   3.14 MBytes
# [  5]   4.00-5.00   sec  41.2 MBytes   346 Mbits/sec    0   3.14 MBytes
# [  5]   5.00-6.00   sec  38.8 MBytes   325 Mbits/sec    0   3.14 MBytes
# [  5]   6.00-7.00   sec  40.0 MBytes   336 Mbits/sec    0   3.14 MBytes
# [  5]   7.00-8.00   sec  41.2 MBytes   346 Mbits/sec    0   3.14 MBytes
# [  5]   8.00-9.00   sec  40.0 MBytes   335 Mbits/sec    0   3.14 MBytes
# [  5]   9.00-10.00  sec  38.8 MBytes   325 Mbits/sec    0   3.14 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   384 MBytes   322 Mbits/sec    0             sender
# [  5]   0.00-10.07  sec   383 MBytes   319 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-5 to k8s-worker-7: 251 Mbits/sec
# Full output from bandwidth-measurement-ds-p2vgl to bandwidth-measurement-ds-z4wqx:
# Connecting to host 192.168.79.76, port 5201
# [  5] local 192.168.18.232 port 47926 connected to 192.168.79.76 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  54.1 MBytes   454 Mbits/sec    0   3.15 MBytes
# [  5]   1.00-2.00   sec  46.2 MBytes   388 Mbits/sec    0   3.15 MBytes
# [  5]   2.00-3.00   sec  40.0 MBytes   336 Mbits/sec    0   3.15 MBytes
# [  5]   3.00-4.00   sec  38.8 MBytes   325 Mbits/sec    0   3.15 MBytes
# [  5]   4.00-5.00   sec  40.0 MBytes   336 Mbits/sec    0   3.15 MBytes
# [  5]   5.00-6.00   sec  40.0 MBytes   336 Mbits/sec    0   3.15 MBytes
# [  5]   6.00-7.00   sec  40.0 MBytes   336 Mbits/sec    0   3.15 MBytes
# [  5]   7.00-8.00   sec  40.0 MBytes   336 Mbits/sec    0   3.15 MBytes
# [  5]   8.00-9.00   sec  40.0 MBytes   336 Mbits/sec    0   3.15 MBytes
# [  5]   9.00-10.00  sec  38.8 MBytes   325 Mbits/sec    0   3.15 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   418 MBytes   351 Mbits/sec    0             sender
# [  5]   0.00-10.05  sec   418 MBytes   349 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-5 to k8s-worker-4: 454 Mbits/sec
# Full output from bandwidth-measurement-ds-r7ftn to bandwidth-measurement-ds-gnsh9:
# Connecting to host 192.168.230.44, port 5201
# [  5] local 192.168.251.65 port 58132 connected to 192.168.230.44 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  32.6 MBytes   274 Mbits/sec    0   1.57 MBytes
# [  5]   1.00-2.00   sec  30.0 MBytes   252 Mbits/sec    0   3.11 MBytes
# [  5]   2.00-3.00   sec  30.0 MBytes   252 Mbits/sec   29   2.27 MBytes
# [  5]   3.00-4.00   sec  27.5 MBytes   231 Mbits/sec    0   2.62 MBytes
# [  5]   4.00-5.00   sec  30.0 MBytes   252 Mbits/sec    0   2.87 MBytes
# [  5]   5.00-6.00   sec  30.0 MBytes   252 Mbits/sec    1   2.18 MBytes
# [  5]   6.00-7.00   sec  28.8 MBytes   241 Mbits/sec    0   2.33 MBytes
# [  5]   7.00-8.00   sec  28.8 MBytes   241 Mbits/sec    0   2.42 MBytes
# [  5]   8.00-9.00   sec  28.8 MBytes   241 Mbits/sec    0   2.45 MBytes
# [  5]   9.00-10.00  sec  28.8 MBytes   241 Mbits/sec    0   2.45 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   295 MBytes   248 Mbits/sec   30             sender
# [  5]   0.00-10.08  sec   294 MBytes   245 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-9 to k8s-worker-1: 274 Mbits/sec
# Full output from bandwidth-measurement-ds-r7ftn to bandwidth-measurement-ds-p2vgl:
# Connecting to host 192.168.18.232, port 5201
# [  5] local 192.168.251.65 port 36464 connected to 192.168.18.232 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  19.5 MBytes   164 Mbits/sec    0   1.04 MBytes
# [  5]   1.00-2.00   sec  20.0 MBytes   168 Mbits/sec    0   2.04 MBytes
# [  5]   2.00-3.00   sec  25.0 MBytes   210 Mbits/sec   12   2.09 MBytes
# ...
# [  5]   4.00-5.00   sec  27.5 MBytes   231 Mbits/sec    0   2.81 MBytes
# [  5]   5.00-6.00   sec  26.2 MBytes   220 Mbits/sec    0   2.99 MBytes
# [  5]   6.00-7.00   sec  28.8 MBytes   241 Mbits/sec    0   3.03 MBytes
# [  5]   7.00-8.00   sec  26.2 MBytes   220 Mbits/sec    0   3.03 MBytes
# [  5]   8.00-9.00   sec  26.2 MBytes   220 Mbits/sec    0   3.03 MBytes
# [  5]   9.00-10.00  sec  27.5 MBytes   231 Mbits/sec    0   3.03 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   300 MBytes   252 Mbits/sec    3             sender
# [  5]   0.00-10.10  sec   300 MBytes   249 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-7 to k8s-worker-6: 377 Mbits/sec
# Full output from bandwidth-measurement-ds-z29qn to bandwidth-measurement-ds-z4wqx:
# Connecting to host 192.168.79.76, port 5201
# [  5] local 192.168.5.12 port 36022 connected to 192.168.79.76 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  23.6 MBytes   198 Mbits/sec    0   1.17 MBytes
# [  5]   1.00-2.00   sec  18.8 MBytes   157 Mbits/sec    0   2.08 MBytes
# [  5]   2.00-3.00   sec  18.8 MBytes   157 Mbits/sec    0   3.02 MBytes
# [  5]   3.00-4.00   sec  17.5 MBytes   147 Mbits/sec    0   3.13 MBytes
# [  5]   4.00-5.00   sec  18.8 MBytes   157 Mbits/sec    0   3.13 MBytes
# [  5]   5.00-6.00   sec  17.5 MBytes   147 Mbits/sec    0   3.13 MBytes
# [  5]   6.00-7.00   sec  15.0 MBytes   126 Mbits/sec    0   3.13 MBytes
# [  5]   7.00-8.00   sec  12.5 MBytes   105 Mbits/sec    0   3.13 MBytes
# [  5]   8.00-9.00   sec  12.5 MBytes   105 Mbits/sec    0   3.13 MBytes
# [  5]   9.00-10.00  sec  12.5 MBytes   105 Mbits/sec    0   3.13 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   167 MBytes   140 Mbits/sec    0             sender
# [  5]   0.00-10.00  sec   167 MBytes   140 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-7 to k8s-worker-4: 198 Mbits/sec
# Full output from bandwidth-measurement-ds-z4wqx to bandwidth-measurement-ds-6dldb:
# Connecting to host 192.168.69.209, port 5201
# [  5] local 192.168.79.76 port 57098 connected to 192.168.69.209 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  3.95 MBytes  33.1 Mbits/sec    0    217 KBytes
# [  5]   1.00-2.00   sec  3.39 MBytes  28.4 Mbits/sec    0    374 KBytes
# [  5]   2.00-3.00   sec  4.04 MBytes  33.9 Mbits/sec    0    547 KBytes
# [  5]   3.00-4.00   sec  4.93 MBytes  41.4 Mbits/sec    0    765 KBytes
# [  5]   4.00-5.00   sec  6.70 MBytes  56.2 Mbits/sec    0   1.07 MBytes
# [  5]   5.00-6.00   sec  8.75 MBytes  73.4 Mbits/sec    0   1.47 MBytes
# [  5]   6.00-7.00   sec  10.0 MBytes  83.9 Mbits/sec    0   1.97 MBytes
# [  5]   7.00-8.00   sec  12.5 MBytes   105 Mbits/sec    0   2.59 MBytes
# [  5]   8.00-9.00   sec  12.5 MBytes   105 Mbits/sec    0   3.14 MBytes
# [  5]   9.00-10.00  sec  12.5 MBytes   105 Mbits/sec    0   3.14 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec  79.2 MBytes  66.5 Mbits/sec    0             sender
# [  5]   0.00-10.22  sec  79.0 MBytes  64.9 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-4 to k8s-worker-3: 33.1 Mbits/sec
# Full output from bandwidth-measurement-ds-z4wqx to bandwidth-measurement-ds-gnsh9:
# Connecting to host 192.168.230.44, port 5201
# [  5] local 192.168.79.76 port 50034 connected to 192.168.230.44 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  25.4 MBytes   213 Mbits/sec    0   1.43 MBytes
# [  5]   1.00-2.00   sec  22.5 MBytes   189 Mbits/sec    0   2.53 MBytes
# [  5]   2.00-3.00   sec  21.2 MBytes   178 Mbits/sec    0   3.15 MBytes
# [  5]   3.00-4.00   sec  21.2 MBytes   178 Mbits/sec    0   3.15 MBytes
# [  5]   4.00-5.00   sec  17.5 MBytes   147 Mbits/sec    0   3.15 MBytes
# [  5]   5.00-6.00   sec  17.5 MBytes   147 Mbits/sec    0   3.15 MBytes
# [  5]   6.00-7.00   sec  15.0 MBytes   126 Mbits/sec    0   3.15 MBytes
# [  5]   7.00-8.00   sec  12.5 MBytes   105 Mbits/sec    0   3.15 MBytes
# [  5]   8.00-9.00   sec  12.5 MBytes   105 Mbits/sec    0   3.15 MBytes
# [  5]   9.00-10.00  sec  12.5 MBytes   105 Mbits/sec    0   3.15 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   178 MBytes   149 Mbits/sec    0             sender
# [  5]   0.00-10.21  sec   178 MBytes   146 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-4 to k8s-worker-1: 213 Mbits/sec
# Full output from bandwidth-measurement-ds-z4wqx to bandwidth-measurement-ds-p2vgl:
# Connecting to host 192.168.18.232, port 5201
# [  5] local 192.168.79.76 port 55358 connected to 192.168.18.232 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  7.81 MBytes  65.5 Mbits/sec    0    521 KBytes
# [  5]   1.00-2.00   sec  7.60 MBytes  63.8 Mbits/sec    0    852 KBytes
# [  5]   2.00-3.00   sec  7.09 MBytes  59.5 Mbits/sec    0   1.17 MBytes
# [  5]   3.00-4.00   sec  6.25 MBytes  52.4 Mbits/sec    0   1.49 MBytes
# [  5]   4.00-5.00   sec  6.25 MBytes  52.4 Mbits/sec    0   1.81 MBytes
# [  5]   5.00-6.00   sec  8.75 MBytes  73.4 Mbits/sec    0   2.20 MBytes
# [  5]   6.00-7.00   sec  6.25 MBytes  52.4 Mbits/sec    0   2.55 MBytes
# [  5]   7.00-8.00   sec  8.75 MBytes  73.4 Mbits/sec    0   2.97 MBytes
# [  5]   8.00-9.00   sec  8.75 MBytes  73.4 Mbits/sec    0   3.13 MBytes
# [  5]   9.00-10.00  sec  7.50 MBytes  62.9 Mbits/sec    0   3.13 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec  75.0 MBytes  62.9 Mbits/sec    0             sender
# [  5]   0.00-10.25  sec  75.0 MBytes  61.3 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-4 to k8s-worker-5: 65.5 Mbits/sec
# Full output from bandwidth-measurement-ds-z4wqx to bandwidth-measurement-ds-r7ftn:
# Connecting to host 192.168.251.65, port 5201
# [  5] local 192.168.79.76 port 39472 connected to 192.168.251.65 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  10.4 MBytes  86.9 Mbits/sec    0    574 KBytes
# [  5]   1.00-2.00   sec  8.49 MBytes  71.3 Mbits/sec    0    956 KBytes
# [  5]   2.00-3.00   sec  8.64 MBytes  72.5 Mbits/sec    0   1.32 MBytes
# [  5]   3.00-4.00   sec  7.50 MBytes  62.9 Mbits/sec    0   1.71 MBytes
# [  5]   4.00-5.00   sec  7.50 MBytes  62.9 Mbits/sec    0   2.08 MBytes
# [  5]   5.00-6.00   sec  8.75 MBytes  73.4 Mbits/sec    0   2.51 MBytes
# [  5]   6.00-7.00   sec  7.50 MBytes  62.9 Mbits/sec    0   2.94 MBytes
# [  5]   7.00-8.00   sec  8.75 MBytes  73.4 Mbits/sec    0   3.13 MBytes
# [  5]   8.00-9.00   sec  8.75 MBytes  73.4 Mbits/sec    0   3.13 MBytes
# [  5]   9.00-10.00  sec  8.75 MBytes  73.4 Mbits/sec    0   3.13 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec  85.0 MBytes  71.3 Mbits/sec    0             sender
# [  5]   0.00-10.32  sec  84.5 MBytes  68.7 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-4 to k8s-worker-9: 86.9 Mbits/sec
# Full output from bandwidth-measurement-ds-z4wqx to bandwidth-measurement-ds-nrznp:
# Connecting to host 192.168.231.226, port 5201
# [  5] local 192.168.79.76 port 44228 connected to 192.168.231.226 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  13.9 MBytes   117 Mbits/sec    0    843 KBytes
# [  5]   1.00-2.00   sec  12.2 MBytes   102 Mbits/sec    0   1.39 MBytes
# [  5]   2.00-3.00   sec  11.2 MBytes  94.4 Mbits/sec    0   1.95 MBytes
# [  5]   3.00-4.00   sec  10.0 MBytes  83.9 Mbits/sec    0   2.49 MBytes
# [  5]   4.00-5.00   sec  11.2 MBytes  94.4 Mbits/sec    0   3.06 MBytes
# [  5]   5.00-6.00   sec  8.75 MBytes  73.4 Mbits/sec    0   3.15 MBytes
# [  5]   6.00-7.00   sec  8.75 MBytes  73.4 Mbits/sec    0   3.15 MBytes
# [  5]   7.00-8.00   sec  8.75 MBytes  73.4 Mbits/sec    0   3.15 MBytes
# [  5]   8.00-9.00   sec  7.50 MBytes  62.9 Mbits/sec    0   3.15 MBytes
# [  5]   9.00-10.00  sec  8.75 MBytes  73.4 Mbits/sec    0   3.15 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   101 MBytes  84.8 Mbits/sec    0             sender
# [  5]   0.00-10.31  sec   101 MBytes  82.3 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-4 to k8s-worker-8: 117 Mbits/sec
# Full output from bandwidth-measurement-ds-z4wqx to bandwidth-measurement-ds-vf5qp:
# Connecting to host 192.168.140.9, port 5201
# [  5] local 192.168.79.76 port 60714 connected to 192.168.140.9 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  12.0 MBytes   101 Mbits/sec    0    660 KBytes
# [  5]   1.00-2.00   sec  10.6 MBytes  88.8 Mbits/sec    0   1.10 MBytes
# [  5]   2.00-3.00   sec  8.75 MBytes  73.4 Mbits/sec    0   1.54 MBytes
# [  5]   3.00-4.00   sec  10.0 MBytes  83.9 Mbits/sec    0   2.01 MBytes
# [  5]   4.00-5.00   sec  7.50 MBytes  62.9 Mbits/sec    0   2.44 MBytes
# [  5]   5.00-6.00   sec  10.0 MBytes  83.9 Mbits/sec    0   2.92 MBytes
# [  5]   6.00-7.00   sec  6.25 MBytes  52.4 Mbits/sec    7   1.06 MBytes
# [  5]   7.00-8.00   sec  8.75 MBytes  73.4 Mbits/sec    0   2.43 MBytes
# [  5]   8.00-9.00   sec  8.75 MBytes  73.4 Mbits/sec    0   2.72 MBytes
# [  5]   9.00-10.00  sec  7.50 MBytes  62.9 Mbits/sec    0   2.91 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec  90.1 MBytes  75.6 Mbits/sec    7             sender
# [  5]   0.00-10.31  sec  90.1 MBytes  73.4 Mbits/sec                  receiver
#
# iperf Done.
# Full output from bandwidth-measurement-ds-z4wqx to bandwidth-measurement-ds-z29qn:
# Connecting to host 192.168.5.12, port 5201
# [  5] local 192.168.79.76 port 51700 connected to 192.168.5.12 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  9.95 MBytes  83.4 Mbits/sec    0    608 KBytes
# [  5]   1.00-2.00   sec  8.80 MBytes  73.9 Mbits/sec    0    999 KBytes
# [  5]   2.00-3.00   sec  7.50 MBytes  62.9 Mbits/sec    0   1.37 MBytes
# [  5]   3.00-4.00   sec  8.75 MBytes  73.4 Mbits/sec    0   1.81 MBytes
# [  5]   4.00-5.00   sec  8.75 MBytes  73.4 Mbits/sec    0   2.20 MBytes
# [  5]   5.00-6.00   sec  6.25 MBytes  52.4 Mbits/sec    0   2.55 MBytes
# [  5]   6.00-7.00   sec  10.0 MBytes  83.9 Mbits/sec    0   3.03 MBytes
# [  5]   7.00-8.00   sec  7.50 MBytes  62.9 Mbits/sec    0   3.13 MBytes
# [  5]   8.00-9.00   sec  10.0 MBytes  83.9 Mbits/sec    0   3.13 MBytes
# [  5]   9.00-10.00  sec  7.50 MBytes  62.9 Mbits/sec    0   3.13 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec  85.0 MBytes  71.3 Mbits/sec    0             sender
# [  5]   0.00-10.25  sec  85.0 MBytes  69.6 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-4 to k8s-worker-7: 83.4 Mbits/sec
#
# Bandwidth from k8s-worker-4 to k8s-worker-2: 101 Mbits/sec
# Full output from bandwidth-measurement-ds-z4wqx to bandwidth-measurement-ds-rfvj2:
# Connecting to host 192.168.227.155, port 5201
# [  5] local 192.168.79.76 port 59978 connected to 192.168.227.155 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  9.95 MBytes  83.4 Mbits/sec    0    608 KBytes
# [  5]   1.00-2.00   sec  8.93 MBytes  74.9 Mbits/sec    0   1.01 MBytes
# [  5]   2.00-3.00   sec  8.75 MBytes  73.4 Mbits/sec    0   1.42 MBytes
# [  5]   3.00-4.00   sec  7.50 MBytes  62.9 Mbits/sec    0   1.81 MBytes
# [  5]   4.00-5.00   sec  8.75 MBytes  73.4 Mbits/sec    0   2.20 MBytes
# [  5]   5.00-6.00   sec  8.75 MBytes  73.4 Mbits/sec    0   2.66 MBytes
# [  5]   6.00-7.00   sec  7.50 MBytes  62.9 Mbits/sec    0   3.07 MBytes
# [  5]   7.00-8.00   sec  10.0 MBytes  83.9 Mbits/sec    0   3.14 MBytes
# [  5]   8.00-9.00   sec  7.50 MBytes  62.9 Mbits/sec    0   3.14 MBytes
# [  5]   9.00-10.00  sec  7.50 MBytes  62.9 Mbits/sec    0   3.14 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec  85.1 MBytes  71.4 Mbits/sec    0             sender
# [  5]   0.00-10.25  sec  85.1 MBytes  69.7 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-4 to k8s-worker-6: 83.4 Mbits/sec
# {'k8s-worker-3': {'k8s-worker-1': '263 Mbits/sec', 'k8s-worker-5': '158 Mbits/sec', 'k8s-worker-8': '114 Mbits/sec', 'k8s-worker-2': '263 Mbits/sec', 'k8s-worker-9': '119 Mbits/sec', 'k8s-worker-6': '156 Mbits/sec', 'k8s-worker-4': '346 Mbits/sec', 'k8s-worker-7': '161 Mbits/sec'}, 'k8s-worker-1': {'k8s-worker-3': '124 Mbits/sec', 'k8s-worker-5': '88.4 Mbits/sec', 'k8s-worker-8': '148 Mbits/sec', 'k8s-worker-9': '425 Mbits/sec', 'k8s-worker-2': '114 Mbits/sec', 'k8s-worker-6': '444 Mbits/sec', 'k8s-worker-7': '103 Mbits/sec', 'k8s-worker-4': '611 Mbits/sec'}, 'k8s-worker-8': {'k8s-worker-3': '374 Mbits/sec', 'k8s-worker-1': '254 Mbits/sec', 'k8s-worker-9': '186 Mbits/sec', 'k8s-worker-6': '225 Mbits/sec', 'k8s-worker-5': '260 Mbits/sec', 'k8s-worker-7': '385 Mbits/sec', 'k8s-worker-4': '158 Mbits/sec', 'k8s-worker-2': '122 Mbits/sec'}, 'k8s-worker-5': {'k8s-worker-1': '127 Mbits/sec', 'k8s-worker-8': '478 Mbits/sec', 'k8s-worker-3': '150 Mbits/sec', 'k8s-worker-6': '231 Mbits/sec', 'k8s-worker-9': '167 Mbits/sec', 'k8s-worker-2': '380 Mbits/sec', 'k8s-worker-7': '251 Mbits/sec', 'k8s-worker-4': '454 Mbits/sec'}, 'k8s-worker-9': {'k8s-worker-3': '768 Mbits/sec', 'k8s-worker-1': '274 Mbits/sec', 'k8s-worker-5': '164 Mbits/sec', 'k8s-worker-8': '408 Mbits/sec', 'k8s-worker-6': '160 Mbits/sec', 'k8s-worker-2': '190 Mbits/sec', 'k8s-worker-7': '494 Mbits/sec', 'k8s-worker-4': '785 Mbits/sec'}, 'k8s-worker-6': {'k8s-worker-1': '229 Mbits/sec', 'k8s-worker-3': '118 Mbits/sec', 'k8s-worker-9': '208 Mbits/sec', 'k8s-worker-5': '122 Mbits/sec', 'k8s-worker-8': '27.8 Mbits/sec', 'k8s-worker-2': '243 Mbits/sec', 'k8s-worker-4': '21.9 Mbits/sec', 'k8s-worker-7': '83.4 Mbits/sec'}, 'k8s-worker-2': {'k8s-worker-8': '342 Mbits/sec', 'k8s-worker-1': '211 Mbits/sec', 'k8s-worker-3': '259 Mbits/sec', 'k8s-worker-9': '134 Mbits/sec', 'k8s-worker-6': '519 Mbits/sec', 'k8s-worker-5': '154 Mbits/sec', 'k8s-worker-7': '124 Mbits/sec', 'k8s-worker-4': '634 Mbits/sec'}, 'k8s-worker-7': {'k8s-worker-3': '641 Mbits/sec', 'k8s-worker-1': '176 Mbits/sec', 'k8s-worker-5': '97.3 Mbits/sec', 'k8s-worker-8': '431 Mbits/sec', 'k8s-worker-2': '158 Mbits/sec', 'k8s-worker-9': '161 Mbits/sec', 'k8s-worker-6': '377 Mbits/sec', 'k8s-worker-4': '198 Mbits/sec'}, 'k8s-worker-4': {'k8s-worker-3': '33.1 Mbits/sec', 'k8s-worker-1': '213 Mbits/sec', 'k8s-worker-5': '65.5 Mbits/sec', 'k8s-worker-9': '86.9 Mbits/sec', 'k8s-worker-8': '117 Mbits/sec', 'k8s-worker-7': '83.4 Mbits/sec', 'k8s-worker-2': '101 Mbits/sec', 'k8s-worker-6': '83.4 Mbits/sec'}}

# %%
import pandas as pd

# Convert the nested dictionary into a pandas DataFrame
df = pd.DataFrame(bandwidth_results)

# Transpose the DataFrame to align the source and destination workers as per convention
df = df.T

# Fill diagonal with 0's for self-latency (optional, if desired for clarity)
for worker in df.columns:
    df.at[worker, worker] = 0

# Save the DataFrame to a CSV file, and add the date, hour and minute to the file name
import datetime
now = datetime.datetime.now()
filename = f"bandwidth_results_{now.strftime('%Y-%m-%d_%H-%M')}.csv"
df.to_csv("/home/ubuntu/iDynamics/iBandwidth/measurer/data/"+filename)
df
# Out:
#                 k8s-worker-1    k8s-worker-5    k8s-worker-8    k8s-worker-6  \
# k8s-worker-3   221 Mbits/sec   224 Mbits/sec   224 Mbits/sec   168 Mbits/sec
# k8s-worker-1               0   136 Mbits/sec   202 Mbits/sec   151 Mbits/sec
# k8s-worker-8   110 Mbits/sec   114 Mbits/sec               0   133 Mbits/sec
# k8s-worker-5   229 Mbits/sec               0   355 Mbits/sec   113 Mbits/sec
# k8s-worker-9   236 Mbits/sec  95.4 Mbits/sec  18.9 Mbits/sec   165 Mbits/sec
# k8s-worker-6   360 Mbits/sec   271 Mbits/sec   145 Mbits/sec               0
# k8s-worker-2   104 Mbits/sec   169 Mbits/sec   123 Mbits/sec   147 Mbits/sec
# k8s-worker-7  20.4 Mbits/sec  12.9 Mbits/sec   245 Mbits/sec  20.4 Mbits/sec
# k8s-worker-4   173 Mbits/sec   374 Mbits/sec   224 Mbits/sec   218 Mbits/sec
#
#                k8s-worker-2   k8s-worker-9    k8s-worker-4    k8s-worker-7  \
# k8s-worker-3  255 Mbits/sec  252 Mbits/sec   350 Mbits/sec   277 Mbits/sec
# k8s-worker-1  354 Mbits/sec  233 Mbits/sec   509 Mbits/sec  43.1 Mbits/sec
# k8s-worker-8  103 Mbits/sec  141 Mbits/sec   134 Mbits/sec   144 Mbits/sec
# k8s-worker-5  469 Mbits/sec  133 Mbits/sec   452 Mbits/sec   233 Mbits/sec
# k8s-worker-9  110 Mbits/sec              0   333 Mbits/sec  93.9 Mbits/sec
# k8s-worker-6  175 Mbits/sec  150 Mbits/sec   112 Mbits/sec   288 Mbits/sec
# k8s-worker-2              0  374 Mbits/sec   627 Mbits/sec  12.2 Mbits/sec
# k8s-worker-7  137 Mbits/sec  143 Mbits/sec  36.1 Mbits/sec               0
# k8s-worker-4  404 Mbits/sec  135 Mbits/sec               0   135 Mbits/sec
#
#                k8s-worker-3
# k8s-worker-3              0
# k8s-worker-1  365 Mbits/sec
# k8s-worker-8  237 Mbits/sec
# k8s-worker-5  125 Mbits/sec
# k8s-worker-9  329 Mbits/sec
# k8s-worker-6  180 Mbits/sec
# k8s-worker-2  463 Mbits/sec
# k8s-worker-7  268 Mbits/sec
# k8s-worker-4  528 Mbits/sec

# %%
# Out:
# Bandwidth from k8s-worker-3 to k8s-worker-1: 806 Mbits/sec
# Bandwidth from k8s-worker-3 to k8s-worker-8: 801 Mbits/sec
# Bandwidth from k8s-worker-3 to k8s-worker-5: 814 Mbits/sec
# Bandwidth from k8s-worker-3 to k8s-worker-9: 813 Mbits/sec
# Bandwidth from k8s-worker-3 to k8s-worker-6: 813 Mbits/sec
# Bandwidth from k8s-worker-3 to k8s-worker-2: 805 Mbits/sec
# Bandwidth from k8s-worker-3 to k8s-worker-7: 815 Mbits/sec
# Bandwidth from k8s-worker-3 to k8s-worker-4: 806 Mbits/sec
# Bandwidth from k8s-worker-1 to k8s-worker-3: 806 Mbits/sec
# Bandwidth from k8s-worker-1 to k8s-worker-8: 819 Mbits/sec
# Bandwidth from k8s-worker-1 to k8s-worker-5: 814 Mbits/sec
# Bandwidth from k8s-worker-1 to k8s-worker-9: 819 Mbits/sec
# Bandwidth from k8s-worker-1 to k8s-worker-6: 807 Mbits/sec
# Bandwidth from k8s-worker-1 to k8s-worker-2: 813 Mbits/sec
# Bandwidth from k8s-worker-1 to k8s-worker-7: 813 Mbits/sec
# Bandwidth from k8s-worker-1 to k8s-worker-4: 810 Mbits/sec
# Bandwidth from k8s-worker-8 to k8s-worker-3: 794 Mbits/sec
# Bandwidth from k8s-worker-8 to k8s-worker-1: 813 Mbits/sec
# Bandwidth from k8s-worker-8 to k8s-worker-5: 802 Mbits/sec
# Bandwidth from k8s-worker-8 to k8s-worker-9: 801 Mbits/sec
# Bandwidth from k8s-worker-8 to k8s-worker-6: 796 Mbits/sec
# Bandwidth from k8s-worker-8 to k8s-worker-2: 794 Mbits/sec
# Bandwidth from k8s-worker-8 to k8s-worker-7: 762 Mbits/sec
# Bandwidth from k8s-worker-8 to k8s-worker-4: 800 Mbits/sec
# Bandwidth from k8s-worker-5 to k8s-worker-3: 803 Mbits/sec
# Bandwidth from k8s-worker-5 to k8s-worker-1: 806 Mbits/sec
# Bandwidth from k8s-worker-5 to k8s-worker-8: 799 Mbits/sec
# Bandwidth from k8s-worker-5 to k8s-worker-9: 806 Mbits/sec
# Bandwidth from k8s-worker-5 to k8s-worker-6: 806 Mbits/sec
# Bandwidth from k8s-worker-5 to k8s-worker-2: 801 Mbits/sec
# Bandwidth from k8s-worker-5 to k8s-worker-7: 805 Mbits/sec
# Bandwidth from k8s-worker-5 to k8s-worker-4: 799 Mbits/sec
# Bandwidth from k8s-worker-9 to k8s-worker-3: 801 Mbits/sec
# Bandwidth from k8s-worker-9 to k8s-worker-1: 813 Mbits/sec
# Bandwidth from k8s-worker-9 to k8s-worker-8: 813 Mbits/sec
# Bandwidth from k8s-worker-9 to k8s-worker-5: 802 Mbits/sec
# Bandwidth from k8s-worker-9 to k8s-worker-6: 810 Mbits/sec
# Bandwidth from k8s-worker-9 to k8s-worker-2: 814 Mbits/sec
# Bandwidth from k8s-worker-9 to k8s-worker-7: 800 Mbits/sec
# Bandwidth from k8s-worker-9 to k8s-worker-4: 797 Mbits/sec
# Bandwidth from k8s-worker-6 to k8s-worker-3: 806 Mbits/sec
# Bandwidth from k8s-worker-6 to k8s-worker-1: 804 Mbits/sec
# Bandwidth from k8s-worker-6 to k8s-worker-8: 808 Mbits/sec
# Bandwidth from k8s-worker-6 to k8s-worker-5: 808 Mbits/sec
# Bandwidth from k8s-worker-6 to k8s-worker-9: 804 Mbits/sec
# Bandwidth from k8s-worker-6 to k8s-worker-2: 802 Mbits/sec
# Bandwidth from k8s-worker-6 to k8s-worker-7: 813 Mbits/sec
# Bandwidth from k8s-worker-6 to k8s-worker-4: 813 Mbits/sec
# Bandwidth from k8s-worker-2 to k8s-worker-3: 816 Mbits/sec
# Bandwidth from k8s-worker-2 to k8s-worker-1: 810 Mbits/sec
# Bandwidth from k8s-worker-2 to k8s-worker-8: 815 Mbits/sec
# Bandwidth from k8s-worker-2 to k8s-worker-5: 811 Mbits/sec
# Bandwidth from k8s-worker-2 to k8s-worker-9: 813 Mbits/sec
# Bandwidth from k8s-worker-2 to k8s-worker-6: 813 Mbits/sec
# Bandwidth from k8s-worker-2 to k8s-worker-7: 813 Mbits/sec
# Bandwidth from k8s-worker-2 to k8s-worker-4: 816 Mbits/sec
# Bandwidth from k8s-worker-7 to k8s-worker-3: 816 Mbits/sec
# Bandwidth from k8s-worker-7 to k8s-worker-1: 809 Mbits/sec
